# %%
pip install keras-tcn
# Out:
# Requirement already satisfied: keras-tcn in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences
timesteps = 104
# dimension of data sequences
n_dim = 80
batch_size = 2

# %%
drive.mount('/content/drive')
dir_name_samples ='/content/drive/My Drive/new_kimore/Preprocessed_data/Exercise3_data.csv'
dir_name_labels ='/content/drive/My Drive/new_kimore/Preprocessed_data/Labels_ex3.csv'
import warnings
warnings.filterwarnings("ignore")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_values = pd.read_csv(dir_name_samples, delimiter=',', encoding='utf-8')
print(X_values.shape)
# # Initialize the MinMaxScaler

# scaler = StandardScaler()
# # Fit and transform the data using the scaler
# scaled_data = scaler.fit_transform(X_values)

# # Create a new DataFrame with the scaled data
# scaled_df = pd.DataFrame(scaled_data, columns=X_values.columns)


# # Extract the underlying NumPy array
# numpy_2d_array = scaled_df.values
# #numpy_2d_array = X_values.values
# # Reshape the 2D array into a 3D array (207, 100, 80)
# X_train = numpy_2d_array.reshape(207, 100, 80)
# # The temporal pyramid requires that the length of the data sequences is divisible by 8.
# # The original length was 100 time steps, so we will repeat the first and last 2 data vectors to obtain sequences with 104 time steps
# X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
numpy_2d_array = X_values.values
X_train = numpy_2d_array.reshape(189, 100, 80)
# Calculate the mean along the specified axes (axis=0, axis=1, and axis=2) to obtain a mean value for the entire array
mean_value = X_train.mean(axis=(0, 1, 2))

# Subtract the mean from the entire array to achieve zero mean
X_train -= mean_value

# Calculate the maximum and minimum values in the array
max_value = X_train.max()
min_value = X_train.min()

# Normalize the array to a range between -1 and 1
data = 2 * (X_train - min_value) / (max_value - min_value) - 1
smoothed_data = np.empty_like(X_train)
for channel in range(80):
    smoothed_data[:, :, channel] = gaussian_filter1d(data[:, :, channel], sigma=5)
X_train=smoothed_data
X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
#-----------labels------------------------------------
Y_values = pd.read_csv(dir_name_labels)
#change the secon column to the labels
y_values= Y_values['EX3'].values

reshaped_data_y = y_values.reshape(189, 1)
# Fit and transform the data using the scaler
#scaler2 = MinMaxScaler(feature_range=(0, 1))
#y_train = scaler2.fit_transform(reshaped_data_y)
min_value = np.min(reshaped_data_y)
max_value = np.max(reshaped_data_y)

# Normalize the vector to be in the range [-1, 1]
y_train = (reshaped_data_y - min_value) / (max_value - min_value)

print('Training sequences dimension', X_train)
print('Training labels dimension', y_train)
# Out:
# (18900, 80)
# Training sequences dimension [[[ 3.59181808e-02  1.23042925e-02  3.41991805e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 3.59329628e-02  1.23353236e-02  3.42067616e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 3.59181808e-02  1.23042925e-02  3.41991805e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   ...
#   [ 2.19753215e-01  3.09667214e-03  1.26327103e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 2.21286387e-01  3.17237706e-03  1.22232970e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 2.20286395e-01  3.12107306e-03  1.24903038e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]]
#
#  [[ 1.10170308e-01  1.04990597e-02  2.85419523e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 1.07968120e-01  1.06805464e-02  2.87397591e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 1.10170308e-01  1.04990597e-02  2.85419523e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   ...
#   [ 8.92577161e-02  1.67863670e-02  3.13512844e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 9.60968815e-02  1.61731943e-02  3.04472754e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 9.15788552e-02  1.65764854e-02  3.10470669e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]]
#
#  [[ 2.22890395e-02  1.75183247e-02  3.41944994e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 2.09813588e-02  1.76348614e-02  3.40896634e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 2.22890395e-02  1.75183247e-02  3.41944994e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   ...
#   [ 3.44628321e-02  1.70814825e-02  3.37762982e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 3.87230801e-02  1.67899962e-02  3.35889872e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 3.58879678e-02  1.69836134e-02  3.37160603e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]]
#
#  ...
#
#  [[-1.75438267e-02  1.71828735e-02  2.65576874e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [-1.75224434e-02  1.72210994e-02  2.65560210e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [-1.75438267e-02  1.71828735e-02  2.65576874e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   ...
#   [-4.88128143e-02  3.81519713e-02  2.28932843e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [-5.40840346e-02  3.95545630e-02  2.22639821e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [-5.06259927e-02  3.86333170e-02  2.26778579e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]]
#
#  [[ 7.47162856e-02  1.13488479e-02  2.27925320e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 7.61717522e-02  1.10848361e-02  2.25586310e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 7.47162856e-02  1.13488479e-02  2.27925320e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   ...
#   [ 9.21649304e-02 -6.06583566e-05  1.70561051e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 1.00059509e-01 -9.95952527e-04  1.42376559e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 9.48257319e-02 -3.78589772e-04  1.61059357e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]]
#
#  [[ 1.13522820e-01 -1.37227939e-03  2.22159115e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 1.14199008e-01 -1.50256596e-03  2.20997587e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 1.13522820e-01 -1.37227939e-03  2.22159115e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   ...
#   [ 1.19485582e-01 -4.99116698e-04  2.15635253e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 1.16704682e-01 -1.02707825e-03  2.17984467e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]
#   [ 1.18580823e-01 -6.82924150e-04  2.16391203e-02 ...  1.99715802e-02
#     1.99715802e-02  1.99715802e-02]]]
# Training labels dimension [[0.95833333]
#  [0.95833333]
#  [0.95833333]
#  [0.89166667]
#  [0.89166667]
#  [0.89166667]
#  [0.98333333]
#  [0.98333333]
#  [0.98333333]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.9       ]
#  [0.9       ]
#  [0.9       ]
#  [0.95      ]
#  [0.95      ]
#  [0.95      ]
#  [0.675     ]
#  [0.675     ]
#  [0.675     ]
#  [0.69166667]
#  [0.69166667]
#  [0.69166667]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.76666667]
#  [0.76666667]
#  [0.76666667]
#  [0.7       ]
#  [0.7       ]
#  [0.7       ]
#  [0.80833333]
#  [0.80833333]
#  [0.80833333]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.575     ]
#  [0.575     ]
#  [0.575     ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.5       ]
#  [0.5       ]
#  [0.5       ]
#  [0.8       ]
#  [0.8       ]
#  [0.8       ]
#  [0.825     ]
#  [0.825     ]
#  [0.825     ]
#  [0.8       ]
#  [0.8       ]
#  [0.8       ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.975     ]
#  [0.975     ]
#  [0.975     ]
#  [0.95      ]
#  [0.95      ]
#  [0.95      ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.725     ]
#  [0.725     ]
#  [0.725     ]
#  [0.925     ]
#  [0.925     ]
#  [0.925     ]
#  [0.925     ]
#  [0.925     ]
#  [0.925     ]
#  [0.95      ]
#  [0.95      ]
#  [0.95      ]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.925     ]
#  [0.925     ]
#  [0.925     ]
#  [0.9       ]
#  [0.9       ]
#  [0.9       ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.875     ]
#  [0.875     ]
#  [0.875     ]
#  [0.9       ]
#  [0.9       ]
#  [0.9       ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.4       ]
#  [0.4       ]
#  [0.4       ]
#  [0.625     ]
#  [0.625     ]
#  [0.625     ]
#  [0.37945345]
#  [0.37945345]
#  [0.37945345]
#  [0.70897055]
#  [0.70897055]
#  [0.70897055]
#  [0.66666667]
#  [0.66666667]
#  [0.66666667]
#  [0.93333333]
#  [0.93333333]
#  [0.93333333]
#  [0.85833333]
#  [0.85833333]
#  [0.85833333]
#  [0.66666667]
#  [0.66666667]
#  [0.66666667]
#  [0.95      ]
#  [0.95      ]
#  [0.95      ]
#  [0.125     ]
#  [0.125     ]
#  [0.125     ]
#  [0.875     ]
#  [0.875     ]
#  [0.875     ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.95      ]
#  [0.95      ]
#  [0.95      ]
#  [0.675     ]
#  [0.675     ]
#  [0.675     ]
#  [0.825     ]
#  [0.825     ]
#  [0.825     ]
#  [0.41738199]
#  [0.41738199]
#  [0.41738199]
#  [0.06666667]
#  [0.06666667]
#  [0.06666667]
#  [0.69166667]
#  [0.69166667]
#  [0.69166667]
#  [0.7       ]
#  [0.7       ]
#  [0.7       ]
#  [0.5       ]
#  [0.5       ]
#  [0.5       ]
#  [0.93333333]
#  [0.93333333]
#  [0.93333333]
#  [0.8       ]
#  [0.8       ]
#  [0.8       ]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [0.4       ]
#  [0.4       ]
#  [0.4       ]
#  [0.60366167]
#  [0.60366167]
#  [0.60366167]
#  [0.6       ]
#  [0.6       ]
#  [0.6       ]
#  [0.55      ]
#  [0.55      ]
#  [0.55      ]
#  [0.96666667]
#  [0.96666667]
#  [0.96666667]]

# %%
# Split the data into training and validation sets
train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.3)
# Split your dataset into a training set (60%) and a combined validation-testing set (40%)
train_x, X_val_test, train_y, y_val_test = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

# Split the combined validation-testing set (40%) into a validation set (20%) and a test set (20%)
valid_x, test_x, valid_y, test_y = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# Now, you have X_train, y_train for training (60%), X_val, y_val for validation (20%), and X_test, y_test for testing (20%)
print('Training data', train_x.shape)
print('Validation data', valid_x.shape)
print('Training label', train_y.shape)
print('Validation label', valid_y.shape)
# Out:
# Training data (113, 104, 80)
# Validation data (38, 104, 80)
# Training label (113, 1)
# Validation label (38, 1)

# %%
# Plot the first and last sequences in the training and validation data
plt.figure(figsize = (14,8))
plt.subplot(2,2,1)
plt.plot(train_x[0])
plt.subplot(2,2,2)
plt.plot(train_x[-1])
plt.subplot(2,2,3)
plt.plot(valid_x[0])
plt.subplot(2,2,4)
plt.plot(valid_x[-1])
plt.tight_layout()
plt.show()

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)
trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)
trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)
trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]
trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]
trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
trainx =  train_x
validx =  valid_x
testx =  test_x

# %%
import matplotlib.patches as mpatches
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(trainx[0,:,0:16], color='red')
plt.plot(trainx[0,:,16:32], color='blue')
plt.plot(trainx[0,:,32:48], color='green')
plt.plot(trainx[0,:,48:64], color='orange')
plt.plot(trainx[0,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('First Train Sequence')
plt.subplot(1,2,2)
plt.plot(trainx[-1,:,0:16], color='red')
plt.plot(trainx[-1,:,16:32], color='blue')
plt.plot(trainx[-1,:,32:48], color='green')
plt.plot(trainx[-1,:,48:64], color='orange')
plt.plot(trainx[-1,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('Last Train Sequence')
plt.tight_layout()
plt.show()

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
n_dim = 80 # dimension after reordering the data into body parts
n_dim1 = 16 # dimension of indiviudal body parts
n_dim2 = 16
n_dim3 = 16 # legs dimension
# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps,n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 16:32])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 32:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:64])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 64:80])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 16:32])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 32:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:64])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 64:80])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 16:32])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 32:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:64])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 64:80])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 16:32])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 32:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:64])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'linear')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 104, 80)]            0         []
#
#  half_scale (InputLayer)     [(None, 52, 80)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 26, 80)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 13, 80)]             0         []
#
#  lambda_20 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_25 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_30 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_35 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_21 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_26 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_31 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_36 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_22 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_27 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_32 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_37 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_23 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_28 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_33 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_38 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_24 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_29 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_34 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_39 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  tcn_23 (TCN)                (None, 104, 12)              5676      ['lambda_20[0][0]']
#
#  tcn_24 (TCN)                (None, 52, 12)               5676      ['lambda_25[0][0]']
#
#  tcn_25 (TCN)                (None, 26, 12)               5676      ['lambda_30[0][0]']
#
#  tcn_26 (TCN)                (None, 13, 12)               5676      ['lambda_35[0][0]']
#
#  tcn_27 (TCN)                (None, 104, 12)              5676      ['lambda_21[0][0]']
#
#  tcn_28 (TCN)                (None, 52, 12)               5676      ['lambda_26[0][0]']
#
#  tcn_29 (TCN)                (None, 26, 12)               5676      ['lambda_31[0][0]']
#
#  tcn_30 (TCN)                (None, 13, 12)               5676      ['lambda_36[0][0]']
#
#  tcn_31 (TCN)                (None, 104, 12)              5676      ['lambda_22[0][0]']
#
#  tcn_32 (TCN)                (None, 52, 12)               5676      ['lambda_27[0][0]']
#
#  tcn_33 (TCN)                (None, 26, 12)               5676      ['lambda_32[0][0]']
#
#  tcn_34 (TCN)                (None, 13, 12)               5676      ['lambda_37[0][0]']
#
#  tcn_35 (TCN)                (None, 104, 12)              5676      ['lambda_23[0][0]']
#
#  tcn_36 (TCN)                (None, 52, 12)               5676      ['lambda_28[0][0]']
#
#  tcn_37 (TCN)                (None, 26, 12)               5676      ['lambda_33[0][0]']
#
#  tcn_38 (TCN)                (None, 13, 12)               5676      ['lambda_38[0][0]']
#
#  tcn_39 (TCN)                (None, 104, 12)              5676      ['lambda_24[0][0]']
#
#  tcn_40 (TCN)                (None, 52, 12)               5676      ['lambda_29[0][0]']
#
#  tcn_41 (TCN)                (None, 26, 12)               5676      ['lambda_34[0][0]']
#
#  tcn_42 (TCN)                (None, 13, 12)               5676      ['lambda_39[0][0]']
#
#  concatenate_6 (Concatenate  (None, 195, 12)              0         ['tcn_23[0][0]',
#  )                                                                   'tcn_24[0][0]',
#                                                                      'tcn_25[0][0]',
#                                                                      'tcn_26[0][0]']
#
#  concatenate_7 (Concatenate  (None, 195, 12)              0         ['tcn_27[0][0]',
#  )                                                                   'tcn_28[0][0]',
#                                                                      'tcn_29[0][0]',
#                                                                      'tcn_30[0][0]']
#
#  concatenate_8 (Concatenate  (None, 195, 12)              0         ['tcn_31[0][0]',
#  )                                                                   'tcn_32[0][0]',
#                                                                      'tcn_33[0][0]',
#                                                                      'tcn_34[0][0]']
#
#  concatenate_9 (Concatenate  (None, 195, 12)              0         ['tcn_35[0][0]',
#  )                                                                   'tcn_36[0][0]',
#                                                                      'tcn_37[0][0]',
#                                                                      'tcn_38[0][0]']
#
#  concatenate_10 (Concatenat  (None, 195, 12)              0         ['tcn_39[0][0]',
#  e)                                                                  'tcn_40[0][0]',
#                                                                      'tcn_41[0][0]',
#                                                                      'tcn_42[0][0]']
#
#  concatenate_11 (Concatenat  (None, 195, 60)              0         ['concatenate_6[0][0]',
#  e)                                                                  'concatenate_7[0][0]',
#                                                                      'concatenate_8[0][0]',
#                                                                      'concatenate_9[0][0]',
#                                                                      'concatenate_10[0][0]']
#
#  tcn_43 (TCN)                (None, 195, 12)              6012      ['concatenate_11[0][0]']
#
#  tcn_44 (TCN)                (None, 195, 8)               1176      ['tcn_43[0][0]']
#
#  tcn_45 (TCN)                (None, 6)                    546       ['tcn_44[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    7         ['tcn_45[0][0]']
#
# ==================================================================================================
# Total params: 121261 (473.68 KB)
# Trainable params: 121165 (473.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX3.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 17/17 [==============================] - ETA: 0s - loss: 1.8862
# Epoch 1: val_loss improved from inf to 4.72212, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 186s 1s/step - loss: 1.8862 - val_loss: 4.7221
# Epoch 2/400
# 17/17 [==============================] - ETA: 0s - loss: 0.8052
# Epoch 2: val_loss improved from 4.72212 to 0.52979, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 354ms/step - loss: 0.8052 - val_loss: 0.5298
# Epoch 3/400
# 17/17 [==============================] - ETA: 0s - loss: 0.5175
# Epoch 3: val_loss improved from 0.52979 to 0.30835, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 328ms/step - loss: 0.5175 - val_loss: 0.3083
# Epoch 4/400
# 17/17 [==============================] - ETA: 0s - loss: 0.2311
# Epoch 4: val_loss improved from 0.30835 to 0.24574, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 345ms/step - loss: 0.2311 - val_loss: 0.2457
# Epoch 5/400
# 17/17 [==============================] - ETA: 0s - loss: 0.3167
# Epoch 5: val_loss improved from 0.24574 to 0.19780, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 313ms/step - loss: 0.3167 - val_loss: 0.1978
# Epoch 6/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1678
# Epoch 6: val_loss did not improve from 0.19780
# 17/17 [==============================] - 2s 109ms/step - loss: 0.1678 - val_loss: 0.2483
# Epoch 7/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1817
# Epoch 7: val_loss did not improve from 0.19780
# 17/17 [==============================] - 3s 151ms/step - loss: 0.1817 - val_loss: 0.2134
# Epoch 8/400
# 17/17 [==============================] - ETA: 0s - loss: 0.2088
# Epoch 8: val_loss improved from 0.19780 to 0.17556, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 309ms/step - loss: 0.2088 - val_loss: 0.1756
# Epoch 9/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1820
# Epoch 9: val_loss improved from 0.17556 to 0.15107, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 316ms/step - loss: 0.1820 - val_loss: 0.1511
# Epoch 10/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1438
# Epoch 10: val_loss improved from 0.15107 to 0.14214, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 348ms/step - loss: 0.1438 - val_loss: 0.1421
# Epoch 11/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1431
# Epoch 11: val_loss improved from 0.14214 to 0.12256, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 312ms/step - loss: 0.1431 - val_loss: 0.1226
# Epoch 12/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1327
# Epoch 12: val_loss improved from 0.12256 to 0.10069, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 367ms/step - loss: 0.1327 - val_loss: 0.1007
# Epoch 13/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1478
# Epoch 13: val_loss improved from 0.10069 to 0.08724, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 317ms/step - loss: 0.1478 - val_loss: 0.0872
# Epoch 14/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1290
# Epoch 14: val_loss improved from 0.08724 to 0.07544, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 363ms/step - loss: 0.1290 - val_loss: 0.0754
# Epoch 15/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1183
# Epoch 15: val_loss improved from 0.07544 to 0.07110, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 323ms/step - loss: 0.1183 - val_loss: 0.0711
# Epoch 16/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1148
# Epoch 16: val_loss improved from 0.07110 to 0.06929, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 365ms/step - loss: 0.1148 - val_loss: 0.0693
# Epoch 17/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0819
# Epoch 17: val_loss did not improve from 0.06929
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0819 - val_loss: 0.0722
# Epoch 18/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1074
# Epoch 18: val_loss improved from 0.06929 to 0.06884, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 315ms/step - loss: 0.1074 - val_loss: 0.0688
# Epoch 19/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0959
# Epoch 19: val_loss improved from 0.06884 to 0.06862, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 343ms/step - loss: 0.0959 - val_loss: 0.0686
# Epoch 20/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1001
# Epoch 20: val_loss improved from 0.06862 to 0.06841, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 316ms/step - loss: 0.1001 - val_loss: 0.0684
# Epoch 21/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0870
# Epoch 21: val_loss improved from 0.06841 to 0.06831, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 359ms/step - loss: 0.0870 - val_loss: 0.0683
# Epoch 22/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0749
# Epoch 22: val_loss improved from 0.06831 to 0.06517, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 317ms/step - loss: 0.0749 - val_loss: 0.0652
# Epoch 23/400
# 17/17 [==============================] - ETA: 0s - loss: 0.1026
# Epoch 23: val_loss improved from 0.06517 to 0.06027, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 346ms/step - loss: 0.1026 - val_loss: 0.0603
# Epoch 24/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0965
# Epoch 24: val_loss improved from 0.06027 to 0.05646, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 314ms/step - loss: 0.0965 - val_loss: 0.0565
# Epoch 25/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0746
# Epoch 25: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0746 - val_loss: 0.0606
# Epoch 26/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0806
# Epoch 26: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 138ms/step - loss: 0.0806 - val_loss: 0.0629
# Epoch 27/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0893
# Epoch 27: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 99ms/step - loss: 0.0893 - val_loss: 0.0647
# Epoch 28/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0885
# Epoch 28: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0885 - val_loss: 0.0644
# Epoch 29/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0723
# Epoch 29: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0723 - val_loss: 0.0618
# Epoch 30/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0741
# Epoch 30: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0741 - val_loss: 0.0599
# Epoch 31/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0745
# Epoch 31: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0745 - val_loss: 0.0607
# Epoch 32/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0748
# Epoch 32: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 143ms/step - loss: 0.0748 - val_loss: 0.0618
# Epoch 33/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0649
# Epoch 33: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0649 - val_loss: 0.0584
# Epoch 34/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0776
# Epoch 34: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0776 - val_loss: 0.0590
# Epoch 35/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 35: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0675 - val_loss: 0.0636
# Epoch 36/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0648
# Epoch 36: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0648 - val_loss: 0.0602
# Epoch 37/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0689
# Epoch 37: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0689 - val_loss: 0.0582
# Epoch 38/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0754
# Epoch 38: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 140ms/step - loss: 0.0754 - val_loss: 0.0592
# Epoch 39/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0679
# Epoch 39: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0679 - val_loss: 0.0596
# Epoch 40/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0689
# Epoch 40: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0689 - val_loss: 0.0573
# Epoch 41/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0550
# Epoch 41: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0550 - val_loss: 0.0565
# Epoch 42/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0612
# Epoch 42: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0612 - val_loss: 0.0577
# Epoch 43/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0641
# Epoch 43: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0641 - val_loss: 0.0576
# Epoch 44/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0621
# Epoch 44: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 142ms/step - loss: 0.0621 - val_loss: 0.0603
# Epoch 45/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0640
# Epoch 45: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0640 - val_loss: 0.0575
# Epoch 46/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0711
# Epoch 46: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0711 - val_loss: 0.0638
# Epoch 47/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0565
# Epoch 47: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0565 - val_loss: 0.0629
# Epoch 48/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0656
# Epoch 48: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0656 - val_loss: 0.0581
# Epoch 49/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0564
# Epoch 49: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0564 - val_loss: 0.0608
# Epoch 50/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0572
# Epoch 50: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 128ms/step - loss: 0.0572 - val_loss: 0.0598
# Epoch 51/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0607
# Epoch 51: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0607 - val_loss: 0.0591
# Epoch 52/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0642
# Epoch 52: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0642 - val_loss: 0.0606
# Epoch 53/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0717
# Epoch 53: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0717 - val_loss: 0.0596
# Epoch 54/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0681
# Epoch 54: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 112ms/step - loss: 0.0681 - val_loss: 0.0586
# Epoch 55/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0628
# Epoch 55: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 99ms/step - loss: 0.0628 - val_loss: 0.0591
# Epoch 56/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0569
# Epoch 56: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 119ms/step - loss: 0.0569 - val_loss: 0.0569
# Epoch 57/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0574
# Epoch 57: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 123ms/step - loss: 0.0574 - val_loss: 0.0567
# Epoch 58/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0514
# Epoch 58: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 110ms/step - loss: 0.0514 - val_loss: 0.0569
# Epoch 59/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 59: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0587 - val_loss: 0.0566
# Epoch 60/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0629
# Epoch 60: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0629 - val_loss: 0.0567
# Epoch 61/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0532
# Epoch 61: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0532 - val_loss: 0.0577
# Epoch 62/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0545
# Epoch 62: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0545 - val_loss: 0.0580
# Epoch 63/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 63: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 144ms/step - loss: 0.0491 - val_loss: 0.0577
# Epoch 64/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0513
# Epoch 64: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0513 - val_loss: 0.0572
# Epoch 65/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0498
# Epoch 65: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0498 - val_loss: 0.0568
# Epoch 66/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0586
# Epoch 66: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0586 - val_loss: 0.0570
# Epoch 67/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0501
# Epoch 67: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0501 - val_loss: 0.0568
# Epoch 68/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0561
# Epoch 68: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0561 - val_loss: 0.0570
# Epoch 69/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0518
# Epoch 69: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 143ms/step - loss: 0.0518 - val_loss: 0.0570
# Epoch 70/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0592
# Epoch 70: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0592 - val_loss: 0.0569
# Epoch 71/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0488
# Epoch 71: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0488 - val_loss: 0.0572
# Epoch 72/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0577
# Epoch 72: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0577 - val_loss: 0.0569
# Epoch 73/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0543
# Epoch 73: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0543 - val_loss: 0.0568
# Epoch 74/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0580
# Epoch 74: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0580 - val_loss: 0.0571
# Epoch 75/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0531
# Epoch 75: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 141ms/step - loss: 0.0531 - val_loss: 0.0568
# Epoch 76/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0505
# Epoch 76: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0505 - val_loss: 0.0566
# Epoch 77/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0520
# Epoch 77: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0520 - val_loss: 0.0567
# Epoch 78/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0553
# Epoch 78: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0553 - val_loss: 0.0570
# Epoch 79/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0515
# Epoch 79: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0515 - val_loss: 0.0570
# Epoch 80/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0591
# Epoch 80: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0591 - val_loss: 0.0568
# Epoch 81/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0510
# Epoch 81: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 134ms/step - loss: 0.0510 - val_loss: 0.0568
# Epoch 82/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0467
# Epoch 82: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 119ms/step - loss: 0.0467 - val_loss: 0.0569
# Epoch 83/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0545
# Epoch 83: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0545 - val_loss: 0.0569
# Epoch 84/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0543
# Epoch 84: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0543 - val_loss: 0.0568
# Epoch 85/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0538
# Epoch 85: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0538 - val_loss: 0.0566
# Epoch 86/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0541
# Epoch 86: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0541 - val_loss: 0.0569
# Epoch 87/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0516
# Epoch 87: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 120ms/step - loss: 0.0516 - val_loss: 0.0569
# Epoch 88/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0534
# Epoch 88: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 120ms/step - loss: 0.0534 - val_loss: 0.0569
# Epoch 89/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0520
# Epoch 89: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0520 - val_loss: 0.0569
# Epoch 90/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0524
# Epoch 90: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0524 - val_loss: 0.0570
# Epoch 91/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0578
# Epoch 91: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0578 - val_loss: 0.0569
# Epoch 92/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0529
# Epoch 92: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0529 - val_loss: 0.0567
# Epoch 93/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0521
# Epoch 93: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0521 - val_loss: 0.0567
# Epoch 94/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0599
# Epoch 94: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 135ms/step - loss: 0.0599 - val_loss: 0.0567
# Epoch 95/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0551
# Epoch 95: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0551 - val_loss: 0.0566
# Epoch 96/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0607
# Epoch 96: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0607 - val_loss: 0.0565
# Epoch 97/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0517
# Epoch 97: val_loss did not improve from 0.05646
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0517 - val_loss: 0.0565
# Epoch 98/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0508
# Epoch 98: val_loss improved from 0.05646 to 0.05644, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 337ms/step - loss: 0.0508 - val_loss: 0.0564
# Epoch 99/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0522
# Epoch 99: val_loss did not improve from 0.05644
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0522 - val_loss: 0.0565
# Epoch 100/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0497
# Epoch 100: val_loss improved from 0.05644 to 0.05635, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 308ms/step - loss: 0.0497 - val_loss: 0.0563
# Epoch 101/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0524
# Epoch 101: val_loss improved from 0.05635 to 0.05628, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 334ms/step - loss: 0.0524 - val_loss: 0.0563
# Epoch 102/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0451
# Epoch 102: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0451 - val_loss: 0.0563
# Epoch 103/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0503
# Epoch 103: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 98ms/step - loss: 0.0503 - val_loss: 0.0563
# Epoch 104/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0556
# Epoch 104: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0556 - val_loss: 0.0563
# Epoch 105/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0528
# Epoch 105: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0528 - val_loss: 0.0564
# Epoch 106/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0550
# Epoch 106: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0550 - val_loss: 0.0564
# Epoch 107/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0547
# Epoch 107: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 145ms/step - loss: 0.0547 - val_loss: 0.0564
# Epoch 108/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0553
# Epoch 108: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0553 - val_loss: 0.0577
# Epoch 109/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0530
# Epoch 109: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0530 - val_loss: 0.0590
# Epoch 110/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0548
# Epoch 110: val_loss did not improve from 0.05628
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0548 - val_loss: 0.0574
# Epoch 111/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0605
# Epoch 111: val_loss improved from 0.05628 to 0.05563, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 336ms/step - loss: 0.0605 - val_loss: 0.0556
# Epoch 112/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0527
# Epoch 112: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0527 - val_loss: 0.0562
# Epoch 113/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0488
# Epoch 113: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0488 - val_loss: 0.0561
# Epoch 114/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0506
# Epoch 114: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0506 - val_loss: 0.0560
# Epoch 115/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 115: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0491 - val_loss: 0.0561
# Epoch 116/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0543
# Epoch 116: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0543 - val_loss: 0.0561
# Epoch 117/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0530
# Epoch 117: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 123ms/step - loss: 0.0530 - val_loss: 0.0561
# Epoch 118/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0521
# Epoch 118: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 115ms/step - loss: 0.0521 - val_loss: 0.0559
# Epoch 119/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0555
# Epoch 119: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0555 - val_loss: 0.0560
# Epoch 120/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0521
# Epoch 120: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0521 - val_loss: 0.0561
# Epoch 121/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0481
# Epoch 121: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0481 - val_loss: 0.0561
# Epoch 122/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0566
# Epoch 122: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0566 - val_loss: 0.0561
# Epoch 123/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0451
# Epoch 123: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 114ms/step - loss: 0.0451 - val_loss: 0.0563
# Epoch 124/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 124: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 137ms/step - loss: 0.0478 - val_loss: 0.0563
# Epoch 125/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 125: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 113ms/step - loss: 0.0490 - val_loss: 0.0561
# Epoch 126/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0517
# Epoch 126: val_loss did not improve from 0.05563
# 17/17 [==============================] - 2s 99ms/step - loss: 0.0517 - val_loss: 0.0560
# Epoch 127/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0563
# Epoch 127: val_loss improved from 0.05563 to 0.05561, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 320ms/step - loss: 0.0563 - val_loss: 0.0556
# Epoch 128/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0512
# Epoch 128: val_loss improved from 0.05561 to 0.05524, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 355ms/step - loss: 0.0512 - val_loss: 0.0552
# Epoch 129/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0558
# Epoch 129: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0558 - val_loss: 0.0553
# Epoch 130/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0507
# Epoch 130: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0507 - val_loss: 0.0567
# Epoch 131/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0523
# Epoch 131: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 115ms/step - loss: 0.0523 - val_loss: 0.0567
# Epoch 132/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0629
# Epoch 132: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 147ms/step - loss: 0.0629 - val_loss: 0.0564
# Epoch 133/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0530
# Epoch 133: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0530 - val_loss: 0.0562
# Epoch 134/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0506
# Epoch 134: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0506 - val_loss: 0.0560
# Epoch 135/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0529
# Epoch 135: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0529 - val_loss: 0.0557
# Epoch 136/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0456
# Epoch 136: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0456 - val_loss: 0.0558
# Epoch 137/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 137: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0478 - val_loss: 0.0558
# Epoch 138/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 138: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 136ms/step - loss: 0.0490 - val_loss: 0.0561
# Epoch 139/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0482
# Epoch 139: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0482 - val_loss: 0.0555
# Epoch 140/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0547
# Epoch 140: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 102ms/step - loss: 0.0547 - val_loss: 0.0555
# Epoch 141/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 141: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0458 - val_loss: 0.0562
# Epoch 142/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0537
# Epoch 142: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 100ms/step - loss: 0.0537 - val_loss: 0.0577
# Epoch 143/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0523
# Epoch 143: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0523 - val_loss: 0.0568
# Epoch 144/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0459
# Epoch 144: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 123ms/step - loss: 0.0459 - val_loss: 0.0567
# Epoch 145/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0496
# Epoch 145: val_loss did not improve from 0.05524
# 17/17 [==============================] - 2s 121ms/step - loss: 0.0496 - val_loss: 0.0554
# Epoch 146/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0569
# Epoch 146: val_loss improved from 0.05524 to 0.05481, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 331ms/step - loss: 0.0569 - val_loss: 0.0548
# Epoch 147/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0516
# Epoch 147: val_loss improved from 0.05481 to 0.05471, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 338ms/step - loss: 0.0516 - val_loss: 0.0547
# Epoch 148/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0518
# Epoch 148: val_loss did not improve from 0.05471
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0518 - val_loss: 0.0549
# Epoch 149/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0494
# Epoch 149: val_loss did not improve from 0.05471
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0494 - val_loss: 0.0548
# Epoch 150/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0474
# Epoch 150: val_loss improved from 0.05471 to 0.05460, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 313ms/step - loss: 0.0474 - val_loss: 0.0546
# Epoch 151/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0513
# Epoch 151: val_loss did not improve from 0.05460
# 17/17 [==============================] - 2s 143ms/step - loss: 0.0513 - val_loss: 0.0548
# Epoch 152/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0496
# Epoch 152: val_loss improved from 0.05460 to 0.05454, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 317ms/step - loss: 0.0496 - val_loss: 0.0545
# Epoch 153/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0454
# Epoch 153: val_loss improved from 0.05454 to 0.05378, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 314ms/step - loss: 0.0454 - val_loss: 0.0538
# Epoch 154/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0539
# Epoch 154: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 124ms/step - loss: 0.0539 - val_loss: 0.0542
# Epoch 155/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0487
# Epoch 155: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0487 - val_loss: 0.0538
# Epoch 156/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0556
# Epoch 156: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0556 - val_loss: 0.0552
# Epoch 157/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0504
# Epoch 157: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0504 - val_loss: 0.0547
# Epoch 158/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 158: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0442 - val_loss: 0.0550
# Epoch 159/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0522
# Epoch 159: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0522 - val_loss: 0.0549
# Epoch 160/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0481
# Epoch 160: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 142ms/step - loss: 0.0481 - val_loss: 0.0552
# Epoch 161/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0477
# Epoch 161: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0477 - val_loss: 0.0547
# Epoch 162/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0483
# Epoch 162: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 101ms/step - loss: 0.0483 - val_loss: 0.0547
# Epoch 163/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0457
# Epoch 163: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0457 - val_loss: 0.0545
# Epoch 164/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0492
# Epoch 164: val_loss did not improve from 0.05378
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0492 - val_loss: 0.0539
# Epoch 165/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0472
# Epoch 165: val_loss improved from 0.05378 to 0.05367, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 347ms/step - loss: 0.0472 - val_loss: 0.0537
# Epoch 166/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0471
# Epoch 166: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0471 - val_loss: 0.0541
# Epoch 167/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 167: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0452 - val_loss: 0.0543
# Epoch 168/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0466
# Epoch 168: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0466 - val_loss: 0.0541
# Epoch 169/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0498
# Epoch 169: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0498 - val_loss: 0.0541
# Epoch 170/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0426
# Epoch 170: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 149ms/step - loss: 0.0426 - val_loss: 0.0541
# Epoch 171/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0493
# Epoch 171: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0493 - val_loss: 0.0549
# Epoch 172/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 172: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0458 - val_loss: 0.0551
# Epoch 173/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0422
# Epoch 173: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0422 - val_loss: 0.0567
# Epoch 174/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0482
# Epoch 174: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0482 - val_loss: 0.0553
# Epoch 175/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 175: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0452 - val_loss: 0.0551
# Epoch 176/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0432
# Epoch 176: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 142ms/step - loss: 0.0432 - val_loss: 0.0552
# Epoch 177/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0482
# Epoch 177: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0482 - val_loss: 0.0540
# Epoch 178/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0464
# Epoch 178: val_loss did not improve from 0.05367
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0464 - val_loss: 0.0541
# Epoch 179/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0430
# Epoch 179: val_loss improved from 0.05367 to 0.05365, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 329ms/step - loss: 0.0430 - val_loss: 0.0536
# Epoch 180/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0425
# Epoch 180: val_loss did not improve from 0.05365
# 17/17 [==============================] - 2s 130ms/step - loss: 0.0425 - val_loss: 0.0550
# Epoch 181/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0485
# Epoch 181: val_loss did not improve from 0.05365
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0485 - val_loss: 0.0540
# Epoch 182/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0470
# Epoch 182: val_loss did not improve from 0.05365
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0470 - val_loss: 0.0553
# Epoch 183/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0479
# Epoch 183: val_loss did not improve from 0.05365
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0479 - val_loss: 0.0561
# Epoch 184/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0415
# Epoch 184: val_loss did not improve from 0.05365
# 17/17 [==============================] - 2s 114ms/step - loss: 0.0415 - val_loss: 0.0564
# Epoch 185/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0464
# Epoch 185: val_loss improved from 0.05365 to 0.05349, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 356ms/step - loss: 0.0464 - val_loss: 0.0535
# Epoch 186/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 186: val_loss did not improve from 0.05349
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0462 - val_loss: 0.0552
# Epoch 187/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0493
# Epoch 187: val_loss did not improve from 0.05349
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0493 - val_loss: 0.0558
# Epoch 188/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 188: val_loss did not improve from 0.05349
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0419 - val_loss: 0.0539
# Epoch 189/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 189: val_loss did not improve from 0.05349
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0438 - val_loss: 0.0575
# Epoch 190/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0372
# Epoch 190: val_loss did not improve from 0.05349
# 17/17 [==============================] - 2s 129ms/step - loss: 0.0372 - val_loss: 0.0548
# Epoch 191/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0381
# Epoch 191: val_loss improved from 0.05349 to 0.05316, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 343ms/step - loss: 0.0381 - val_loss: 0.0532
# Epoch 192/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 192: val_loss did not improve from 0.05316
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0452 - val_loss: 0.0547
# Epoch 193/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 193: val_loss did not improve from 0.05316
# 17/17 [==============================] - 2s 114ms/step - loss: 0.0452 - val_loss: 0.0534
# Epoch 194/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0438
# Epoch 194: val_loss did not improve from 0.05316
# 17/17 [==============================] - 2s 128ms/step - loss: 0.0438 - val_loss: 0.0561
# Epoch 195/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0376
# Epoch 195: val_loss did not improve from 0.05316
# 17/17 [==============================] - 2s 118ms/step - loss: 0.0376 - val_loss: 0.0551
# Epoch 196/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0429
# Epoch 196: val_loss did not improve from 0.05316
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0429 - val_loss: 0.0538
# Epoch 197/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 197: val_loss improved from 0.05316 to 0.05315, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 325ms/step - loss: 0.0383 - val_loss: 0.0532
# Epoch 198/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0378
# Epoch 198: val_loss improved from 0.05315 to 0.05314, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 348ms/step - loss: 0.0378 - val_loss: 0.0531
# Epoch 199/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0365
# Epoch 199: val_loss did not improve from 0.05314
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0365 - val_loss: 0.0563
# Epoch 200/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0371
# Epoch 200: val_loss did not improve from 0.05314
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0371 - val_loss: 0.0578
# Epoch 201/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0398
# Epoch 201: val_loss did not improve from 0.05314
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0398 - val_loss: 0.0565
# Epoch 202/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0336
# Epoch 202: val_loss did not improve from 0.05314
# 17/17 [==============================] - 2s 116ms/step - loss: 0.0336 - val_loss: 0.0553
# Epoch 203/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0410
# Epoch 203: val_loss did not improve from 0.05314
# 17/17 [==============================] - 2s 140ms/step - loss: 0.0410 - val_loss: 0.0552
# Epoch 204/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0475
# Epoch 204: val_loss did not improve from 0.05314
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0475 - val_loss: 0.0534
# Epoch 205/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0452
# Epoch 205: val_loss improved from 0.05314 to 0.04909, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 328ms/step - loss: 0.0452 - val_loss: 0.0491
# Epoch 206/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0397
# Epoch 206: val_loss improved from 0.04909 to 0.04848, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 6s 341ms/step - loss: 0.0397 - val_loss: 0.0485
# Epoch 207/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0393
# Epoch 207: val_loss improved from 0.04848 to 0.04617, saving model to /content/drive/My Drive/new_kimore/modelEX3.h5
# 17/17 [==============================] - 5s 317ms/step - loss: 0.0393 - val_loss: 0.0462
# Epoch 208/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0320
# Epoch 208: val_loss did not improve from 0.04617
# 17/17 [==============================] - 2s 115ms/step - loss: 0.0320 - val_loss: 0.0525
# Epoch 209/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0321
# Epoch 209: val_loss did not improve from 0.04617
# 17/17 [==============================] - 2s 140ms/step - loss: 0.0321 - val_loss: 0.0504
# Epoch 210/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0355
# Epoch 210: val_loss did not improve from 0.04617
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0355 - val_loss: 0.0565
# Epoch 211/400
# ...
# 17/17 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 327: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0073 - val_loss: 0.0527
# Epoch 328/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 328: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0087 - val_loss: 0.0536
# Epoch 329/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 329: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0068 - val_loss: 0.0552
# Epoch 330/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 330: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0089 - val_loss: 0.0551
# Epoch 331/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 331: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0095 - val_loss: 0.0559
# Epoch 332/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 332: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 147ms/step - loss: 0.0123 - val_loss: 0.0595
# Epoch 333/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 333: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0148 - val_loss: 0.0609
# Epoch 334/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 334: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0114 - val_loss: 0.0616
# Epoch 335/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 335: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 110ms/step - loss: 0.0109 - val_loss: 0.0552
# Epoch 336/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 336: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0088 - val_loss: 0.0534
# Epoch 337/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 337: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0100 - val_loss: 0.0530
# Epoch 338/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 338: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 147ms/step - loss: 0.0080 - val_loss: 0.0542
# Epoch 339/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 339: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0093 - val_loss: 0.0571
# Epoch 340/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 340: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0080 - val_loss: 0.0544
# Epoch 341/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 341: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 110ms/step - loss: 0.0078 - val_loss: 0.0542
# Epoch 342/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 342: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0083 - val_loss: 0.0507
# Epoch 343/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 343: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0072 - val_loss: 0.0551
# Epoch 344/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 344: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 150ms/step - loss: 0.0072 - val_loss: 0.0532
# Epoch 345/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 345: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0065 - val_loss: 0.0536
# Epoch 346/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 346: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0070 - val_loss: 0.0542
# Epoch 347/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 347: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0075 - val_loss: 0.0541
# Epoch 348/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 348: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0064 - val_loss: 0.0549
# Epoch 349/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 349: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0082 - val_loss: 0.0555
# Epoch 350/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 350: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 146ms/step - loss: 0.0074 - val_loss: 0.0570
# Epoch 351/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 351: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0084 - val_loss: 0.0564
# Epoch 352/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 352: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 111ms/step - loss: 0.0107 - val_loss: 0.0501
# Epoch 353/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 353: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 117ms/step - loss: 0.0082 - val_loss: 0.0536
# Epoch 354/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 354: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0086 - val_loss: 0.0539
# Epoch 355/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 355: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0109 - val_loss: 0.0524
# Epoch 356/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 356: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 146ms/step - loss: 0.0112 - val_loss: 0.0558
# Epoch 357/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 357: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0072 - val_loss: 0.0585
# Epoch 358/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 358: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0098 - val_loss: 0.0573
# Epoch 359/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 359: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0066 - val_loss: 0.0547
# Epoch 360/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 360: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 110ms/step - loss: 0.0071 - val_loss: 0.0546
# Epoch 361/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 361: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0089 - val_loss: 0.0558
# Epoch 362/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 362: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 148ms/step - loss: 0.0064 - val_loss: 0.0562
# Epoch 363/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 363: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 118ms/step - loss: 0.0048 - val_loss: 0.0547
# Epoch 364/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 364: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 110ms/step - loss: 0.0062 - val_loss: 0.0546
# Epoch 365/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 365: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0083 - val_loss: 0.0545
# Epoch 366/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 366: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0114 - val_loss: 0.0552
# Epoch 367/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 367: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0133 - val_loss: 0.0588
# Epoch 368/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 368: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 149ms/step - loss: 0.0050 - val_loss: 0.0583
# Epoch 369/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 369: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0098 - val_loss: 0.0567
# Epoch 370/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 370: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0086 - val_loss: 0.0518
# Epoch 371/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 371: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0073 - val_loss: 0.0555
# Epoch 372/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 372: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0084 - val_loss: 0.0536
# Epoch 373/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 373: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0093 - val_loss: 0.0530
# Epoch 374/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 374: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 147ms/step - loss: 0.0057 - val_loss: 0.0532
# Epoch 375/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 375: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0072 - val_loss: 0.0526
# Epoch 376/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 376: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0078 - val_loss: 0.0557
# Epoch 377/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 377: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0067 - val_loss: 0.0527
# Epoch 378/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 378: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0086 - val_loss: 0.0541
# Epoch 379/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 379: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0070 - val_loss: 0.0562
# Epoch 380/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 380: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 149ms/step - loss: 0.0065 - val_loss: 0.0562
# Epoch 381/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 381: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0080 - val_loss: 0.0548
# Epoch 382/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 382: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0075 - val_loss: 0.0553
# Epoch 383/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 383: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 109ms/step - loss: 0.0099 - val_loss: 0.0531
# Epoch 384/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 384: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0087 - val_loss: 0.0513
# Epoch 385/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 385: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0078 - val_loss: 0.0506
# Epoch 386/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 386: val_loss did not improve from 0.04086
# 17/17 [==============================] - 3s 156ms/step - loss: 0.0063 - val_loss: 0.0538
# Epoch 387/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 387: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 106ms/step - loss: 0.0057 - val_loss: 0.0530
# Epoch 388/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 388: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 103ms/step - loss: 0.0066 - val_loss: 0.0533
# Epoch 389/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 389: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0084 - val_loss: 0.0535
# Epoch 390/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 390: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 110ms/step - loss: 0.0094 - val_loss: 0.0531
# Epoch 391/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 391: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 105ms/step - loss: 0.0082 - val_loss: 0.0512
# Epoch 392/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 392: val_loss did not improve from 0.04086
# 17/17 [==============================] - 3s 152ms/step - loss: 0.0079 - val_loss: 0.0560
# Epoch 393/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 393: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0079 - val_loss: 0.0546
# Epoch 394/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 394: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 104ms/step - loss: 0.0078 - val_loss: 0.0512
# Epoch 395/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 395: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0057 - val_loss: 0.0535
# Epoch 396/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 396: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 108ms/step - loss: 0.0081 - val_loss: 0.0537
# Epoch 397/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 397: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0076 - val_loss: 0.0536
# Epoch 398/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 398: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 149ms/step - loss: 0.0055 - val_loss: 0.0528
# Epoch 399/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 399: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0076 - val_loss: 0.0531
# Epoch 400/400
# 17/17 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 400: val_loss did not improve from 0.04086
# 17/17 [==============================] - 2s 107ms/step - loss: 0.0065 - val_loss: 0.0528
# Training time: 0:18:19.700310

# %%
print(tracemalloc.get_traced_memory())
# stopping the library
tracemalloc.stop()
# Out:
# (134126156, 135666886)

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.004843481350690126
# Validation loss 0.04085525870323181

# %%
# Plot the prediction of the model for the training and validation sets
import tensorflow as tf
from keras.models import load_model
from keras.initializers import glorot_uniform
# Load the best model's weights
best_model = load_model('/content/drive/My Drive/new_kimore/modelEX3.h5', custom_objects={'TCN': TCN, 'GlorotUniform': glorot_uniform()})

pred_train = model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.1,1.1])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(valid_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.1,1.1])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()

plt.show()
# Out:
# 4/4 [==============================] - 9s 48ms/step
# 2/2 [==============================] - 0s 26ms/step

# %%
test_dev = abs(np.squeeze(pred_test)-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
#MSE
MSE=mean_squared_error(pred_test, test_y)
#MAPE
#P1 = 19*pred_test + 31;
#P2 = 19*test_y+31;
MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
print('MSE:',MSE)
rms_dev = np.sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
print('MAPE:',MAPE)
# Out:
# MSE: 0.03799610654096702
# Mean absolute deviation: 0.2091704789521808
# RMS deviation: 0.19492590012865665
# MAPE: inf
