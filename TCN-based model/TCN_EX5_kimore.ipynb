# %%
pip install keras-tcn
# Out:
# Requirement already satisfied: keras-tcn in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences
timesteps = 104
# dimension of data sequences
n_dim = 80
batch_size = 2

# %%
drive.mount('/content/drive')
dir_name_samples ='/content/drive/My Drive/new_kimore/Preprocessed_data/Exercise5_data.csv'
dir_name_labels ='/content/drive/My Drive/new_kimore/Preprocessed_data/Labels_ex5.csv'
import warnings
warnings.filterwarnings("ignore")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_values = pd.read_csv(dir_name_samples, delimiter=',', encoding='utf-8')
print(X_values.shape)
# # Initialize the MinMaxScaler

# scaler = StandardScaler()
# # Fit and transform the data using the scaler
# scaled_data = scaler.fit_transform(X_values)

# # Create a new DataFrame with the scaled data
# scaled_df = pd.DataFrame(scaled_data, columns=X_values.columns)


# # Extract the underlying NumPy array
# numpy_2d_array = scaled_df.values
# #numpy_2d_array = X_values.values
# # Reshape the 2D array into a 3D array (207, 100, 80)
# X_train = numpy_2d_array.reshape(207, 100, 80)
# # The temporal pyramid requires that the length of the data sequences is divisible by 8.
# # The original length was 100 time steps, so we will repeat the first and last 2 data vectors to obtain sequences with 104 time steps
# X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
numpy_2d_array = X_values.values
X_train = numpy_2d_array.reshape(207, 100, 80)

# Calculate the mean along the specified axes (axis=0, axis=1, and axis=2) to obtain a mean value for the entire array
mean_value = X_train.mean(axis=(0, 1, 2))

# Subtract the mean from the entire array to achieve zero mean
X_train -= mean_value

# Calculate the maximum and minimum values in the array
max_value = X_train.max()
min_value = X_train.min()

# Normalize the array to a range between -1 and 1
data = 2 * (X_train - min_value) / (max_value - min_value) - 1
smoothed_data = np.empty_like(X_train)
for channel in range(80):
    smoothed_data[:, :, channel] = gaussian_filter1d(data[:, :, channel], sigma=5)
X_train=smoothed_data
X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
#-----------labels------------------------------------
Y_values = pd.read_csv(dir_name_labels)
#change the secon column to the labels
y_values= Y_values['EX5'].values

reshaped_data_y = y_values.reshape(207, 1)
# Fit and transform the data using the scaler
#scaler2 = MinMaxScaler(feature_range=(-1, 1))
#y_train = scaler2.fit_transform(reshaped_data_y)
min_value = np.min(reshaped_data_y)
max_value = np.max(reshaped_data_y)

# Normalize the vector to be in the range [-1, 1]
y_train = (reshaped_data_y - min_value) / (max_value - min_value)

print('Training sequences dimension', X_train.shape)
print('Training labels dimension', y_train)
# Out:
# (20700, 80)
# Training sequences dimension (207, 104, 80)
# Training labels dimension [[0.95535714]
#  [0.95535714]
#  [0.95535714]
#  [0.80357143]
#  [0.80357143]
#  [0.80357143]
#  [0.72321429]
#  [0.72321429]
#  [0.72321429]
#  [0.8125    ]
#  [0.8125    ]
#  [0.8125    ]
#  [0.77678571]
#  [0.77678571]
#  [0.77678571]
#  [0.33035714]
#  [0.33035714]
#  [0.33035714]
#  [0.67857143]
#  [0.67857143]
#  [0.67857143]
#  [0.8125    ]
#  [0.8125    ]
#  [0.8125    ]
#  [0.36607143]
#  [0.36607143]
#  [0.36607143]
#  [0.1875    ]
#  [0.1875    ]
#  [0.1875    ]
#  [0.82142857]
#  [0.82142857]
#  [0.82142857]
#  [0.6875    ]
#  [0.6875    ]
#  [0.6875    ]
#  [0.84821429]
#  [0.84821429]
#  [0.84821429]
#  [0.23214286]
#  [0.23214286]
#  [0.23214286]
#  [0.54464286]
#  [0.54464286]
#  [0.54464286]
#  [0.70535714]
#  [0.70535714]
#  [0.70535714]
#  [0.78571429]
#  [0.78571429]
#  [0.78571429]
#  [0.70535714]
#  [0.70535714]
#  [0.70535714]
#  [0.41071429]
#  [0.41071429]
#  [0.41071429]
#  [0.89285714]
#  [0.89285714]
#  [0.89285714]
#  [0.85714286]
#  [0.85714286]
#  [0.85714286]
#  [0.67857143]
#  [0.67857143]
#  [0.67857143]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.86607143]
#  [0.86607143]
#  [0.86607143]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.8125    ]
#  [0.8125    ]
#  [0.8125    ]
#  [0.86607143]
#  [0.86607143]
#  [0.86607143]
#  [0.97321429]
#  [0.97321429]
#  [0.97321429]
#  [0.82142857]
#  [0.82142857]
#  [0.82142857]
#  [0.86607143]
#  [0.86607143]
#  [0.86607143]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.8125    ]
#  [0.8125    ]
#  [0.8125    ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.25      ]
#  [0.25      ]
#  [0.25      ]
#  [0.625     ]
#  [0.625     ]
#  [0.625     ]
#  [0.09587108]
#  [0.09587108]
#  [0.09587108]
#  [0.52102907]
#  [0.52102907]
#  [0.52102907]
#  [0.82142857]
#  [0.82142857]
#  [0.82142857]
#  [0.9375    ]
#  [0.9375    ]
#  [0.9375    ]
#  [0.65178571]
#  [0.65178571]
#  [0.65178571]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [0.83928571]
#  [0.83928571]
#  [0.83928571]
#  [0.625     ]
#  [0.625     ]
#  [0.625     ]
#  [0.11607143]
#  [0.11607143]
#  [0.11607143]
#  [0.65178571]
#  [0.65178571]
#  [0.65178571]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.41964286]
#  [0.41964286]
#  [0.41964286]
#  [0.51785714]
#  [0.51785714]
#  [0.51785714]
#  [0.67857143]
#  [0.67857143]
#  [0.67857143]
#  [0.50566792]
#  [0.50566792]
#  [0.50566792]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.30357143]
#  [0.30357143]
#  [0.30357143]
#  [0.23214286]
#  [0.23214286]
#  [0.23214286]
#  [0.64285714]
#  [0.64285714]
#  [0.64285714]
#  [0.625     ]
#  [0.625     ]
#  [0.625     ]
#  [0.57142857]
#  [0.57142857]
#  [0.57142857]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [0.19642857]
#  [0.19642857]
#  [0.19642857]
#  [0.41071429]
#  [0.41071429]
#  [0.41071429]
#  [0.41071429]
#  [0.41071429]
#  [0.41071429]
#  [0.61904384]
#  [0.61904384]
#  [0.61904384]
#  [0.52678571]
#  [0.52678571]
#  [0.52678571]
#  [0.33928571]
#  [0.33928571]
#  [0.33928571]
#  [0.60714286]
#  [0.60714286]
#  [0.60714286]
#  [0.1875    ]
#  [0.1875    ]
#  [0.1875    ]
#  [0.89285714]
#  [0.89285714]
#  [0.89285714]]

# %%
print(min(reshaped_data_y))
# Out:
# [12.66666667]

# %%
# # Identify positive and negative samples
# positive_indices = np.where(y_train >= 0)[0]
# negative_indices = np.where(y_train < 0)[0]

# # Determine the number of samples for training, testing, and validation
# num_samples = min(len(positive_indices), len(negative_indices))
# num_train = int(0.6 * num_samples)  # 60% for training
# num_test = int(0.2 * num_samples)  # 20% for testing
# num_val = num_samples - num_train - num_test  # Remaining for validation

# # Shuffle the indices for each label
# np.random.shuffle(positive_indices)
# np.random.shuffle(negative_indices)

# # Split the data into training, testing, and validation
# train_indices = np.concatenate((positive_indices[:num_train], negative_indices[:num_train]))
# test_indices = np.concatenate((positive_indices[num_train:num_train + num_test], negative_indices[num_train:num_train + num_test]))
# val_indices = np.concatenate((positive_indices[num_train + num_test:], negative_indices[num_train + num_test:]))

# train_x = X_train[val_indices]
# train_y = y_train[val_indices]
# valid_x = X_train[test_indices]
# valid_y = y_train[test_indices]
# test_x = X_train[train_indices]
# test_y = y_train[train_indices]

# %%
# original_data = X_train

# # Determine the number of duplicates you want
# num_duplicates = 207  # You want to double the size

# # Initialize an array to store the duplicated data
# duplicated_data = np.empty((num_duplicates, 104, 80))

# # Add random noise to each sample and duplicate it
# for i in range(num_duplicates):
#     noise = np.random.normal(0, 0.1, (104, 80))  # Adjust the noise level as needed
#     duplicated_data[i, :, :] = original_data[i, :, :] + noise

# # Concatenate the original data and duplicated data
# final_data = np.concatenate((original_data, duplicated_data), axis=0)
# X_train=final_data

# %%
# # Duplicate the array by concatenating it to itself
# y_train = np.concatenate([y_train, y_train], axis=0)
# print(y_train.shape)
# print(X_train.shape)

# %%
# Split your dataset into a training set (60%) and a combined validation-testing set (40%)
train_x, X_val_test, train_y, y_val_test = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

# Split the combined validation-testing set (40%) into a validation set (20%) and a test set (20%)
valid_x, test_x, valid_y, test_y = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# Now, you have X_train, y_train for training (60%), X_val, y_val for validation (20%), and X_test, y_test for testing (20%)
print('Training data', train_x.shape)
print('Validation data', valid_x.shape)
print('Training label', train_y.shape)
print('Validation label', valid_y.shape)
# Out:
# Training data (124, 104, 80)
# Validation data (41, 104, 80)
# Training label (124, 1)
# Validation label (41, 1)

# %%
# Plot the first and last sequences in the training and validation data
plt.figure(figsize = (14,8))
plt.subplot(2,2,1)
plt.plot(train_x[0])
plt.subplot(2,2,2)
plt.plot(train_x[-1])
plt.subplot(2,2,3)
plt.plot(valid_x[0])
plt.subplot(2,2,4)
plt.plot(valid_x[-1])
plt.tight_layout()
plt.show()

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)
trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)
trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)
trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]
trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]
trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
trainx =  train_x
validx =  valid_x
testx =  test_x

# %%
import matplotlib.patches as mpatches
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(trainx[0,:,0:16], color='red')
plt.plot(trainx[0,:,16:32], color='blue')
plt.plot(trainx[0,:,32:48], color='green')
plt.plot(trainx[0,:,48:64], color='orange')
plt.plot(trainx[0,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('First Train Sequence')
plt.subplot(1,2,2)
plt.plot(trainx[-1,:,0:16], color='red')
plt.plot(trainx[-1,:,16:32], color='blue')
plt.plot(trainx[-1,:,32:48], color='green')
plt.plot(trainx[-1,:,48:64], color='orange')
plt.plot(trainx[-1,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('Last Train Sequence')
plt.tight_layout()
plt.show()

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
n_dim = 80 # dimension after reordering the data into body parts
n_dim1 = 16 # dimension of indiviudal body parts
n_dim2 = 16
n_dim3 = 16 # legs dimension
# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps,n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 16:32])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 32:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:64])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 64:80])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 16:32])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 32:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:64])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 64:80])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 16:32])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 32:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:64])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 64:80])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 16:32])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 32:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:64])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.005,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'tanh')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 104, 80)]            0         []
#
#  half_scale (InputLayer)     [(None, 52, 80)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 26, 80)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 13, 80)]             0         []
#
#  lambda (Lambda)             (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_5 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_10 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_15 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_1 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_6 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_11 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_16 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_2 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_7 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_12 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_17 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_3 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_8 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_13 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_18 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_4 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_9 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_14 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_19 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  tcn (TCN)                   (None, 104, 12)              5676      ['lambda[0][0]']
#
#  tcn_1 (TCN)                 (None, 52, 12)               5676      ['lambda_5[0][0]']
#
#  tcn_2 (TCN)                 (None, 26, 12)               5676      ['lambda_10[0][0]']
#
#  tcn_3 (TCN)                 (None, 13, 12)               5676      ['lambda_15[0][0]']
#
#  tcn_4 (TCN)                 (None, 104, 12)              5676      ['lambda_1[0][0]']
#
#  tcn_5 (TCN)                 (None, 52, 12)               5676      ['lambda_6[0][0]']
#
#  tcn_6 (TCN)                 (None, 26, 12)               5676      ['lambda_11[0][0]']
#
#  tcn_7 (TCN)                 (None, 13, 12)               5676      ['lambda_16[0][0]']
#
#  tcn_8 (TCN)                 (None, 104, 12)              5676      ['lambda_2[0][0]']
#
#  tcn_9 (TCN)                 (None, 52, 12)               5676      ['lambda_7[0][0]']
#
#  tcn_10 (TCN)                (None, 26, 12)               5676      ['lambda_12[0][0]']
#
#  tcn_11 (TCN)                (None, 13, 12)               5676      ['lambda_17[0][0]']
#
#  tcn_12 (TCN)                (None, 104, 12)              5676      ['lambda_3[0][0]']
#
#  tcn_13 (TCN)                (None, 52, 12)               5676      ['lambda_8[0][0]']
#
#  tcn_14 (TCN)                (None, 26, 12)               5676      ['lambda_13[0][0]']
#
#  tcn_15 (TCN)                (None, 13, 12)               5676      ['lambda_18[0][0]']
#
#  tcn_16 (TCN)                (None, 104, 12)              5676      ['lambda_4[0][0]']
#
#  tcn_17 (TCN)                (None, 52, 12)               5676      ['lambda_9[0][0]']
#
#  tcn_18 (TCN)                (None, 26, 12)               5676      ['lambda_14[0][0]']
#
#  tcn_19 (TCN)                (None, 13, 12)               5676      ['lambda_19[0][0]']
#
#  concatenate (Concatenate)   (None, 195, 12)              0         ['tcn[0][0]',
#                                                                      'tcn_1[0][0]',
#                                                                      'tcn_2[0][0]',
#                                                                      'tcn_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 195, 12)              0         ['tcn_4[0][0]',
#  )                                                                   'tcn_5[0][0]',
#                                                                      'tcn_6[0][0]',
#                                                                      'tcn_7[0][0]']
#
#  concatenate_2 (Concatenate  (None, 195, 12)              0         ['tcn_8[0][0]',
#  )                                                                   'tcn_9[0][0]',
#                                                                      'tcn_10[0][0]',
#                                                                      'tcn_11[0][0]']
#
#  concatenate_3 (Concatenate  (None, 195, 12)              0         ['tcn_12[0][0]',
#  )                                                                   'tcn_13[0][0]',
#                                                                      'tcn_14[0][0]',
#                                                                      'tcn_15[0][0]']
#
#  concatenate_4 (Concatenate  (None, 195, 12)              0         ['tcn_16[0][0]',
#  )                                                                   'tcn_17[0][0]',
#                                                                      'tcn_18[0][0]',
#                                                                      'tcn_19[0][0]']
#
#  concatenate_5 (Concatenate  (None, 195, 60)              0         ['concatenate[0][0]',
#  )                                                                   'concatenate_1[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'concatenate_4[0][0]']
#
#  tcn_20 (TCN)                (None, 195, 12)              6012      ['concatenate_5[0][0]']
#
#  tcn_21 (TCN)                (None, 195, 8)               1176      ['tcn_20[0][0]']
#
#  tcn_22 (TCN)                (None, 6)                    546       ['tcn_21[0][0]']
#
#  dense (Dense)               (None, 1)                    7         ['tcn_22[0][0]']
#
# ==================================================================================================
# Total params: 121261 (473.68 KB)
# Trainable params: 121165 (473.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX5.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1813
# Epoch 1: val_loss improved from inf to 0.18012, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 169s 1s/step - loss: 0.1813 - val_loss: 0.1801
# Epoch 2/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1853
# Epoch 2: val_loss improved from 0.18012 to 0.18012, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 279ms/step - loss: 0.1853 - val_loss: 0.1801
# Epoch 3/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1838
# Epoch 3: val_loss improved from 0.18012 to 0.18011, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 307ms/step - loss: 0.1838 - val_loss: 0.1801
# Epoch 4/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1908
# Epoch 4: val_loss improved from 0.18011 to 0.17967, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 280ms/step - loss: 0.1908 - val_loss: 0.1797
# Epoch 5/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1854
# Epoch 5: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 95ms/step - loss: 0.1854 - val_loss: 0.1838
# Epoch 6/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1787
# Epoch 6: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 136ms/step - loss: 0.1787 - val_loss: 0.1895
# Epoch 7/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1862
# Epoch 7: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 97ms/step - loss: 0.1862 - val_loss: 0.1800
# Epoch 8/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1853
# Epoch 8: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 95ms/step - loss: 0.1853 - val_loss: 0.1800
# Epoch 9/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1857
# Epoch 9: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 97ms/step - loss: 0.1857 - val_loss: 0.1801
# Epoch 10/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1861
# Epoch 10: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 96ms/step - loss: 0.1861 - val_loss: 0.1801
# Epoch 11/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1848
# Epoch 11: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 96ms/step - loss: 0.1848 - val_loss: 0.1801
# Epoch 12/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1886
# Epoch 12: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 109ms/step - loss: 0.1886 - val_loss: 0.1801
# Epoch 13/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1854
# Epoch 13: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 118ms/step - loss: 0.1854 - val_loss: 0.1801
# Epoch 14/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1849
# Epoch 14: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 94ms/step - loss: 0.1849 - val_loss: 0.1801
# Epoch 15/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1836
# Epoch 15: val_loss did not improve from 0.17967
# 18/18 [==============================] - 2s 95ms/step - loss: 0.1836 - val_loss: 0.1799
# Epoch 16/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1839
# Epoch 16: val_loss improved from 0.17967 to 0.17919, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 305ms/step - loss: 0.1839 - val_loss: 0.1792
# Epoch 17/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1700
# Epoch 17: val_loss improved from 0.17919 to 0.15884, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 6s 325ms/step - loss: 0.1700 - val_loss: 0.1588
# Epoch 18/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1467
# Epoch 18: val_loss improved from 0.15884 to 0.10637, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 288ms/step - loss: 0.1467 - val_loss: 0.1064
# Epoch 19/400
# 18/18 [==============================] - ETA: 0s - loss: 0.1070
# Epoch 19: val_loss improved from 0.10637 to 0.07648, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 6s 323ms/step - loss: 0.1070 - val_loss: 0.0765
# Epoch 20/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0761
# Epoch 20: val_loss did not improve from 0.07648
# 18/18 [==============================] - 2s 107ms/step - loss: 0.0761 - val_loss: 0.1073
# Epoch 21/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0718
# Epoch 21: val_loss did not improve from 0.07648
# 18/18 [==============================] - 2s 107ms/step - loss: 0.0718 - val_loss: 0.0927
# Epoch 22/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0772
# Epoch 22: val_loss did not improve from 0.07648
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0772 - val_loss: 0.0917
# Epoch 23/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0631
# Epoch 23: val_loss did not improve from 0.07648
# 18/18 [==============================] - 2s 123ms/step - loss: 0.0631 - val_loss: 0.0893
# Epoch 24/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0751
# Epoch 24: val_loss did not improve from 0.07648
# 18/18 [==============================] - 2s 110ms/step - loss: 0.0751 - val_loss: 0.0777
# Epoch 25/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0758
# Epoch 25: val_loss improved from 0.07648 to 0.07304, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 307ms/step - loss: 0.0758 - val_loss: 0.0730
# Epoch 26/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0862
# Epoch 26: val_loss did not improve from 0.07304
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0862 - val_loss: 0.0892
# Epoch 27/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0722
# Epoch 27: val_loss improved from 0.07304 to 0.06609, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 307ms/step - loss: 0.0722 - val_loss: 0.0661
# Epoch 28/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0729
# Epoch 28: val_loss did not improve from 0.06609
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0729 - val_loss: 0.0701
# Epoch 29/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0744
# Epoch 29: val_loss improved from 0.06609 to 0.06519, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 283ms/step - loss: 0.0744 - val_loss: 0.0652
# Epoch 30/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0686
# Epoch 30: val_loss improved from 0.06519 to 0.06438, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 313ms/step - loss: 0.0686 - val_loss: 0.0644
# Epoch 31/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0744
# Epoch 31: val_loss improved from 0.06438 to 0.06405, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 282ms/step - loss: 0.0744 - val_loss: 0.0640
# Epoch 32/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0700
# Epoch 32: val_loss improved from 0.06405 to 0.06287, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 299ms/step - loss: 0.0700 - val_loss: 0.0629
# Epoch 33/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0722
# Epoch 33: val_loss did not improve from 0.06287
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0722 - val_loss: 0.0630
# Epoch 34/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0692
# Epoch 34: val_loss did not improve from 0.06287
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0692 - val_loss: 0.0629
# Epoch 35/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0604
# Epoch 35: val_loss did not improve from 0.06287
# 18/18 [==============================] - 2s 105ms/step - loss: 0.0604 - val_loss: 0.0634
# Epoch 36/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0589
# Epoch 36: val_loss improved from 0.06287 to 0.06264, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 306ms/step - loss: 0.0589 - val_loss: 0.0626
# Epoch 37/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0657
# Epoch 37: val_loss did not improve from 0.06264
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0657 - val_loss: 0.0635
# Epoch 38/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0578
# Epoch 38: val_loss did not improve from 0.06264
# 18/18 [==============================] - 2s 109ms/step - loss: 0.0578 - val_loss: 0.0654
# Epoch 39/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0653
# Epoch 39: val_loss did not improve from 0.06264
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0653 - val_loss: 0.0663
# Epoch 40/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0490
# Epoch 40: val_loss did not improve from 0.06264
# 18/18 [==============================] - 2s 104ms/step - loss: 0.0490 - val_loss: 0.0690
# Epoch 41/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0357
# Epoch 41: val_loss did not improve from 0.06264
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0357 - val_loss: 0.0738
# Epoch 42/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0515
# Epoch 42: val_loss did not improve from 0.06264
# 18/18 [==============================] - 2s 124ms/step - loss: 0.0515 - val_loss: 0.0702
# Epoch 43/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0542
# Epoch 43: val_loss did not improve from 0.06264
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0542 - val_loss: 0.0632
# Epoch 44/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0424
# Epoch 44: val_loss improved from 0.06264 to 0.06112, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 6s 326ms/step - loss: 0.0424 - val_loss: 0.0611
# Epoch 45/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 45: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 109ms/step - loss: 0.0185 - val_loss: 0.0625
# Epoch 46/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 46: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 124ms/step - loss: 0.0192 - val_loss: 0.0638
# Epoch 47/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 47: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 107ms/step - loss: 0.0112 - val_loss: 0.0658
# Epoch 48/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 48: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0168 - val_loss: 0.0639
# Epoch 49/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 49: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0141 - val_loss: 0.0658
# Epoch 50/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 50: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 94ms/step - loss: 0.0114 - val_loss: 0.0679
# Epoch 51/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 51: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0114 - val_loss: 0.0674
# Epoch 52/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 52: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 134ms/step - loss: 0.0121 - val_loss: 0.0640
# Epoch 53/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 53: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 105ms/step - loss: 0.0091 - val_loss: 0.0641
# Epoch 54/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 54: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 104ms/step - loss: 0.0081 - val_loss: 0.0709
# Epoch 55/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 55: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0115 - val_loss: 0.0689
# Epoch 56/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 56: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0085 - val_loss: 0.0649
# Epoch 57/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 57: val_loss did not improve from 0.06112
# 18/18 [==============================] - 2s 104ms/step - loss: 0.0070 - val_loss: 0.0671
# Epoch 58/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 58: val_loss improved from 0.06112 to 0.06015, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 6s 343ms/step - loss: 0.0100 - val_loss: 0.0602
# Epoch 59/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 59: val_loss improved from 0.06015 to 0.05854, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 281ms/step - loss: 0.0097 - val_loss: 0.0585
# Epoch 60/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 60: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 128ms/step - loss: 0.0131 - val_loss: 0.0623
# Epoch 61/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 61: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0063 - val_loss: 0.0667
# Epoch 62/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 62: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0108 - val_loss: 0.0673
# Epoch 63/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 63: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0070 - val_loss: 0.0657
# Epoch 64/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 64: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0066 - val_loss: 0.0632
# Epoch 65/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 65: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0115 - val_loss: 0.0616
# Epoch 66/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 66: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 121ms/step - loss: 0.0059 - val_loss: 0.0647
# Epoch 67/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 67: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 112ms/step - loss: 0.0058 - val_loss: 0.0645
# Epoch 68/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 68: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0077 - val_loss: 0.0652
# Epoch 69/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 69: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0077 - val_loss: 0.0629
# Epoch 70/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 70: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0080 - val_loss: 0.0651
# Epoch 71/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 71: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0098 - val_loss: 0.0661
# Epoch 72/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 72: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0086 - val_loss: 0.0621
# Epoch 73/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 73: val_loss did not improve from 0.05854
# 18/18 [==============================] - 2s 128ms/step - loss: 0.0065 - val_loss: 0.0597
# Epoch 74/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 74: val_loss improved from 0.05854 to 0.05703, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 309ms/step - loss: 0.0072 - val_loss: 0.0570
# Epoch 75/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 75: val_loss improved from 0.05703 to 0.05484, saving model to /content/drive/My Drive/new_kimore/modelEX5.h5
# 18/18 [==============================] - 5s 284ms/step - loss: 0.0058 - val_loss: 0.0548
# Epoch 76/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 76: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 109ms/step - loss: 0.0047 - val_loss: 0.0606
# Epoch 77/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 77: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0051 - val_loss: 0.0587
# Epoch 78/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 78: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0064 - val_loss: 0.0550
# Epoch 79/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 79: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0073 - val_loss: 0.0653
# Epoch 80/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 80: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0055 - val_loss: 0.0603
# Epoch 81/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 81: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 115ms/step - loss: 0.0053 - val_loss: 0.0619
# Epoch 82/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 82: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0057 - val_loss: 0.0609
# Epoch 83/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 83: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0042 - val_loss: 0.0631
# Epoch 84/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 84: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0048 - val_loss: 0.0668
# Epoch 85/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 85: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0044 - val_loss: 0.0636
# Epoch 86/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 86: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0088 - val_loss: 0.0605
# Epoch 87/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 87: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0046 - val_loss: 0.0569
# Epoch 88/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 88: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 129ms/step - loss: 0.0042 - val_loss: 0.0771
# Epoch 89/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 89: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0067 - val_loss: 0.0632
# Epoch 90/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 90: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0053 - val_loss: 0.0671
# Epoch 91/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 91: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0048 - val_loss: 0.0675
# Epoch 92/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 92: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0049 - val_loss: 0.0684
# Epoch 93/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 93: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 105ms/step - loss: 0.0035 - val_loss: 0.0628
# Epoch 94/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 94: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0043 - val_loss: 0.0626
# Epoch 95/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 95: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0047 - val_loss: 0.0613
# Epoch 96/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 96: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0036 - val_loss: 0.0644
# Epoch 97/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 97: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0054 - val_loss: 0.0690
# Epoch 98/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 98: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0070 - val_loss: 0.0655
# Epoch 99/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 99: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0083 - val_loss: 0.0680
# Epoch 100/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 100: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 130ms/step - loss: 0.0034 - val_loss: 0.0708
# Epoch 101/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 101: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0074 - val_loss: 0.0668
# Epoch 102/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 102: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0029 - val_loss: 0.0653
# Epoch 103/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 103: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0043 - val_loss: 0.0621
# Epoch 104/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 104: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0032 - val_loss: 0.0617
# Epoch 105/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 105: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 94ms/step - loss: 0.0051 - val_loss: 0.0637
# Epoch 106/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 106: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 140ms/step - loss: 0.0025 - val_loss: 0.0603
# Epoch 107/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 107: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0018 - val_loss: 0.0617
# Epoch 108/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 108: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0038 - val_loss: 0.0609
# Epoch 109/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 109: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0029 - val_loss: 0.0640
# Epoch 110/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 110: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0025 - val_loss: 0.0664
# Epoch 111/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 111: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0077 - val_loss: 0.0659
# Epoch 112/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 112: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 114ms/step - loss: 0.0142 - val_loss: 0.0768
# Epoch 113/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 113: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 113ms/step - loss: 0.0121 - val_loss: 0.0837
# Epoch 114/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 114: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0107 - val_loss: 0.0694
# Epoch 115/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 115: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0060 - val_loss: 0.0675
# Epoch 116/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 116: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0086 - val_loss: 0.0612
# Epoch 117/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 117: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0035 - val_loss: 0.0638
# Epoch 118/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 118: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 106ms/step - loss: 0.0061 - val_loss: 0.0657
# Epoch 119/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 119: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 125ms/step - loss: 0.0064 - val_loss: 0.0624
# Epoch 120/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 120: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0061 - val_loss: 0.0664
# Epoch 121/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 121: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0036 - val_loss: 0.0643
# Epoch 122/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 122: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0041 - val_loss: 0.0663
# Epoch 123/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 123: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0045 - val_loss: 0.0612
# Epoch 124/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 124: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0034 - val_loss: 0.0627
# Epoch 125/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 125: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 137ms/step - loss: 0.0052 - val_loss: 0.0611
# Epoch 126/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 126: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0034 - val_loss: 0.0615
# Epoch 127/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 127: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0046 - val_loss: 0.0599
# Epoch 128/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 128: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0033 - val_loss: 0.0608
# Epoch 129/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 129: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0044 - val_loss: 0.0647
# Epoch 130/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 130: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0021 - val_loss: 0.0708
# Epoch 131/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 131: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 134ms/step - loss: 0.0020 - val_loss: 0.0702
# Epoch 132/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 132: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0032 - val_loss: 0.0650
# Epoch 133/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 133: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0040 - val_loss: 0.0692
# Epoch 134/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 134: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0017 - val_loss: 0.0692
# Epoch 135/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 135: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0021 - val_loss: 0.0727
# Epoch 136/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 136: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0028 - val_loss: 0.0650
# Epoch 137/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 137: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 135ms/step - loss: 0.0020 - val_loss: 0.0632
# Epoch 138/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 138: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0028 - val_loss: 0.0647
# Epoch 139/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 139: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0019 - val_loss: 0.0635
# Epoch 140/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 140: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0021 - val_loss: 0.0656
# Epoch 141/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 141: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0025 - val_loss: 0.0667
# Epoch 142/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 142: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0034 - val_loss: 0.0660
# Epoch 143/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 143: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 127ms/step - loss: 0.0023 - val_loss: 0.0654
# Epoch 144/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 144: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 104ms/step - loss: 0.0036 - val_loss: 0.0672
# Epoch 145/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 145: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0025 - val_loss: 0.0697
# Epoch 146/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 146: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0022 - val_loss: 0.0699
# Epoch 147/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 147: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0023 - val_loss: 0.0630
# Epoch 148/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 148: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0029 - val_loss: 0.0642
# Epoch 149/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 149: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 119ms/step - loss: 0.0037 - val_loss: 0.0654
# Epoch 150/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 150: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 110ms/step - loss: 0.0034 - val_loss: 0.0647
# Epoch 151/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 151: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0022 - val_loss: 0.0640
# Epoch 152/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 152: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0036 - val_loss: 0.0636
# Epoch 153/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 153: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 101ms/step - loss: 0.0032 - val_loss: 0.0625
# Epoch 154/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 154: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0028 - val_loss: 0.0642
# Epoch 155/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 155: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 108ms/step - loss: 0.0029 - val_loss: 0.0636
# Epoch 156/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 156: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 120ms/step - loss: 0.0027 - val_loss: 0.0647
# Epoch 157/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 157: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0019 - val_loss: 0.0674
# Epoch 158/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 158: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0046 - val_loss: 0.0719
# Epoch 159/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 159: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0032 - val_loss: 0.0692
# Epoch 160/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 160: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 97ms/step - loss: 0.0023 - val_loss: 0.0691
# Epoch 161/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 161: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0021 - val_loss: 0.0649
# Epoch 162/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 162: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0039 - val_loss: 0.0688
# Epoch 163/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 163: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 96ms/step - loss: 0.0019 - val_loss: 0.0653
# Epoch 164/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 164: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0056 - val_loss: 0.0661
# Epoch 165/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 165: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0023 - val_loss: 0.0632
# Epoch 166/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0015
# Epoch 166: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0015 - val_loss: 0.0655
# Epoch 167/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 167: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0024 - val_loss: 0.0609
# Epoch 168/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 168: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 134ms/step - loss: 0.0048 - val_loss: 0.0589
# Epoch 169/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 169: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 98ms/step - loss: 0.0046 - val_loss: 0.0609
# Epoch 170/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 170: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0035 - val_loss: 0.0625
# Epoch 171/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 171: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 101ms/step - loss: 0.0044 - val_loss: 0.0610
# Epoch 172/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 172: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 100ms/step - loss: 0.0023 - val_loss: 0.0600
# Epoch 173/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 173: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 99ms/step - loss: 0.0043 - val_loss: 0.0636
# Epoch 174/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 174: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 136ms/step - loss: 0.0032 - val_loss: 0.0677
# Epoch 175/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 175: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 95ms/step - loss: 0.0017 - val_loss: 0.0674
# Epoch 176/400
# 18/18 [==============================] - ETA: 0s - loss: 0.0018Restoring model weights from the end of the best epoch: 106.
#
# Epoch 176: val_loss did not improve from 0.05484
# 18/18 [==============================] - 2s 114ms/step - loss: 0.0018 - val_loss: 0.0641
# Epoch 176: early stopping
# Training time: 0:09:22.355837

# %%
print(tracemalloc.get_traced_memory())
# stopping the library
tracemalloc.stop()
# Out:
# (136848943, 138363104)

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.0014911229955032468
# Validation loss 0.054838214069604874

# %%
# Plot the prediction of the model for the training and validation sets
import tensorflow as tf
from keras.models import load_model
from keras.initializers import glorot_uniform
# Load the best model's weights
best_model = load_model('/content/drive/My Drive/new_kimore/modelEX5.h5', custom_objects={'TCN': TCN, 'GlorotUniform': glorot_uniform()})

pred_train = best_model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = best_model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-1.2,1.2])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(valid_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-1.2,1.2])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()

plt.show()
# Out:
# 4/4 [==============================] - 7s 49ms/step
# 2/2 [==============================] - 0s 35ms/step

# %%
test_dev = abs(np.squeeze(pred_test)-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
#MSE
MSE=mean_squared_error(pred_test, test_y)
#MAPE
#P1 = 19*pred_test + 31;
#P2 = 19*test_y+31;
MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
print('MSE:',MSE)
rms_dev = np.sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
print('MAPE:',MAPE)
# Out:
# MSE: 0.07323998450156248
# Mean absolute deviation: 0.25436587871750926
# RMS deviation: 0.27062886856646035
# MAPE: inf

# %%
MAPE=np.mean(np.abs((pred_train-train_y)/train_y))*100
print(MAPE)
# Out:
# inf

# %%
print(pred_test)
# Out:
# [[0.71376914]
#  [0.56206936]
#  [0.82020193]
#  [0.7043059 ]
#  [0.8880633 ]
#  [0.60898507]
#  [0.61306983]
#  [0.57564044]
#  [0.6864603 ]
#  [0.62665194]
#  [0.7479335 ]
#  [0.2609434 ]
#  [0.4908717 ]
#  [0.663501  ]
#  [0.8349557 ]
#  [0.71453726]
#  [0.72508365]
#  [0.71735173]
#  [0.7500358 ]
#  [0.69663423]
#  [0.59456074]
#  [0.81375664]
#  [0.6703184 ]
#  [0.23345748]
#  [0.46718735]
#  [0.5558091 ]
#  [0.7443147 ]
#  [0.8300575 ]
#  [0.827009  ]
#  [0.7215498 ]
#  [0.33131394]
#  [0.6892668 ]
#  [0.7476609 ]
#  [0.7916122 ]
#  [0.6859433 ]
#  [0.850666  ]
#  [0.78906757]
#  [0.8328676 ]
#  [0.7947749 ]
#  [0.7505355 ]
#  [0.77150077]
#  [0.8214009 ]]
