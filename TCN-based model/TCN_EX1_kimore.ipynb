# %%
pip install keras-tcn
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Collecting tensorflow-addons (from keras-tcn)
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->keras-tcn)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)
# Installing collected packages: typeguard, tensorflow-addons, keras-tcn
# Successfully installed keras-tcn-3.5.0 tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences
timesteps = 104
# dimension of data sequences
n_dim = 80
batch_size = 2

# %%
drive.mount('/content/drive')
dir_name_samples ='/content/drive/My Drive/new_kimore/Preprocessed_data/Exercise1_data.csv'
dir_name_labels ='/content/drive/My Drive/new_kimore/Preprocessed_data/Labels_ex1.csv'
import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive

# %%
X_values = pd.read_csv(dir_name_samples, delimiter=',', encoding='utf-8')
print(X_values.shape)
# # Initialize the MinMaxScaler

# scaler = StandardScaler()
# # Fit and transform the data using the scaler
# scaled_data = scaler.fit_transform(X_values)

# # Create a new DataFrame with the scaled data
# scaled_df = pd.DataFrame(scaled_data, columns=X_values.columns)


# # Extract the underlying NumPy array
# numpy_2d_array = scaled_df.values
# #numpy_2d_array = X_values.values
# # Reshape the 2D array into a 3D array (207, 100, 80)
# X_train = numpy_2d_array.reshape(207, 100, 80)
# # The temporal pyramid requires that the length of the data sequences is divisible by 8.
# # The original length was 100 time steps, so we will repeat the first and last 2 data vectors to obtain sequences with 104 time steps
# X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
numpy_2d_array = X_values.values
X_train = numpy_2d_array.reshape(213, 100, 80)
# Calculate the mean along the specified axes (axis=0, axis=1, and axis=2) to obtain a mean value for the entire array
mean_value = X_train.mean(axis=(0, 1, 2))

# Subtract the mean from the entire array to achieve zero mean
X_train -= mean_value

# Calculate the maximum and minimum values in the array
max_value = X_train.max()
min_value = X_train.min()

# Normalize the array to a range between -1 and 1
data = 2 * (X_train - min_value) / (max_value - min_value) - 1
smoothed_data = np.empty_like(X_train)
for channel in range(80):
    smoothed_data[:, :, channel] = gaussian_filter1d(data[:, :, channel], sigma=5)
X_train=smoothed_data
X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
#-----------labels------------------------------------
Y_values = pd.read_csv(dir_name_labels)
#change the secon column to the labels
y_values= Y_values['EX1'].values

reshaped_data_y = y_values.reshape(213, 1)
# Fit and transform the data using the scaler
#scaler2 = MinMaxScaler(feature_range=(0, 1))
#y_train = scaler2.fit_transform(reshaped_data_y)
min_value = np.min(reshaped_data_y)
max_value = np.max(reshaped_data_y)

# Normalize the vector to be in the range [-1, 1]
y_train = (reshaped_data_y - min_value) / (max_value - min_value)

print('Training sequences dimension', X_train)
print('Training labels dimension', y_train)
# Out:
# (21300, 80)
# Training sequences dimension [[[-0.0161619  -0.01031645 -0.00666048 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.01607827 -0.0103141  -0.00665525 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.0161619  -0.01031645 -0.00666048 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00726294 -0.00880858 -0.00572311 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00697359 -0.00876007 -0.00570275 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.007165   -0.00879241 -0.00571619 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00990915 -0.00655313 -0.00597644 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00992924 -0.00656738 -0.00598018 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00990915 -0.00655313 -0.00597644 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00164321 -0.00689076 -0.00536924 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00176402 -0.00685255 -0.00537985 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00168268 -0.00687817 -0.00537283 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00621833 -0.00618291 -0.00549057 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00636479 -0.00619827 -0.00549802 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00621833 -0.00618291 -0.00549057 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00088778 -0.00436638 -0.00551589 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00086231 -0.0043763  -0.00551431 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00087756 -0.0043695  -0.00551527 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  ...
#
#  [[-0.02121325 -0.00582086 -0.00616994 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.02119875 -0.00581283 -0.00616874 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.02121325 -0.00582086 -0.00616994 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00702552 -0.00489937 -0.00603099 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00654121 -0.00487431 -0.00603277 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00686291 -0.00489016 -0.00603167 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00031776 -0.00627259 -0.00575816 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00040594 -0.00624775 -0.00577212 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00031776 -0.00627259 -0.00575816 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00539327 -0.00563069 -0.00538058 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00530069 -0.00569648 -0.005344   ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00536083 -0.00565384 -0.00536813 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00595845 -0.00838938 -0.006219   ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00594273 -0.00838813 -0.00621095 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00595845 -0.00838938 -0.006219   ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.01023785 -0.00647186 -0.00623266 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.01024414 -0.00655752 -0.00625003 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.01023977 -0.00650194 -0.00623867 ... -0.00600993 -0.00600993
#    -0.00600993]]]
# Training labels dimension [[0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.89814815]
#  [0.89814815]
#  [0.89814815]
#  [0.83333333]
#  [0.83333333]
#  [0.83333333]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.71296296]
#  [0.71296296]
#  [0.71296296]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [0.98148148]
#  [0.98148148]
#  [0.98148148]
#  [0.84259259]
#  [0.84259259]
#  [0.84259259]
#  [0.74074074]
#  [0.74074074]
#  [0.74074074]
#  [0.82407407]
#  [0.82407407]
#  [0.82407407]
#  [0.77777778]
#  [0.77777778]
#  [0.77777778]
#  [0.72222222]
#  [0.72222222]
#  [0.72222222]
#  [0.77777778]
#  [0.77777778]
#  [0.77777778]
#  [0.55555556]
#  [0.55555556]
#  [0.55555556]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.72222222]
#  [0.72222222]
#  [0.72222222]
#  [0.7962963 ]
#  [0.7962963 ]
#  [0.7962963 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.86111111]
#  [0.86111111]
#  [0.86111111]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.66666667]
#  [0.66666667]
#  [0.66666667]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.80555556]
#  [0.80555556]
#  [0.80555556]
#  [0.85185185]
#  [0.85185185]
#  [0.85185185]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [0.66666667]
#  [0.66666667]
#  [0.66666667]
#  [0.39472448]
#  [0.39472448]
#  [0.39472448]
#  [0.5372148 ]
#  [0.5372148 ]
#  [0.5372148 ]
#  [0.84259259]
#  [0.84259259]
#  [0.84259259]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.87037037]
#  [0.87037037]
#  [0.87037037]
#  [0.73148148]
#  [0.73148148]
#  [0.73148148]
#  [0.94444444]
#  [0.94444444]
#  [0.94444444]
#  [0.36111111]
#  [0.36111111]
#  [0.36111111]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.22222222]
#  [0.22222222]
#  [0.22222222]
#  [0.90740741]
#  [0.90740741]
#  [0.90740741]
#  [0.5       ]
#  [0.5       ]
#  [0.5       ]
#  [0.72222222]
#  [0.72222222]
#  [0.72222222]
#  [0.56411612]
#  [0.56411612]
#  [0.56411612]
#  [0.01851852]
#  [0.01851852]
#  [0.01851852]
#  [0.60185185]
#  [0.60185185]
#  [0.60185185]
#  [0.62962963]
#  [0.62962963]
#  [0.62962963]
#  [0.61111111]
#  [0.61111111]
#  [0.61111111]
#  [0.37962963]
#  [0.37962963]
#  [0.37962963]
#  [0.63888889]
#  [0.63888889]
#  [0.63888889]
#  [0.36111111]
#  [0.36111111]
#  [0.36111111]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.55555556]
#  [0.55555556]
#  [0.55555556]
#  [0.83333333]
#  [0.83333333]
#  [0.83333333]
#  [0.33333333]
#  [0.33333333]
#  [0.33333333]
#  [0.67807648]
#  [0.67807648]
#  [0.67807648]
#  [0.35185185]
#  [0.35185185]
#  [0.35185185]
#  [0.61111111]
#  [0.61111111]
#  [0.61111111]
#  [0.34259259]
#  [0.34259259]
#  [0.34259259]
#  [0.5462963 ]
#  [0.5462963 ]
#  [0.5462963 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]

# %%
# Split the data into training and validation sets
train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.3)
# Split your dataset into a training set (60%) and a combined validation-testing set (40%)
train_x, X_val_test, train_y, y_val_test = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

# Split the combined validation-testing set (40%) into a validation set (20%) and a test set (20%)
valid_x, test_x, valid_y, test_y = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# Now, you have X_train, y_train for training (60%), X_val, y_val for validation (20%), and X_test, y_test for testing (20%)
print('Training data', train_x.shape)
print('Validation data', valid_x.shape)
print('Training label', train_y.shape)
print('Validation label', valid_y.shape)
# Out:
# Training data (127, 104, 80)
# Validation data (43, 104, 80)
# Training label (127, 1)
# Validation label (43, 1)

# %%
# Plot the first and last sequences in the training and validation data
plt.figure(figsize = (14,8))
plt.subplot(2,2,1)
plt.plot(train_x[0])
plt.subplot(2,2,2)
plt.plot(train_x[-1])
plt.subplot(2,2,3)
plt.plot(valid_x[0])
plt.subplot(2,2,4)
plt.plot(valid_x[-1])
plt.tight_layout()
plt.show()

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)
trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)
trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)
trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]
trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]
trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
trainx =  train_x
validx =  valid_x
testx =  test_x

# %%
import matplotlib.patches as mpatches
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(trainx[0,:,0:16], color='red')
plt.plot(trainx[0,:,16:32], color='blue')
plt.plot(trainx[0,:,32:48], color='green')
plt.plot(trainx[0,:,48:64], color='orange')
plt.plot(trainx[0,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('First Train Sequence')
plt.subplot(1,2,2)
plt.plot(trainx[-1,:,0:16], color='red')
plt.plot(trainx[-1,:,16:32], color='blue')
plt.plot(trainx[-1,:,32:48], color='green')
plt.plot(trainx[-1,:,48:64], color='orange')
plt.plot(trainx[-1,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('Last Train Sequence')
plt.tight_layout()
plt.show()

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
n_dim = 80 # dimension after reordering the data into body parts
n_dim1 = 16 # dimension of indiviudal body parts
n_dim2 = 16
n_dim3 = 16 # legs dimension
# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps,n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 16:32])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 32:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:64])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 64:80])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 16:32])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 32:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:64])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 64:80])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 16:32])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 32:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:64])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 64:80])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 16:32])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 32:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:64])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'linear')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 104, 80)]            0         []
#
#  half_scale (InputLayer)     [(None, 52, 80)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 26, 80)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 13, 80)]             0         []
#
#  lambda (Lambda)             (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_5 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_10 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_15 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_1 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_6 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_11 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_16 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_2 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_7 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_12 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_17 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_3 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_8 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_13 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_18 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_4 (Lambda)           (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_9 (Lambda)           (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_14 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_19 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  tcn (TCN)                   (None, 104, 12)              5676      ['lambda[0][0]']
#
#  tcn_1 (TCN)                 (None, 52, 12)               5676      ['lambda_5[0][0]']
#
#  tcn_2 (TCN)                 (None, 26, 12)               5676      ['lambda_10[0][0]']
#
#  tcn_3 (TCN)                 (None, 13, 12)               5676      ['lambda_15[0][0]']
#
#  tcn_4 (TCN)                 (None, 104, 12)              5676      ['lambda_1[0][0]']
#
#  tcn_5 (TCN)                 (None, 52, 12)               5676      ['lambda_6[0][0]']
#
#  tcn_6 (TCN)                 (None, 26, 12)               5676      ['lambda_11[0][0]']
#
#  tcn_7 (TCN)                 (None, 13, 12)               5676      ['lambda_16[0][0]']
#
#  tcn_8 (TCN)                 (None, 104, 12)              5676      ['lambda_2[0][0]']
#
#  tcn_9 (TCN)                 (None, 52, 12)               5676      ['lambda_7[0][0]']
#
#  tcn_10 (TCN)                (None, 26, 12)               5676      ['lambda_12[0][0]']
#
#  tcn_11 (TCN)                (None, 13, 12)               5676      ['lambda_17[0][0]']
#
#  tcn_12 (TCN)                (None, 104, 12)              5676      ['lambda_3[0][0]']
#
#  tcn_13 (TCN)                (None, 52, 12)               5676      ['lambda_8[0][0]']
#
#  tcn_14 (TCN)                (None, 26, 12)               5676      ['lambda_13[0][0]']
#
#  tcn_15 (TCN)                (None, 13, 12)               5676      ['lambda_18[0][0]']
#
#  tcn_16 (TCN)                (None, 104, 12)              5676      ['lambda_4[0][0]']
#
#  tcn_17 (TCN)                (None, 52, 12)               5676      ['lambda_9[0][0]']
#
#  tcn_18 (TCN)                (None, 26, 12)               5676      ['lambda_14[0][0]']
#
#  tcn_19 (TCN)                (None, 13, 12)               5676      ['lambda_19[0][0]']
#
#  concatenate (Concatenate)   (None, 195, 12)              0         ['tcn[0][0]',
#                                                                      'tcn_1[0][0]',
#                                                                      'tcn_2[0][0]',
#                                                                      'tcn_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 195, 12)              0         ['tcn_4[0][0]',
#  )                                                                   'tcn_5[0][0]',
#                                                                      'tcn_6[0][0]',
#                                                                      'tcn_7[0][0]']
#
#  concatenate_2 (Concatenate  (None, 195, 12)              0         ['tcn_8[0][0]',
#  )                                                                   'tcn_9[0][0]',
#                                                                      'tcn_10[0][0]',
#                                                                      'tcn_11[0][0]']
#
#  concatenate_3 (Concatenate  (None, 195, 12)              0         ['tcn_12[0][0]',
#  )                                                                   'tcn_13[0][0]',
#                                                                      'tcn_14[0][0]',
#                                                                      'tcn_15[0][0]']
#
#  concatenate_4 (Concatenate  (None, 195, 12)              0         ['tcn_16[0][0]',
#  )                                                                   'tcn_17[0][0]',
#                                                                      'tcn_18[0][0]',
#                                                                      'tcn_19[0][0]']
#
#  concatenate_5 (Concatenate  (None, 195, 60)              0         ['concatenate[0][0]',
#  )                                                                   'concatenate_1[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'concatenate_4[0][0]']
#
#  tcn_20 (TCN)                (None, 195, 12)              6012      ['concatenate_5[0][0]']
#
#  tcn_21 (TCN)                (None, 195, 8)               1176      ['tcn_20[0][0]']
#
#  tcn_22 (TCN)                (None, 6)                    546       ['tcn_21[0][0]']
#
#  dense (Dense)               (None, 1)                    7         ['tcn_22[0][0]']
#
# ==================================================================================================
# Total params: 121261 (473.68 KB)
# Trainable params: 121165 (473.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX1.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 19/19 [==============================] - ETA: 0s - loss: 0.6352
# Epoch 1: val_loss improved from inf to 1.38527, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 280s 2s/step - loss: 0.6352 - val_loss: 1.3853
# Epoch 2/400
# 19/19 [==============================] - ETA: 0s - loss: 0.3920
# Epoch 2: val_loss improved from 1.38527 to 0.14324, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 469ms/step - loss: 0.3920 - val_loss: 0.1432
# Epoch 3/400
# 19/19 [==============================] - ETA: 0s - loss: 0.3553
# Epoch 3: val_loss improved from 0.14324 to 0.08639, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 510ms/step - loss: 0.3553 - val_loss: 0.0864
# Epoch 4/400
# 19/19 [==============================] - ETA: 0s - loss: 0.2231
# Epoch 4: val_loss improved from 0.08639 to 0.06115, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 461ms/step - loss: 0.2231 - val_loss: 0.0611
# Epoch 5/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1927
# Epoch 5: val_loss did not improve from 0.06115
# 19/19 [==============================] - 4s 215ms/step - loss: 0.1927 - val_loss: 0.1052
# Epoch 6/400
# 19/19 [==============================] - ETA: 0s - loss: 0.2080
# Epoch 6: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 173ms/step - loss: 0.2080 - val_loss: 0.1036
# Epoch 7/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1304
# Epoch 7: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 181ms/step - loss: 0.1304 - val_loss: 0.1064
# Epoch 8/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1572
# Epoch 8: val_loss did not improve from 0.06115
# 19/19 [==============================] - 5s 273ms/step - loss: 0.1572 - val_loss: 0.1056
# Epoch 9/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0938
# Epoch 9: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 184ms/step - loss: 0.0938 - val_loss: 0.0931
# Epoch 10/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1214
# Epoch 10: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 175ms/step - loss: 0.1214 - val_loss: 0.0834
# Epoch 11/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0918
# Epoch 11: val_loss did not improve from 0.06115
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0918 - val_loss: 0.0819
# Epoch 12/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0938
# Epoch 12: val_loss did not improve from 0.06115
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0938 - val_loss: 0.0774
# Epoch 13/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1256
# Epoch 13: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 171ms/step - loss: 0.1256 - val_loss: 0.0798
# Epoch 14/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0891
# Epoch 14: val_loss did not improve from 0.06115
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0891 - val_loss: 0.0740
# Epoch 15/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0974
# Epoch 15: val_loss did not improve from 0.06115
# 19/19 [==============================] - 5s 248ms/step - loss: 0.0974 - val_loss: 0.0669
# Epoch 16/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1012
# Epoch 16: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 177ms/step - loss: 0.1012 - val_loss: 0.0676
# Epoch 17/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1022
# Epoch 17: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 172ms/step - loss: 0.1022 - val_loss: 0.0727
# Epoch 18/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1051
# Epoch 18: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 169ms/step - loss: 0.1051 - val_loss: 0.0708
# Epoch 19/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0903
# Epoch 19: val_loss did not improve from 0.06115
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0903 - val_loss: 0.0679
# Epoch 20/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1019
# Epoch 20: val_loss did not improve from 0.06115
# 19/19 [==============================] - 3s 173ms/step - loss: 0.1019 - val_loss: 0.0676
# Epoch 21/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0861
# Epoch 21: val_loss improved from 0.06115 to 0.05733, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 510ms/step - loss: 0.0861 - val_loss: 0.0573
# Epoch 22/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0975
# Epoch 22: val_loss did not improve from 0.05733
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0975 - val_loss: 0.0645
# Epoch 23/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0819
# Epoch 23: val_loss did not improve from 0.05733
# 19/19 [==============================] - 3s 182ms/step - loss: 0.0819 - val_loss: 0.0638
# Epoch 24/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0920
# Epoch 24: val_loss did not improve from 0.05733
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0920 - val_loss: 0.0646
# Epoch 25/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0790
# Epoch 25: val_loss did not improve from 0.05733
# 19/19 [==============================] - 5s 268ms/step - loss: 0.0790 - val_loss: 0.0679
# Epoch 26/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0899
# Epoch 26: val_loss did not improve from 0.05733
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0899 - val_loss: 0.0670
# Epoch 27/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0839
# Epoch 27: val_loss did not improve from 0.05733
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0839 - val_loss: 0.0596
# Epoch 28/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0767
# Epoch 28: val_loss did not improve from 0.05733
# 19/19 [==============================] - 4s 232ms/step - loss: 0.0767 - val_loss: 0.0623
# Epoch 29/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0724
# Epoch 29: val_loss did not improve from 0.05733
# 19/19 [==============================] - 4s 213ms/step - loss: 0.0724 - val_loss: 0.0596
# Epoch 30/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0837
# Epoch 30: val_loss did not improve from 0.05733
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0837 - val_loss: 0.0636
# Epoch 31/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0798
# Epoch 31: val_loss did not improve from 0.05733
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0798 - val_loss: 0.0650
# Epoch 32/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0873
# Epoch 32: val_loss did not improve from 0.05733
# 19/19 [==============================] - 5s 256ms/step - loss: 0.0873 - val_loss: 0.0628
# Epoch 33/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0687
# Epoch 33: val_loss improved from 0.05733 to 0.05595, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 486ms/step - loss: 0.0687 - val_loss: 0.0560
# Epoch 34/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0772
# Epoch 34: val_loss improved from 0.05595 to 0.05325, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 10s 525ms/step - loss: 0.0772 - val_loss: 0.0532
# Epoch 35/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 35: val_loss did not improve from 0.05325
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0773 - val_loss: 0.0542
# Epoch 36/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0640
# Epoch 36: val_loss improved from 0.05325 to 0.05155, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 10s 572ms/step - loss: 0.0640 - val_loss: 0.0515
# Epoch 37/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0797
# Epoch 37: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0797 - val_loss: 0.0524
# Epoch 38/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0737
# Epoch 38: val_loss did not improve from 0.05155
# 19/19 [==============================] - 5s 243ms/step - loss: 0.0737 - val_loss: 0.0545
# Epoch 39/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0677
# Epoch 39: val_loss did not improve from 0.05155
# 19/19 [==============================] - 4s 183ms/step - loss: 0.0677 - val_loss: 0.0523
# Epoch 40/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0655
# Epoch 40: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0655 - val_loss: 0.0516
# Epoch 41/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0611
# Epoch 41: val_loss did not improve from 0.05155
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0611 - val_loss: 0.0544
# Epoch 42/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0687
# Epoch 42: val_loss did not improve from 0.05155
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0687 - val_loss: 0.0526
# Epoch 43/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0637
# Epoch 43: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0637 - val_loss: 0.0533
# Epoch 44/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0622
# Epoch 44: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0622 - val_loss: 0.0543
# Epoch 45/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0741
# Epoch 45: val_loss did not improve from 0.05155
# 19/19 [==============================] - 4s 205ms/step - loss: 0.0741 - val_loss: 0.0572
# Epoch 46/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0700
# Epoch 46: val_loss did not improve from 0.05155
# 19/19 [==============================] - 4s 219ms/step - loss: 0.0700 - val_loss: 0.0537
# Epoch 47/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0671
# Epoch 47: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0671 - val_loss: 0.0539
# Epoch 48/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0641
# Epoch 48: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0641 - val_loss: 0.0545
# Epoch 49/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0664
# Epoch 49: val_loss did not improve from 0.05155
# 19/19 [==============================] - 4s 232ms/step - loss: 0.0664 - val_loss: 0.0544
# Epoch 50/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0672
# Epoch 50: val_loss did not improve from 0.05155
# 19/19 [==============================] - 4s 188ms/step - loss: 0.0672 - val_loss: 0.0566
# Epoch 51/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 51: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0675 - val_loss: 0.0584
# Epoch 52/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0654
# Epoch 52: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0654 - val_loss: 0.0566
# Epoch 53/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0676
# Epoch 53: val_loss did not improve from 0.05155
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0676 - val_loss: 0.0556
# Epoch 54/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0745
# Epoch 54: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0745 - val_loss: 0.0593
# Epoch 55/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0717
# Epoch 55: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0717 - val_loss: 0.0592
# Epoch 56/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0704
# Epoch 56: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0704 - val_loss: 0.0556
# Epoch 57/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 57: val_loss did not improve from 0.05155
# 19/19 [==============================] - 5s 248ms/step - loss: 0.0675 - val_loss: 0.0516
# Epoch 58/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0726
# Epoch 58: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0726 - val_loss: 0.0524
# Epoch 59/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0673
# Epoch 59: val_loss did not improve from 0.05155
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0673 - val_loss: 0.0567
# Epoch 60/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0624
# Epoch 60: val_loss did not improve from 0.05155
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0624 - val_loss: 0.0589
# Epoch 61/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0609
# Epoch 61: val_loss improved from 0.05155 to 0.05032, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 502ms/step - loss: 0.0609 - val_loss: 0.0503
# Epoch 62/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0680
# Epoch 62: val_loss did not improve from 0.05032
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0680 - val_loss: 0.0519
# Epoch 63/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0617
# Epoch 63: val_loss did not improve from 0.05032
# 19/19 [==============================] - 4s 208ms/step - loss: 0.0617 - val_loss: 0.0517
# Epoch 64/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0681
# Epoch 64: val_loss did not improve from 0.05032
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0681 - val_loss: 0.0538
# Epoch 65/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0616
# Epoch 65: val_loss did not improve from 0.05032
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0616 - val_loss: 0.0509
# Epoch 66/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0631
# Epoch 66: val_loss did not improve from 0.05032
# 19/19 [==============================] - 5s 271ms/step - loss: 0.0631 - val_loss: 0.0538
# Epoch 67/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0676
# Epoch 67: val_loss did not improve from 0.05032
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0676 - val_loss: 0.0534
# Epoch 68/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0645
# Epoch 68: val_loss did not improve from 0.05032
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0645 - val_loss: 0.0530
# Epoch 69/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0671
# Epoch 69: val_loss did not improve from 0.05032
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0671 - val_loss: 0.0532
# Epoch 70/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0685
# Epoch 70: val_loss did not improve from 0.05032
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0685 - val_loss: 0.0549
# Epoch 71/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0645
# Epoch 71: val_loss did not improve from 0.05032
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0645 - val_loss: 0.0535
# Epoch 72/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0616
# Epoch 72: val_loss did not improve from 0.05032
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0616 - val_loss: 0.0534
# Epoch 73/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0561
# Epoch 73: val_loss did not improve from 0.05032
# 19/19 [==============================] - 4s 234ms/step - loss: 0.0561 - val_loss: 0.0545
# Epoch 74/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0574
# Epoch 74: val_loss did not improve from 0.05032
# 19/19 [==============================] - 4s 206ms/step - loss: 0.0574 - val_loss: 0.0528
# Epoch 75/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0585
# Epoch 75: val_loss improved from 0.05032 to 0.04961, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 481ms/step - loss: 0.0585 - val_loss: 0.0496
# Epoch 76/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0615
# Epoch 76: val_loss improved from 0.04961 to 0.04935, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 491ms/step - loss: 0.0615 - val_loss: 0.0493
# Epoch 77/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0525
# Epoch 77: val_loss improved from 0.04935 to 0.04882, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 506ms/step - loss: 0.0525 - val_loss: 0.0488
# Epoch 78/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0574
# Epoch 78: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0574 - val_loss: 0.0500
# Epoch 79/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0609
# Epoch 79: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0609 - val_loss: 0.0519
# Epoch 80/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0559
# Epoch 80: val_loss did not improve from 0.04882
# 19/19 [==============================] - 5s 258ms/step - loss: 0.0559 - val_loss: 0.0511
# Epoch 81/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0661
# Epoch 81: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0661 - val_loss: 0.0571
# Epoch 82/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0605
# Epoch 82: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0605 - val_loss: 0.0535
# Epoch 83/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0603
# Epoch 83: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 184ms/step - loss: 0.0603 - val_loss: 0.0603
# Epoch 84/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0592
# Epoch 84: val_loss did not improve from 0.04882
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0592 - val_loss: 0.0599
# Epoch 85/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0622
# Epoch 85: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0622 - val_loss: 0.0518
# Epoch 86/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 86: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0587 - val_loss: 0.0510
# Epoch 87/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0655
# Epoch 87: val_loss did not improve from 0.04882
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0655 - val_loss: 0.0507
# Epoch 88/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0599
# Epoch 88: val_loss did not improve from 0.04882
# 19/19 [==============================] - 4s 206ms/step - loss: 0.0599 - val_loss: 0.0537
# Epoch 89/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0630
# Epoch 89: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0630 - val_loss: 0.0553
# Epoch 90/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0589
# Epoch 90: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0589 - val_loss: 0.0503
# Epoch 91/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0600
# Epoch 91: val_loss did not improve from 0.04882
# 19/19 [==============================] - 5s 258ms/step - loss: 0.0600 - val_loss: 0.0511
# Epoch 92/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0544
# Epoch 92: val_loss did not improve from 0.04882
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0544 - val_loss: 0.0517
# Epoch 93/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0547
# Epoch 93: val_loss improved from 0.04882 to 0.04879, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 498ms/step - loss: 0.0547 - val_loss: 0.0488
# Epoch 94/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0632
# Epoch 94: val_loss did not improve from 0.04879
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0632 - val_loss: 0.0531
# Epoch 95/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0548
# Epoch 95: val_loss improved from 0.04879 to 0.04777, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 446ms/step - loss: 0.0548 - val_loss: 0.0478
# Epoch 96/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0597
# Epoch 96: val_loss did not improve from 0.04777
# 19/19 [==============================] - 4s 231ms/step - loss: 0.0597 - val_loss: 0.0490
# Epoch 97/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0539
# Epoch 97: val_loss did not improve from 0.04777
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0539 - val_loss: 0.0495
# Epoch 98/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0574
# Epoch 98: val_loss did not improve from 0.04777
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0574 - val_loss: 0.0511
# Epoch 99/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0645
# Epoch 99: val_loss did not improve from 0.04777
# 19/19 [==============================] - 4s 238ms/step - loss: 0.0645 - val_loss: 0.0480
# Epoch 100/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0589
# Epoch 100: val_loss improved from 0.04777 to 0.04626, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 489ms/step - loss: 0.0589 - val_loss: 0.0463
# Epoch 101/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0582
# Epoch 101: val_loss did not improve from 0.04626
# 19/19 [==============================] - 4s 230ms/step - loss: 0.0582 - val_loss: 0.0507
# Epoch 102/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0551
# Epoch 102: val_loss did not improve from 0.04626
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0551 - val_loss: 0.0472
# Epoch 103/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0601
# Epoch 103: val_loss did not improve from 0.04626
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0601 - val_loss: 0.0504
# Epoch 104/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0566
# Epoch 104: val_loss did not improve from 0.04626
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0566 - val_loss: 0.0482
# Epoch 105/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0522
# Epoch 105: val_loss improved from 0.04626 to 0.04457, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 10s 552ms/step - loss: 0.0522 - val_loss: 0.0446
# Epoch 106/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0592
# Epoch 106: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0592 - val_loss: 0.0525
# Epoch 107/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0557
# Epoch 107: val_loss did not improve from 0.04457
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0557 - val_loss: 0.0463
# Epoch 108/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0533
# Epoch 108: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0533 - val_loss: 0.0475
# Epoch 109/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0589
# Epoch 109: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0589 - val_loss: 0.0466
# Epoch 110/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0586
# Epoch 110: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0586 - val_loss: 0.0512
# Epoch 111/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0545
# Epoch 111: val_loss did not improve from 0.04457
# 19/19 [==============================] - 5s 265ms/step - loss: 0.0545 - val_loss: 0.0461
# Epoch 112/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0496
# Epoch 112: val_loss did not improve from 0.04457
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0496 - val_loss: 0.0457
# Epoch 113/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0533
# Epoch 113: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0533 - val_loss: 0.0517
# Epoch 114/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0555
# Epoch 114: val_loss did not improve from 0.04457
# 19/19 [==============================] - 4s 210ms/step - loss: 0.0555 - val_loss: 0.0536
# Epoch 115/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0568
# Epoch 115: val_loss did not improve from 0.04457
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0568 - val_loss: 0.0539
# Epoch 116/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0568
# Epoch 116: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0568 - val_loss: 0.0549
# Epoch 117/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0544
# Epoch 117: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0544 - val_loss: 0.0545
# Epoch 118/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0469
# Epoch 118: val_loss did not improve from 0.04457
# 19/19 [==============================] - 5s 271ms/step - loss: 0.0469 - val_loss: 0.0575
# Epoch 119/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 119: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0491 - val_loss: 0.0523
# Epoch 120/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0561
# Epoch 120: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0561 - val_loss: 0.0485
# Epoch 121/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0502
# Epoch 121: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0502 - val_loss: 0.0525
# Epoch 122/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0509
# Epoch 122: val_loss did not improve from 0.04457
# 19/19 [==============================] - 5s 254ms/step - loss: 0.0509 - val_loss: 0.0522
# Epoch 123/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0526
# Epoch 123: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0526 - val_loss: 0.0559
# Epoch 124/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0510
# Epoch 124: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0510 - val_loss: 0.0467
# Epoch 125/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0488
# Epoch 125: val_loss did not improve from 0.04457
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0488 - val_loss: 0.0451
# Epoch 126/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0417
# Epoch 126: val_loss did not improve from 0.04457
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0417 - val_loss: 0.0470
# Epoch 127/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0403
# Epoch 127: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 185ms/step - loss: 0.0403 - val_loss: 0.0485
# Epoch 128/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0507
# Epoch 128: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0507 - val_loss: 0.0484
# Epoch 129/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0420
# Epoch 129: val_loss did not improve from 0.04457
# 19/19 [==============================] - 5s 261ms/step - loss: 0.0420 - val_loss: 0.0467
# Epoch 130/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0436
# Epoch 130: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0436 - val_loss: 0.0525
# Epoch 131/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0480
# Epoch 131: val_loss did not improve from 0.04457
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0480 - val_loss: 0.0527
# Epoch 132/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 132: val_loss did not improve from 0.04457
# 19/19 [==============================] - 4s 198ms/step - loss: 0.0367 - val_loss: 0.0469
# Epoch 133/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0348
# Epoch 133: val_loss did not improve from 0.04457
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0348 - val_loss: 0.0462
# Epoch 134/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0380
# Epoch 134: val_loss improved from 0.04457 to 0.04423, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 472ms/step - loss: 0.0380 - val_loss: 0.0442
# Epoch 135/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0460
# Epoch 135: val_loss did not improve from 0.04423
# 19/19 [==============================] - 5s 244ms/step - loss: 0.0460 - val_loss: 0.0477
# Epoch 136/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0442
# Epoch 136: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0442 - val_loss: 0.0476
# Epoch 137/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0407
# Epoch 137: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0407 - val_loss: 0.0457
# Epoch 138/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0469
# Epoch 138: val_loss did not improve from 0.04423
# 19/19 [==============================] - 4s 228ms/step - loss: 0.0469 - val_loss: 0.0527
# Epoch 139/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0407
# Epoch 139: val_loss did not improve from 0.04423
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0407 - val_loss: 0.0576
# Epoch 140/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0403
# Epoch 140: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0403 - val_loss: 0.0450
# Epoch 141/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0399
# Epoch 141: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0399 - val_loss: 0.0527
# Epoch 142/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0425
# Epoch 142: val_loss did not improve from 0.04423
# 19/19 [==============================] - 5s 272ms/step - loss: 0.0425 - val_loss: 0.0481
# Epoch 143/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 143: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0349 - val_loss: 0.0496
# Epoch 144/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0351
# Epoch 144: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0351 - val_loss: 0.0497
# Epoch 145/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 145: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0374 - val_loss: 0.0495
# Epoch 146/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0309
# Epoch 146: val_loss did not improve from 0.04423
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0309 - val_loss: 0.0493
# Epoch 147/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0362
# Epoch 147: val_loss did not improve from 0.04423
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0362 - val_loss: 0.0541
# Epoch 148/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0315
# Epoch 148: val_loss improved from 0.04423 to 0.04333, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 511ms/step - loss: 0.0315 - val_loss: 0.0433
# Epoch 149/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0444
# Epoch 149: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0444 - val_loss: 0.0536
# Epoch 150/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0357
# Epoch 150: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0357 - val_loss: 0.0555
# Epoch 151/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 151: val_loss did not improve from 0.04333
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0317 - val_loss: 0.0517
# Epoch 152/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 152: val_loss did not improve from 0.04333
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0301 - val_loss: 0.0543
# Epoch 153/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0255
# Epoch 153: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 183ms/step - loss: 0.0255 - val_loss: 0.0507
# Epoch 154/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0274
# Epoch 154: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0274 - val_loss: 0.0528
# Epoch 155/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0320
# Epoch 155: val_loss did not improve from 0.04333
# 19/19 [==============================] - 5s 274ms/step - loss: 0.0320 - val_loss: 0.0516
# Epoch 156/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0292
# Epoch 156: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0292 - val_loss: 0.0505
# Epoch 157/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 157: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0285 - val_loss: 0.0554
# Epoch 158/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0315
# Epoch 158: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 184ms/step - loss: 0.0315 - val_loss: 0.0510
# Epoch 159/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0310
# Epoch 159: val_loss did not improve from 0.04333
# 19/19 [==============================] - 5s 243ms/step - loss: 0.0310 - val_loss: 0.0625
# Epoch 160/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0304
# Epoch 160: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0304 - val_loss: 0.0501
# Epoch 161/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0253
# Epoch 161: val_loss did not improve from 0.04333
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0253 - val_loss: 0.0460
# Epoch 162/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0332
# Epoch 162: val_loss did not improve from 0.04333
# 19/19 [==============================] - 4s 209ms/step - loss: 0.0332 - val_loss: 0.0437
# Epoch 163/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 163: val_loss improved from 0.04333 to 0.04193, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 514ms/step - loss: 0.0233 - val_loss: 0.0419
# Epoch 164/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 164: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0314 - val_loss: 0.0429
# Epoch 165/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 165: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0286 - val_loss: 0.0420
# Epoch 166/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 166: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0233 - val_loss: 0.0490
# Epoch 167/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0232
# Epoch 167: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0232 - val_loss: 0.0590
# Epoch 168/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0235
# Epoch 168: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0235 - val_loss: 0.0547
# Epoch 169/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0220
# Epoch 169: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0220 - val_loss: 0.0580
# Epoch 170/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 170: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 189ms/step - loss: 0.0203 - val_loss: 0.0551
# Epoch 171/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 171: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 196ms/step - loss: 0.0247 - val_loss: 0.0655
# Epoch 172/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 172: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 240ms/step - loss: 0.0211 - val_loss: 0.0606
# Epoch 173/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0241
# Epoch 173: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0241 - val_loss: 0.0583
# Epoch 174/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0278
# Epoch 174: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0278 - val_loss: 0.0464
# Epoch 175/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 175: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 234ms/step - loss: 0.0282 - val_loss: 0.0521
# Epoch 176/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0353
# Epoch 176: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 190ms/step - loss: 0.0353 - val_loss: 0.0503
# Epoch 177/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 177: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0244 - val_loss: 0.0502
# Epoch 178/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 178: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0231 - val_loss: 0.0494
# Epoch 179/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 179: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 258ms/step - loss: 0.0231 - val_loss: 0.0452
# Epoch 180/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0250
# Epoch 180: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0250 - val_loss: 0.0467
# Epoch 181/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 181: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0227 - val_loss: 0.0459
# Epoch 182/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0295
# Epoch 182: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0295 - val_loss: 0.0501
# Epoch 183/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0228
# Epoch 183: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 231ms/step - loss: 0.0228 - val_loss: 0.0497
# Epoch 184/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 184: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0227 - val_loss: 0.0452
# Epoch 185/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 185: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0233 - val_loss: 0.0478
# Epoch 186/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0214
# Epoch 186: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 232ms/step - loss: 0.0214 - val_loss: 0.0450
# Epoch 187/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 187: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0185 - val_loss: 0.0499
# Epoch 188/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 188: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0204 - val_loss: 0.0493
# Epoch 189/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 189: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0178 - val_loss: 0.0438
# Epoch 190/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 190: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0197 - val_loss: 0.0492
# Epoch 191/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0237
# Epoch 191: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0237 - val_loss: 0.0499
# Epoch 192/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 192: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0269 - val_loss: 0.0551
# Epoch 193/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 193: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 230ms/step - loss: 0.0157 - val_loss: 0.0547
# Epoch 194/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 194: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 208ms/step - loss: 0.0227 - val_loss: 0.0524
# Epoch 195/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0217
# Epoch 195: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0217 - val_loss: 0.0511
# Epoch 196/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 196: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0186 - val_loss: 0.0536
# Epoch 197/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 197: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0185 - val_loss: 0.0535
# Epoch 198/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 198: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0215 - val_loss: 0.0543
# Epoch 199/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 199: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0164 - val_loss: 0.0527
# Epoch 200/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 200: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0167 - val_loss: 0.0586
# Epoch 201/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 201: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 239ms/step - loss: 0.0198 - val_loss: 0.0606
# Epoch 202/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 202: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 186ms/step - loss: 0.0142 - val_loss: 0.0641
# Epoch 203/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 203: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0183 - val_loss: 0.0623
# Epoch 204/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0173
# Epoch 204: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0173 - val_loss: 0.0627
# Epoch 205/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 205: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 186ms/step - loss: 0.0142 - val_loss: 0.0625
# Epoch 206/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0193
# Epoch 206: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0193 - val_loss: 0.0579
# Epoch 207/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0177
# Epoch 207: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 174ms/step - loss: 0.0177 - val_loss: 0.0588
# Epoch 208/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 208: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 273ms/step - loss: 0.0120 - val_loss: 0.0655
# Epoch 209/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 209: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0160 - val_loss: 0.0573
# Epoch 210/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 210: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0152 - val_loss: 0.0611
# Epoch 211/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 211: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 198ms/step - loss: 0.0157 - val_loss: 0.0556
# Epoch 212/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0153
# Epoch 212: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 227ms/step - loss: 0.0153 - val_loss: 0.0573
# Epoch 213/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 213: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0168 - val_loss: 0.0573
# Epoch 214/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 214: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 192ms/step - loss: 0.0167 - val_loss: 0.0579
# Epoch 215/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0136
# Epoch 215: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 248ms/step - loss: 0.0136 - val_loss: 0.0567
# Epoch 216/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 216: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 180ms/step - loss: 0.0189 - val_loss: 0.0559
# Epoch 217/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 217: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0166 - val_loss: 0.0583
# Epoch 218/400
# ...
# 19/19 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 327: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0074 - val_loss: 0.0563
# Epoch 328/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 328: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0082 - val_loss: 0.0577
# Epoch 329/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 329: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0077 - val_loss: 0.0583
# Epoch 330/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 330: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0070 - val_loss: 0.0551
# Epoch 331/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 331: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 205ms/step - loss: 0.0070 - val_loss: 0.0579
# Epoch 332/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 332: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 237ms/step - loss: 0.0075 - val_loss: 0.0536
# Epoch 333/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 333: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0074 - val_loss: 0.0562
# Epoch 334/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 334: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0061 - val_loss: 0.0560
# Epoch 335/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 335: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 262ms/step - loss: 0.0076 - val_loss: 0.0576
# Epoch 336/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 336: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0067 - val_loss: 0.0546
# Epoch 337/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 337: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0075 - val_loss: 0.0587
# Epoch 338/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 338: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 186ms/step - loss: 0.0099 - val_loss: 0.0591
# Epoch 339/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 339: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 251ms/step - loss: 0.0070 - val_loss: 0.0570
# Epoch 340/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 340: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 199ms/step - loss: 0.0072 - val_loss: 0.0585
# Epoch 341/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 341: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0070 - val_loss: 0.0547
# Epoch 342/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 342: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 256ms/step - loss: 0.0066 - val_loss: 0.0622
# Epoch 343/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 343: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 180ms/step - loss: 0.0090 - val_loss: 0.0584
# Epoch 344/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 344: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0092 - val_loss: 0.0563
# Epoch 345/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 345: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0061 - val_loss: 0.0537
# Epoch 346/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 346: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0074 - val_loss: 0.0550
# Epoch 347/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 347: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0071 - val_loss: 0.0533
# Epoch 348/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 348: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0073 - val_loss: 0.0573
# Epoch 349/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 349: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0078 - val_loss: 0.0544
# Epoch 350/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 350: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 213ms/step - loss: 0.0057 - val_loss: 0.0573
# Epoch 351/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 351: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0083 - val_loss: 0.0563
# Epoch 352/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 352: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0072 - val_loss: 0.0583
# Epoch 353/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 353: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0056 - val_loss: 0.0572
# Epoch 354/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 354: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0062 - val_loss: 0.0661
# Epoch 355/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 355: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0064 - val_loss: 0.0577
# Epoch 356/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 356: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 185ms/step - loss: 0.0075 - val_loss: 0.0584
# Epoch 357/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 357: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0103 - val_loss: 0.0588
# Epoch 358/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0095
# Epoch 358: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 182ms/step - loss: 0.0095 - val_loss: 0.0648
# Epoch 359/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 359: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0071 - val_loss: 0.0580
# Epoch 360/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 360: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 246ms/step - loss: 0.0074 - val_loss: 0.0553
# Epoch 361/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 361: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 192ms/step - loss: 0.0094 - val_loss: 0.0518
# Epoch 362/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 362: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0082 - val_loss: 0.0529
# Epoch 363/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 363: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0086 - val_loss: 0.0563
# Epoch 364/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 364: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0078 - val_loss: 0.0611
# Epoch 365/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 365: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0055 - val_loss: 0.0578
# Epoch 366/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 366: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0069 - val_loss: 0.0580
# Epoch 367/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 367: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0058 - val_loss: 0.0575
# Epoch 368/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 368: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 213ms/step - loss: 0.0083 - val_loss: 0.0600
# Epoch 369/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 369: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0060 - val_loss: 0.0587
# Epoch 370/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 370: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0065 - val_loss: 0.0609
# Epoch 371/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 371: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 264ms/step - loss: 0.0071 - val_loss: 0.0629
# Epoch 372/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 372: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0066 - val_loss: 0.0635
# Epoch 373/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 373: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0046 - val_loss: 0.0568
# Epoch 374/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 374: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 206ms/step - loss: 0.0059 - val_loss: 0.0554
# Epoch 375/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 375: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 229ms/step - loss: 0.0066 - val_loss: 0.0551
# Epoch 376/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 376: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0083 - val_loss: 0.0572
# Epoch 377/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 377: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0055 - val_loss: 0.0568
# Epoch 378/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 378: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0069 - val_loss: 0.0525
# Epoch 379/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 379: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0057 - val_loss: 0.0505
# Epoch 380/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 380: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0063 - val_loss: 0.0583
# Epoch 381/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 381: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0081 - val_loss: 0.0594
# Epoch 382/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 382: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 251ms/step - loss: 0.0091 - val_loss: 0.0605
# Epoch 383/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 383: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0082 - val_loss: 0.0561
# Epoch 384/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 384: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 181ms/step - loss: 0.0058 - val_loss: 0.0568
# Epoch 385/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 385: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0066 - val_loss: 0.0560
# Epoch 386/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 386: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 192ms/step - loss: 0.0082 - val_loss: 0.0577
# Epoch 387/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 387: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0049 - val_loss: 0.0505
# Epoch 388/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 388: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0087 - val_loss: 0.0553
# Epoch 389/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 389: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 265ms/step - loss: 0.0067 - val_loss: 0.0555
# Epoch 390/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 390: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0048 - val_loss: 0.0560
# Epoch 391/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 391: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 180ms/step - loss: 0.0074 - val_loss: 0.0563
# Epoch 392/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 392: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 209ms/step - loss: 0.0048 - val_loss: 0.0531
# Epoch 393/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 393: val_loss did not improve from 0.04193
# 19/19 [==============================] - 4s 229ms/step - loss: 0.0073 - val_loss: 0.0547
# Epoch 394/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 394: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0052 - val_loss: 0.0541
# Epoch 395/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 395: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0050 - val_loss: 0.0583
# Epoch 396/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 396: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0075 - val_loss: 0.0552
# Epoch 397/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 397: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 178ms/step - loss: 0.0079 - val_loss: 0.0619
# Epoch 398/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 398: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0072 - val_loss: 0.0519
# Epoch 399/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 399: val_loss did not improve from 0.04193
# 19/19 [==============================] - 3s 176ms/step - loss: 0.0049 - val_loss: 0.0543
# Epoch 400/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 400: val_loss did not improve from 0.04193
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0061 - val_loss: 0.0545
# Training time: 0:32:26.364472

# %%
print(tracemalloc.get_traced_memory())
# stopping the library
tracemalloc.stop()
# Out:
# (136316104, 137809617)

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.004568102303892374
# Validation loss 0.04193420708179474

# %%
# Plot the prediction of the model for the training and validation sets
import tensorflow as tf
from keras.models import load_model
from keras.initializers import glorot_uniform
# Load the best model's weights
best_model = load_model('/content/drive/My Drive/new_kimore/modelEX1.h5', custom_objects={'TCN': TCN, 'GlorotUniform': glorot_uniform()})

pred_train = best_model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = best_model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.2,1.2])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(valid_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.2,1.2])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()

plt.show()
# Out:
# 4/4 [==============================] - 15s 102ms/step
# 2/2 [==============================] - 0s 48ms/step

# %%
test_dev = abs(pred_test-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
#MSE
MSE=mean_squared_error(pred_test, test_y)
#MAPE
#P1 = 19*pred_test + 31;
#P2 = 19*test_y+31;
MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
print('MSE:',MSE)
rms_dev = np.sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
print('MAPE:',MAPE)
# Out:
# MSE: 0.06315464705782882
# Mean absolute deviation: 0.1946876766085663
# RMS deviation: 0.25130588345247473
# MAPE: inf
