# %%
pip install keras-tcn
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Collecting tensorflow-addons (from keras-tcn)
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->keras-tcn)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)
# Installing collected packages: typeguard, tensorflow-addons, keras-tcn
# Successfully installed keras-tcn-3.5.0 tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences
timesteps = 104
# dimension of data sequences
n_dim = 80
batch_size = 2

# %%
drive.mount('/content/drive')
dir_name_samples ='/content/drive/My Drive/new_kimore/Preprocessed_data/Exercise1_data.csv'
dir_name_labels ='/content/drive/My Drive/new_kimore/Preprocessed_data/Labels_ex1.csv'
import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive

# %%
X_values = pd.read_csv(dir_name_samples, delimiter=',', encoding='utf-8')
print(X_values.shape)
# # Initialize the MinMaxScaler

# scaler = StandardScaler()
# # Fit and transform the data using the scaler
# scaled_data = scaler.fit_transform(X_values)

# # Create a new DataFrame with the scaled data
# scaled_df = pd.DataFrame(scaled_data, columns=X_values.columns)


# # Extract the underlying NumPy array
# numpy_2d_array = scaled_df.values
# #numpy_2d_array = X_values.values
# # Reshape the 2D array into a 3D array (207, 100, 80)
# X_train = numpy_2d_array.reshape(207, 100, 80)
# # The temporal pyramid requires that the length of the data sequences is divisible by 8.
# # The original length was 100 time steps, so we will repeat the first and last 2 data vectors to obtain sequences with 104 time steps
# X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
numpy_2d_array = X_values.values
X_train = numpy_2d_array.reshape(213, 100, 80)
# Calculate the mean along the specified axes (axis=0, axis=1, and axis=2) to obtain a mean value for the entire array
mean_value = X_train.mean(axis=(0, 1, 2))

# Subtract the mean from the entire array to achieve zero mean
X_train -= mean_value

# Calculate the maximum and minimum values in the array
max_value = X_train.max()
min_value = X_train.min()

# Normalize the array to a range between -1 and 1
data = 2 * (X_train - min_value) / (max_value - min_value) - 1
smoothed_data = np.empty_like(X_train)
for channel in range(80):
    smoothed_data[:, :, channel] = gaussian_filter1d(data[:, :, channel], sigma=5)
X_train=smoothed_data
X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
#-----------labels------------------------------------
Y_values = pd.read_csv(dir_name_labels)
#change the secon column to the labels
y_values= Y_values['EX1'].values

reshaped_data_y = y_values.reshape(213, 1)
# Fit and transform the data using the scaler
#scaler2 = MinMaxScaler(feature_range=(0, 1))
#y_train = scaler2.fit_transform(reshaped_data_y)
min_value = np.min(reshaped_data_y)
max_value = np.max(reshaped_data_y)

# Normalize the vector to be in the range [-1, 1]
y_train = (reshaped_data_y - min_value) / (max_value - min_value)

print('Training sequences dimension', X_train)
print('Training labels dimension', y_train)
# Out:
# (21300, 80)
# Training sequences dimension [[[-0.0161619  -0.01031645 -0.00666048 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.01607827 -0.0103141  -0.00665525 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.0161619  -0.01031645 -0.00666048 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00726294 -0.00880858 -0.00572311 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00697359 -0.00876007 -0.00570275 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.007165   -0.00879241 -0.00571619 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00990915 -0.00655313 -0.00597644 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00992924 -0.00656738 -0.00598018 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00990915 -0.00655313 -0.00597644 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00164321 -0.00689076 -0.00536924 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00176402 -0.00685255 -0.00537985 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00168268 -0.00687817 -0.00537283 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00621833 -0.00618291 -0.00549057 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00636479 -0.00619827 -0.00549802 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00621833 -0.00618291 -0.00549057 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00088778 -0.00436638 -0.00551589 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00086231 -0.0043763  -0.00551431 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00087756 -0.0043695  -0.00551527 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  ...
#
#  [[-0.02121325 -0.00582086 -0.00616994 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.02119875 -0.00581283 -0.00616874 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.02121325 -0.00582086 -0.00616994 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00702552 -0.00489937 -0.00603099 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00654121 -0.00487431 -0.00603277 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00686291 -0.00489016 -0.00603167 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00031776 -0.00627259 -0.00575816 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00040594 -0.00624775 -0.00577212 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00031776 -0.00627259 -0.00575816 ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.00539327 -0.00563069 -0.00538058 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00530069 -0.00569648 -0.005344   ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00536083 -0.00565384 -0.00536813 ... -0.00600993 -0.00600993
#    -0.00600993]]
#
#  [[-0.00595845 -0.00838938 -0.006219   ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00594273 -0.00838813 -0.00621095 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.00595845 -0.00838938 -0.006219   ... -0.00600993 -0.00600993
#    -0.00600993]
#   ...
#   [-0.01023785 -0.00647186 -0.00623266 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.01024414 -0.00655752 -0.00625003 ... -0.00600993 -0.00600993
#    -0.00600993]
#   [-0.01023977 -0.00650194 -0.00623867 ... -0.00600993 -0.00600993
#    -0.00600993]]]
# Training labels dimension [[0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [0.9537037 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.89814815]
#  [0.89814815]
#  [0.89814815]
#  [0.83333333]
#  [0.83333333]
#  [0.83333333]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.71296296]
#  [0.71296296]
#  [0.71296296]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [0.98148148]
#  [0.98148148]
#  [0.98148148]
#  [0.84259259]
#  [0.84259259]
#  [0.84259259]
#  [0.74074074]
#  [0.74074074]
#  [0.74074074]
#  [0.82407407]
#  [0.82407407]
#  [0.82407407]
#  [0.77777778]
#  [0.77777778]
#  [0.77777778]
#  [0.72222222]
#  [0.72222222]
#  [0.72222222]
#  [0.77777778]
#  [0.77777778]
#  [0.77777778]
#  [0.55555556]
#  [0.55555556]
#  [0.55555556]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.72222222]
#  [0.72222222]
#  [0.72222222]
#  [0.7962963 ]
#  [0.7962963 ]
#  [0.7962963 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.86111111]
#  [0.86111111]
#  [0.86111111]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.66666667]
#  [0.66666667]
#  [0.66666667]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.80555556]
#  [0.80555556]
#  [0.80555556]
#  [0.85185185]
#  [0.85185185]
#  [0.85185185]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.91666667]
#  [0.91666667]
#  [0.91666667]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.97222222]
#  [0.75      ]
#  [0.75      ]
#  [0.75      ]
#  [0.66666667]
#  [0.66666667]
#  [0.66666667]
#  [0.39472448]
#  [0.39472448]
#  [0.39472448]
#  [0.5372148 ]
#  [0.5372148 ]
#  [0.5372148 ]
#  [0.84259259]
#  [0.84259259]
#  [0.84259259]
#  [0.88888889]
#  [0.88888889]
#  [0.88888889]
#  [0.87037037]
#  [0.87037037]
#  [0.87037037]
#  [0.73148148]
#  [0.73148148]
#  [0.73148148]
#  [0.94444444]
#  [0.94444444]
#  [0.94444444]
#  [0.36111111]
#  [0.36111111]
#  [0.36111111]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.22222222]
#  [0.22222222]
#  [0.22222222]
#  [0.90740741]
#  [0.90740741]
#  [0.90740741]
#  [0.5       ]
#  [0.5       ]
#  [0.5       ]
#  [0.72222222]
#  [0.72222222]
#  [0.72222222]
#  [0.56411612]
#  [0.56411612]
#  [0.56411612]
#  [0.01851852]
#  [0.01851852]
#  [0.01851852]
#  [0.60185185]
#  [0.60185185]
#  [0.60185185]
#  [0.62962963]
#  [0.62962963]
#  [0.62962963]
#  [0.61111111]
#  [0.61111111]
#  [0.61111111]
#  [0.37962963]
#  [0.37962963]
#  [0.37962963]
#  [0.63888889]
#  [0.63888889]
#  [0.63888889]
#  [0.36111111]
#  [0.36111111]
#  [0.36111111]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.55555556]
#  [0.55555556]
#  [0.55555556]
#  [0.83333333]
#  [0.83333333]
#  [0.83333333]
#  [0.33333333]
#  [0.33333333]
#  [0.33333333]
#  [0.67807648]
#  [0.67807648]
#  [0.67807648]
#  [0.35185185]
#  [0.35185185]
#  [0.35185185]
#  [0.61111111]
#  [0.61111111]
#  [0.61111111]
#  [0.34259259]
#  [0.34259259]
#  [0.34259259]
#  [0.5462963 ]
#  [0.5462963 ]
#  [0.5462963 ]
#  [1.        ]
#  [1.        ]
#  [1.        ]]

# %%
# Split the data into training and validation sets
train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.3)
# Split your dataset into a training set (60%) and a combined validation-testing set (40%)
train_x, X_val_test, train_y, y_val_test = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

# Split the combined validation-testing set (40%) into a validation set (20%) and a test set (20%)
valid_x, test_x, valid_y, test_y = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# Now, you have X_train, y_train for training (60%), X_val, y_val for validation (20%), and X_test, y_test for testing (20%)
print('Training data', train_x.shape)
print('Validation data', valid_x.shape)
print('Training label', train_y.shape)
print('Validation label', valid_y.shape)
# Out:
# Training data (127, 104, 80)
# Validation data (43, 104, 80)
# Training label (127, 1)
# Validation label (43, 1)

# %%
# Plot the first and last sequences in the training and validation data
plt.figure(figsize = (14,8))
plt.subplot(2,2,1)
plt.plot(train_x[0])
plt.subplot(2,2,2)
plt.plot(train_x[-1])
plt.subplot(2,2,3)
plt.plot(valid_x[0])
plt.subplot(2,2,4)
plt.plot(valid_x[-1])
plt.tight_layout()
plt.show()

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)
trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)
trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)
trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]
trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]
trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
trainx =  train_x
validx =  valid_x
testx =  test_x

# %%
import matplotlib.patches as mpatches
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(trainx[0,:,0:16], color='red')
plt.plot(trainx[0,:,16:32], color='blue')
plt.plot(trainx[0,:,32:48], color='green')
plt.plot(trainx[0,:,48:64], color='orange')
plt.plot(trainx[0,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('First Train Sequence')
plt.subplot(1,2,2)
plt.plot(trainx[-1,:,0:16], color='red')
plt.plot(trainx[-1,:,16:32], color='blue')
plt.plot(trainx[-1,:,32:48], color='green')
plt.plot(trainx[-1,:,48:64], color='orange')
plt.plot(trainx[-1,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('Last Train Sequence')
plt.tight_layout()
plt.show()

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
n_dim = 80 # dimension after reordering the data into body parts
n_dim1 = 16 # dimension of indiviudal body parts
n_dim2 = 16
n_dim3 = 16 # legs dimension
# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps,n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 16:32])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 32:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:64])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 64:80])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 16:32])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 32:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:64])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 64:80])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 16:32])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 32:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:64])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 64:80])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 16:32])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 32:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:64])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'linear')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 104, 80)]            0         []
#
#  half_scale (InputLayer)     [(None, 52, 80)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 26, 80)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 13, 80)]             0         []
#
#  lambda_20 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_25 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_30 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_35 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_21 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_26 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_31 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_36 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_22 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_27 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_32 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_37 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_23 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_28 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_33 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_38 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_24 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_29 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_34 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_39 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  tcn_23 (TCN)                (None, 104, 12)              5676      ['lambda_20[0][0]']
#
#  tcn_24 (TCN)                (None, 52, 12)               5676      ['lambda_25[0][0]']
#
#  tcn_25 (TCN)                (None, 26, 12)               5676      ['lambda_30[0][0]']
#
#  tcn_26 (TCN)                (None, 13, 12)               5676      ['lambda_35[0][0]']
#
#  tcn_27 (TCN)                (None, 104, 12)              5676      ['lambda_21[0][0]']
#
#  tcn_28 (TCN)                (None, 52, 12)               5676      ['lambda_26[0][0]']
#
#  tcn_29 (TCN)                (None, 26, 12)               5676      ['lambda_31[0][0]']
#
#  tcn_30 (TCN)                (None, 13, 12)               5676      ['lambda_36[0][0]']
#
#  tcn_31 (TCN)                (None, 104, 12)              5676      ['lambda_22[0][0]']
#
#  tcn_32 (TCN)                (None, 52, 12)               5676      ['lambda_27[0][0]']
#
#  tcn_33 (TCN)                (None, 26, 12)               5676      ['lambda_32[0][0]']
#
#  tcn_34 (TCN)                (None, 13, 12)               5676      ['lambda_37[0][0]']
#
#  tcn_35 (TCN)                (None, 104, 12)              5676      ['lambda_23[0][0]']
#
#  tcn_36 (TCN)                (None, 52, 12)               5676      ['lambda_28[0][0]']
#
#  tcn_37 (TCN)                (None, 26, 12)               5676      ['lambda_33[0][0]']
#
#  tcn_38 (TCN)                (None, 13, 12)               5676      ['lambda_38[0][0]']
#
#  tcn_39 (TCN)                (None, 104, 12)              5676      ['lambda_24[0][0]']
#
#  tcn_40 (TCN)                (None, 52, 12)               5676      ['lambda_29[0][0]']
#
#  tcn_41 (TCN)                (None, 26, 12)               5676      ['lambda_34[0][0]']
#
#  tcn_42 (TCN)                (None, 13, 12)               5676      ['lambda_39[0][0]']
#
#  concatenate_6 (Concatenate  (None, 195, 12)              0         ['tcn_23[0][0]',
#  )                                                                   'tcn_24[0][0]',
#                                                                      'tcn_25[0][0]',
#                                                                      'tcn_26[0][0]']
#
#  concatenate_7 (Concatenate  (None, 195, 12)              0         ['tcn_27[0][0]',
#  )                                                                   'tcn_28[0][0]',
#                                                                      'tcn_29[0][0]',
#                                                                      'tcn_30[0][0]']
#
#  concatenate_8 (Concatenate  (None, 195, 12)              0         ['tcn_31[0][0]',
#  )                                                                   'tcn_32[0][0]',
#                                                                      'tcn_33[0][0]',
#                                                                      'tcn_34[0][0]']
#
#  concatenate_9 (Concatenate  (None, 195, 12)              0         ['tcn_35[0][0]',
#  )                                                                   'tcn_36[0][0]',
#                                                                      'tcn_37[0][0]',
#                                                                      'tcn_38[0][0]']
#
#  concatenate_10 (Concatenat  (None, 195, 12)              0         ['tcn_39[0][0]',
#  e)                                                                  'tcn_40[0][0]',
#                                                                      'tcn_41[0][0]',
#                                                                      'tcn_42[0][0]']
#
#  concatenate_11 (Concatenat  (None, 195, 60)              0         ['concatenate_6[0][0]',
#  e)                                                                  'concatenate_7[0][0]',
#                                                                      'concatenate_8[0][0]',
#                                                                      'concatenate_9[0][0]',
#                                                                      'concatenate_10[0][0]']
#
#  tcn_43 (TCN)                (None, 195, 12)              6012      ['concatenate_11[0][0]']
#
#  tcn_44 (TCN)                (None, 195, 8)               1176      ['tcn_43[0][0]']
#
#  tcn_45 (TCN)                (None, 6)                    546       ['tcn_44[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    7         ['tcn_45[0][0]']
#
# ==================================================================================================
# Total params: 121261 (473.68 KB)
# Trainable params: 121165 (473.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
import tensorflow as tf
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
    input_shapes = [tf.TensorSpec(shape=input_shape[1:], dtype=tf.float32) for input_shape in model.input_shape]
    forward_pass = tf.function(model.call, input_signature=[input_shapes])
    graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
    flops = graph_info.total_float_ops
    return flops

flops = get_flops(model)
macs = flops / 2
print(f"MACs: {macs:,}")
print(f"FLOPs: {flops:,}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f4345f0471f1> in <cell line: 12>()
#      10     return flops
#      11
# ---> 12 flops = get_flops(model)
#      13 macs = flops / 2
#      14 print(f"MACs: {macs:,}")
#
# <ipython-input-13-f4345f0471f1> in get_flops(model)
#       6     input_shapes = [tf.TensorSpec(shape=input_shape[1:], dtype=tf.float32) for input_shape in model.input_shape]
#       7     forward_pass = tf.function(model.call, input_signature=[input_shapes])
# ----> 8     graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
#       9     flops = graph_info.total_float_ops
#      10     return flops
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1225   def get_concrete_function(self, *args, **kwargs):
#    1226     # Implements PolymorphicFunction.get_concrete_function.
# -> 1227     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1228     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1229     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1195       if self._variable_creation_config is None:
#    1196         initializers = []
# -> 1197         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1198         self._initialize_uninitialized_variables(initializers)
#    1199
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     693     )
#     694     # Force the definition of the function for these arguments
# --> 695     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696         args, kwds, self._variable_creation_config
#     697     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     596         # the function a weak reference to itself to avoid a reference cycle.
#     597         with OptionalXlaContext(compile_with_xla):
# --> 598           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599         return out
#     600
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      50     except Exception as e:  # pylint:disable=broad-except
#      51       if hasattr(e, "ag_error_metadata"):
# ---> 52         raise e.ag_error_metadata.to_exception(e)
#      53       else:
#      54         raise
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in tf__call(self, inputs, training, mask)
#      27                 try:
#      28                     do_return = True
# ---> 29                     retval_ = ag__.converted_call(ag__.ld(self)._run_internal_graph, (ag__.ld(inputs),), dict(training=ag__.ld(training), mask=ag__.ld(mask)), fscope)
#      30                 except:
#      31                     do_return = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     670
#     671                 args, kwargs = node.map_arguments(tensor_dict)
# --> 672                 outputs = node.layer(*args, **kwargs)
#     673
#     674                 # Update tensor_dict.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# <ipython-input-12-adac8c3712c8> in <lambda>(x)
#      39 seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 32:48])(seq_input_8)
#      40 seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:64])(seq_input_8)
# ---> 41 seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)
#      42
#      43 concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 515, in call  *
#         return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph  **
#         outputs = node.layer(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "<ipython-input-12-adac8c3712c8>", line 41, in <lambda>
#         seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)
#
#     ValueError: Exception encountered when calling layer 'lambda_19' (type Lambda).
#
#     Index out of range using input dim 2; input has only 2 dims for '{{node lambda_19/strided_slice}} = StridedSlice[Index=DT_INT32, T=DT_FLOAT, begin_mask=3, ellipsis_mask=0, end_mask=3, new_axis_mask=0, shrink_axis_mask=0](inputs_3, lambda_19/strided_slice/stack, lambda_19/strided_slice/stack_1, lambda_19/strided_slice/stack_2)' with input shapes: [13,80], [3], [3], [3] and with computed input tensors: input[3] = <1 1 1>.
#
#     Call arguments received by layer 'lambda_19' (type Lambda):
#       • inputs=tf.Tensor(shape=(13, 80), dtype=float32)
#       • mask=None
#       • training=None

# %%
pip install keras-flops
# Out:
# Collecting keras-flops
#   Downloading keras_flops-0.1.2-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: tensorflow<3.0,>=2.2 in /usr/local/lib/python3.10/dist-packages (from keras-flops) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<3.0,>=2.2->keras-flops) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<3.0,>=2.2->keras-flops) (3.2.2)
# Installing collected packages: keras-flops
# Successfully installed keras-flops-0.1.2

# %%
import tensorflow as tf
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  print(tf.TensorSpec(shape=(1,) + model.input_shape[1:]))
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

HEIGHT = 224
WIDTH = 224
CHANNELS = 3

model = tf.keras.Sequential([
    tf.keras.Input(shape=(HEIGHT, WIDTH, CHANNELS), name='model_input'),
    tf.keras.layers.Conv2D(filters=3, kernel_size=(1, 1), padding='same', groups=3, activation='linear', name='DepthwiseConv2D_1'),
    tf.keras.layers.Dense(units=1, activation='relu', name='PointwiseConv2D_1')
    ])

# model.compile(optimizer='adam', loss='bce', metrics=['accuracy'])

flops = get_flops(model)
macs = flops / 2
print(f"MACs: {macs:,}")
print(f"FLOPs: {flops:,}")
# Out:
# TensorSpec(shape=(1, 224, 224, 3), dtype=tf.float32, name=None)
# MACs: 250,880.0
# FLOPs: 501,760

# %%
import tensorflow as tf
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
    input_shapes = [tf.TensorSpec(shape=input_shape[1:], dtype=tf.float32) for input_shape in model.input_shape]
    forward_pass = tf.function(model.call, input_signature=[input_shapes])
    graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
    flops = graph_info.total_float_ops
    return flops

flops = get_flops(model)
macs = flops / 2
print(f"MACs: {macs:,}")
print(f"FLOPs: {flops:,}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f4345f0471f1> in <cell line: 12>()
#      10     return flops
#      11
# ---> 12 flops = get_flops(model)
#      13 macs = flops / 2
#      14 print(f"MACs: {macs:,}")
#
# <ipython-input-14-f4345f0471f1> in get_flops(model)
#       6     input_shapes = [tf.TensorSpec(shape=input_shape[1:], dtype=tf.float32) for input_shape in model.input_shape]
#       7     forward_pass = tf.function(model.call, input_signature=[input_shapes])
# ----> 8     graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
#       9     flops = graph_info.total_float_ops
#      10     return flops
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in get_concrete_function(self, *args, **kwargs)
#    1225   def get_concrete_function(self, *args, **kwargs):
#    1226     # Implements PolymorphicFunction.get_concrete_function.
# -> 1227     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1228     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1229     return concrete
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1195       if self._variable_creation_config is None:
#    1196         initializers = []
# -> 1197         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1198         self._initialize_uninitialized_variables(initializers)
#    1199
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _initialize(self, args, kwds, add_initializers_to)
#     693     )
#     694     # Force the definition of the function for these arguments
# --> 695     self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696         args, kwds, self._variable_creation_config
#     697     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     596         # the function a weak reference to itself to avoid a reference cycle.
#     597         with OptionalXlaContext(compile_with_xla):
# --> 598           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599         return out
#     600
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      50     except Exception as e:  # pylint:disable=broad-except
#      51       if hasattr(e, "ag_error_metadata"):
# ---> 52         raise e.ag_error_metadata.to_exception(e)
#      53       else:
#      54         raise
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in tf__call(self, inputs, training, mask)
#      27                 try:
#      28                     do_return = True
# ---> 29                     retval_ = ag__.converted_call(ag__.ld(self)._run_internal_graph, (ag__.ld(inputs),), dict(training=ag__.ld(training), mask=ag__.ld(mask)), fscope)
#      30                 except:
#      31                     do_return = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     670
#     671                 args, kwargs = node.map_arguments(tensor_dict)
# --> 672                 outputs = node.layer(*args, **kwargs)
#     673
#     674                 # Update tensor_dict.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# <ipython-input-13-adac8c3712c8> in <lambda>(x)
#      39 seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 32:48])(seq_input_8)
#      40 seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:64])(seq_input_8)
# ---> 41 seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)
#      42
#      43 concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 515, in call  *
#         return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph  **
#         outputs = node.layer(*args, **kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "<ipython-input-13-adac8c3712c8>", line 41, in <lambda>
#         seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)
#
#     ValueError: Exception encountered when calling layer 'lambda_19' (type Lambda).
#
#     Index out of range using input dim 2; input has only 2 dims for '{{node lambda_19/strided_slice}} = StridedSlice[Index=DT_INT32, T=DT_FLOAT, begin_mask=3, ellipsis_mask=0, end_mask=3, new_axis_mask=0, shrink_axis_mask=0](inputs_3, lambda_19/strided_slice/stack, lambda_19/strided_slice/stack_1, lambda_19/strided_slice/stack_2)' with input shapes: [13,80], [3], [3], [3] and with computed input tensors: input[3] = <1 1 1>.
#
#     Call arguments received by layer 'lambda_19' (type Lambda):
#       • inputs=tf.Tensor(shape=(13, 80), dtype=float32)
#       • mask=None
#       • training=None

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX1.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 19/19 [==============================] - ETA: 0s - loss: 14.1836
# Epoch 1: val_loss improved from inf to 32.89967, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 265s 2s/step - loss: 14.1836 - val_loss: 32.8997
# Epoch 2/400
# 19/19 [==============================] - ETA: 0s - loss: 0.2992
# Epoch 2: val_loss improved from 32.89967 to 1.98755, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 499ms/step - loss: 0.2992 - val_loss: 1.9876
# Epoch 3/400
# 19/19 [==============================] - ETA: 0s - loss: 0.2587
# Epoch 3: val_loss improved from 1.98755 to 0.29486, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 435ms/step - loss: 0.2587 - val_loss: 0.2949
# Epoch 4/400
# 19/19 [==============================] - ETA: 0s - loss: 0.2581
# Epoch 4: val_loss improved from 0.29486 to 0.19584, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 437ms/step - loss: 0.2581 - val_loss: 0.1958
# Epoch 5/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1874
# Epoch 5: val_loss did not improve from 0.19584
# 19/19 [==============================] - 3s 171ms/step - loss: 0.1874 - val_loss: 0.2217
# Epoch 6/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1875
# Epoch 6: val_loss did not improve from 0.19584
# 19/19 [==============================] - 5s 249ms/step - loss: 0.1875 - val_loss: 0.2471
# Epoch 7/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1949
# Epoch 7: val_loss did not improve from 0.19584
# 19/19 [==============================] - 3s 159ms/step - loss: 0.1949 - val_loss: 0.2580
# Epoch 8/400
# 19/19 [==============================] - ETA: 0s - loss: 0.2422
# Epoch 8: val_loss did not improve from 0.19584
# 19/19 [==============================] - 4s 204ms/step - loss: 0.2422 - val_loss: 0.2486
# Epoch 9/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1821
# Epoch 9: val_loss did not improve from 0.19584
# 19/19 [==============================] - 5s 289ms/step - loss: 0.1821 - val_loss: 0.2386
# Epoch 10/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1636
# Epoch 10: val_loss did not improve from 0.19584
# 19/19 [==============================] - 3s 170ms/step - loss: 0.1636 - val_loss: 0.2062
# Epoch 11/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1631
# Epoch 11: val_loss improved from 0.19584 to 0.18781, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 419ms/step - loss: 0.1631 - val_loss: 0.1878
# Epoch 12/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1433
# Epoch 12: val_loss improved from 0.18781 to 0.17900, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 472ms/step - loss: 0.1433 - val_loss: 0.1790
# Epoch 13/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1493
# Epoch 13: val_loss improved from 0.17900 to 0.16564, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 453ms/step - loss: 0.1493 - val_loss: 0.1656
# Epoch 14/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1453
# Epoch 14: val_loss did not improve from 0.16564
# 19/19 [==============================] - 3s 160ms/step - loss: 0.1453 - val_loss: 0.1663
# Epoch 15/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1293
# Epoch 15: val_loss improved from 0.16564 to 0.16176, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 427ms/step - loss: 0.1293 - val_loss: 0.1618
# Epoch 16/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1258
# Epoch 16: val_loss improved from 0.16176 to 0.15288, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 454ms/step - loss: 0.1258 - val_loss: 0.1529
# Epoch 17/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1063
# Epoch 17: val_loss improved from 0.15288 to 0.14779, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 472ms/step - loss: 0.1063 - val_loss: 0.1478
# Epoch 18/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1242
# Epoch 18: val_loss did not improve from 0.14779
# 19/19 [==============================] - 3s 159ms/step - loss: 0.1242 - val_loss: 0.1493
# Epoch 19/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1055
# Epoch 19: val_loss improved from 0.14779 to 0.12842, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 439ms/step - loss: 0.1055 - val_loss: 0.1284
# Epoch 20/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1045
# Epoch 20: val_loss improved from 0.12842 to 0.12121, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 417ms/step - loss: 0.1045 - val_loss: 0.1212
# Epoch 21/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1106
# Epoch 21: val_loss improved from 0.12121 to 0.11255, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 473ms/step - loss: 0.1106 - val_loss: 0.1125
# Epoch 22/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1213
# Epoch 22: val_loss did not improve from 0.11255
# 19/19 [==============================] - 3s 159ms/step - loss: 0.1213 - val_loss: 0.1196
# Epoch 23/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1022
# Epoch 23: val_loss improved from 0.11255 to 0.10513, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 479ms/step - loss: 0.1022 - val_loss: 0.1051
# Epoch 24/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1001
# Epoch 24: val_loss improved from 0.10513 to 0.10160, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 431ms/step - loss: 0.1001 - val_loss: 0.1016
# Epoch 25/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1154
# Epoch 25: val_loss improved from 0.10160 to 0.09038, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 495ms/step - loss: 0.1154 - val_loss: 0.0904
# Epoch 26/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1289
# Epoch 26: val_loss did not improve from 0.09038
# 19/19 [==============================] - 3s 162ms/step - loss: 0.1289 - val_loss: 0.0961
# Epoch 27/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1281
# Epoch 27: val_loss improved from 0.09038 to 0.07915, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 468ms/step - loss: 0.1281 - val_loss: 0.0792
# Epoch 28/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1091
# Epoch 28: val_loss improved from 0.07915 to 0.07683, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 410ms/step - loss: 0.1091 - val_loss: 0.0768
# Epoch 29/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1004
# Epoch 29: val_loss improved from 0.07683 to 0.07455, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 480ms/step - loss: 0.1004 - val_loss: 0.0746
# Epoch 30/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1272
# Epoch 30: val_loss did not improve from 0.07455
# 19/19 [==============================] - 4s 216ms/step - loss: 0.1272 - val_loss: 0.0866
# Epoch 31/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0998
# Epoch 31: val_loss did not improve from 0.07455
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0998 - val_loss: 0.0954
# Epoch 32/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1114
# Epoch 32: val_loss did not improve from 0.07455
# 19/19 [==============================] - 3s 163ms/step - loss: 0.1114 - val_loss: 0.0911
# Epoch 33/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1070
# Epoch 33: val_loss did not improve from 0.07455
# 19/19 [==============================] - 3s 164ms/step - loss: 0.1070 - val_loss: 0.1007
# Epoch 34/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0830
# Epoch 34: val_loss did not improve from 0.07455
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0830 - val_loss: 0.0963
# Epoch 35/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0973
# Epoch 35: val_loss did not improve from 0.07455
# 19/19 [==============================] - 5s 239ms/step - loss: 0.0973 - val_loss: 0.0770
# Epoch 36/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0941
# Epoch 36: val_loss improved from 0.07455 to 0.07138, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 429ms/step - loss: 0.0941 - val_loss: 0.0714
# Epoch 37/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0757
# Epoch 37: val_loss did not improve from 0.07138
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0757 - val_loss: 0.0761
# Epoch 38/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0938
# Epoch 38: val_loss did not improve from 0.07138
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0938 - val_loss: 0.0733
# Epoch 39/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0843
# Epoch 39: val_loss improved from 0.07138 to 0.07043, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 434ms/step - loss: 0.0843 - val_loss: 0.0704
# Epoch 40/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0954
# Epoch 40: val_loss did not improve from 0.07043
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0954 - val_loss: 0.0721
# Epoch 41/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0823
# Epoch 41: val_loss improved from 0.07043 to 0.06738, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 421ms/step - loss: 0.0823 - val_loss: 0.0674
# Epoch 42/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0864
# Epoch 42: val_loss improved from 0.06738 to 0.06431, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 500ms/step - loss: 0.0864 - val_loss: 0.0643
# Epoch 43/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0828
# Epoch 43: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0828 - val_loss: 0.0652
# Epoch 44/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0929
# Epoch 44: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 189ms/step - loss: 0.0929 - val_loss: 0.0669
# Epoch 45/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1077
# Epoch 45: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 214ms/step - loss: 0.1077 - val_loss: 0.0678
# Epoch 46/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0956
# Epoch 46: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0956 - val_loss: 0.0731
# Epoch 47/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0834
# Epoch 47: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0834 - val_loss: 0.0727
# Epoch 48/400
# 19/19 [==============================] - ETA: 0s - loss: 0.1060
# Epoch 48: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 188ms/step - loss: 0.1060 - val_loss: 0.0690
# Epoch 49/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0790
# Epoch 49: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 214ms/step - loss: 0.0790 - val_loss: 0.0657
# Epoch 50/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0864
# Epoch 50: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0864 - val_loss: 0.0651
# Epoch 51/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0807
# Epoch 51: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0807 - val_loss: 0.0670
# Epoch 52/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0914
# Epoch 52: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 189ms/step - loss: 0.0914 - val_loss: 0.0713
# Epoch 53/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0861
# Epoch 53: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0861 - val_loss: 0.0699
# Epoch 54/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0756
# Epoch 54: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0756 - val_loss: 0.0667
# Epoch 55/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 55: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0779 - val_loss: 0.0679
# Epoch 56/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0837
# Epoch 56: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 198ms/step - loss: 0.0837 - val_loss: 0.0733
# Epoch 57/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0894
# Epoch 57: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 199ms/step - loss: 0.0894 - val_loss: 0.0703
# Epoch 58/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0875
# Epoch 58: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0875 - val_loss: 0.0672
# Epoch 59/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0847
# Epoch 59: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0847 - val_loss: 0.0674
# Epoch 60/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0835
# Epoch 60: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0835 - val_loss: 0.0712
# Epoch 61/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0820
# Epoch 61: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 192ms/step - loss: 0.0820 - val_loss: 0.0744
# Epoch 62/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0879
# Epoch 62: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0879 - val_loss: 0.0724
# Epoch 63/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0753
# Epoch 63: val_loss did not improve from 0.06431
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0753 - val_loss: 0.0758
# Epoch 64/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0906
# Epoch 64: val_loss did not improve from 0.06431
# 19/19 [==============================] - 4s 210ms/step - loss: 0.0906 - val_loss: 0.0678
# Epoch 65/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0730
# Epoch 65: val_loss improved from 0.06431 to 0.06430, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 512ms/step - loss: 0.0730 - val_loss: 0.0643
# Epoch 66/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0725
# Epoch 66: val_loss did not improve from 0.06430
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0725 - val_loss: 0.0664
# Epoch 67/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 67: val_loss did not improve from 0.06430
# 19/19 [==============================] - 4s 199ms/step - loss: 0.0675 - val_loss: 0.0679
# Epoch 68/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0653
# Epoch 68: val_loss improved from 0.06430 to 0.06392, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 445ms/step - loss: 0.0653 - val_loss: 0.0639
# Epoch 69/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0701
# Epoch 69: val_loss did not improve from 0.06392
# 19/19 [==============================] - 4s 227ms/step - loss: 0.0701 - val_loss: 0.0639
# Epoch 70/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0626
# Epoch 70: val_loss did not improve from 0.06392
# 19/19 [==============================] - 3s 173ms/step - loss: 0.0626 - val_loss: 0.0654
# Epoch 71/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0628
# Epoch 71: val_loss did not improve from 0.06392
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0628 - val_loss: 0.0656
# Epoch 72/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0737
# Epoch 72: val_loss did not improve from 0.06392
# 19/19 [==============================] - 3s 185ms/step - loss: 0.0737 - val_loss: 0.0643
# Epoch 73/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0792
# Epoch 73: val_loss did not improve from 0.06392
# 19/19 [==============================] - 4s 215ms/step - loss: 0.0792 - val_loss: 0.0670
# Epoch 74/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0675
# Epoch 74: val_loss did not improve from 0.06392
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0675 - val_loss: 0.0694
# Epoch 75/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0702
# Epoch 75: val_loss did not improve from 0.06392
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0702 - val_loss: 0.0652
# Epoch 76/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0668
# Epoch 76: val_loss did not improve from 0.06392
# 19/19 [==============================] - 4s 192ms/step - loss: 0.0668 - val_loss: 0.0650
# Epoch 77/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0725
# Epoch 77: val_loss improved from 0.06392 to 0.06202, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 475ms/step - loss: 0.0725 - val_loss: 0.0620
# Epoch 78/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0778
# Epoch 78: val_loss improved from 0.06202 to 0.06181, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 465ms/step - loss: 0.0778 - val_loss: 0.0618
# Epoch 79/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0660
# Epoch 79: val_loss did not improve from 0.06181
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0660 - val_loss: 0.0632
# Epoch 80/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0778
# Epoch 80: val_loss improved from 0.06181 to 0.05934, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 438ms/step - loss: 0.0778 - val_loss: 0.0593
# Epoch 81/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0739
# Epoch 81: val_loss improved from 0.05934 to 0.05840, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 415ms/step - loss: 0.0739 - val_loss: 0.0584
# Epoch 82/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0770
# Epoch 82: val_loss did not improve from 0.05840
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0770 - val_loss: 0.0601
# Epoch 83/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 83: val_loss did not improve from 0.05840
# 19/19 [==============================] - 5s 241ms/step - loss: 0.0773 - val_loss: 0.0613
# Epoch 84/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0634
# Epoch 84: val_loss did not improve from 0.05840
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0634 - val_loss: 0.0603
# Epoch 85/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0695
# Epoch 85: val_loss did not improve from 0.05840
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0695 - val_loss: 0.0610
# Epoch 86/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0690
# Epoch 86: val_loss did not improve from 0.05840
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0690 - val_loss: 0.0586
# Epoch 87/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 87: val_loss did not improve from 0.05840
# 19/19 [==============================] - 4s 215ms/step - loss: 0.0777 - val_loss: 0.0618
# Epoch 88/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0681
# Epoch 88: val_loss did not improve from 0.05840
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0681 - val_loss: 0.0613
# Epoch 89/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0683
# Epoch 89: val_loss did not improve from 0.05840
# 19/19 [==============================] - 3s 157ms/step - loss: 0.0683 - val_loss: 0.0602
# Epoch 90/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0750
# Epoch 90: val_loss did not improve from 0.05840
# 19/19 [==============================] - 4s 192ms/step - loss: 0.0750 - val_loss: 0.0601
# Epoch 91/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0695
# Epoch 91: val_loss improved from 0.05840 to 0.05706, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 469ms/step - loss: 0.0695 - val_loss: 0.0571
# Epoch 92/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0768
# Epoch 92: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0768 - val_loss: 0.0586
# Epoch 93/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0782
# Epoch 93: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 250ms/step - loss: 0.0782 - val_loss: 0.0638
# Epoch 94/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0718
# Epoch 94: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0718 - val_loss: 0.0612
# Epoch 95/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0600
# Epoch 95: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 172ms/step - loss: 0.0600 - val_loss: 0.0594
# Epoch 96/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0761
# Epoch 96: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0761 - val_loss: 0.0612
# Epoch 97/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0710
# Epoch 97: val_loss did not improve from 0.05706
# 19/19 [==============================] - 6s 299ms/step - loss: 0.0710 - val_loss: 0.0607
# Epoch 98/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0740
# Epoch 98: val_loss did not improve from 0.05706
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0740 - val_loss: 0.0622
# Epoch 99/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0689
# Epoch 99: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0689 - val_loss: 0.0625
# Epoch 100/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0670
# Epoch 100: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0670 - val_loss: 0.0626
# Epoch 101/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0728
# Epoch 101: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0728 - val_loss: 0.0590
# Epoch 102/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0605
# Epoch 102: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0605 - val_loss: 0.0608
# Epoch 103/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0750
# Epoch 103: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0750 - val_loss: 0.0607
# Epoch 104/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0690
# Epoch 104: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0690 - val_loss: 0.0628
# Epoch 105/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0649
# Epoch 105: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0649 - val_loss: 0.0595
# Epoch 106/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0700
# Epoch 106: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0700 - val_loss: 0.0592
# Epoch 107/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0644
# Epoch 107: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0644 - val_loss: 0.0575
# Epoch 108/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0646
# Epoch 108: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0646 - val_loss: 0.0594
# Epoch 109/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0706
# Epoch 109: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 248ms/step - loss: 0.0706 - val_loss: 0.0635
# Epoch 110/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0671
# Epoch 110: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0671 - val_loss: 0.0638
# Epoch 111/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0782
# Epoch 111: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0782 - val_loss: 0.0613
# Epoch 112/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0692
# Epoch 112: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0692 - val_loss: 0.0623
# Epoch 113/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0696
# Epoch 113: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0696 - val_loss: 0.0664
# Epoch 114/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0704
# Epoch 114: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0704 - val_loss: 0.0617
# Epoch 115/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0693
# Epoch 115: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 156ms/step - loss: 0.0693 - val_loss: 0.0620
# Epoch 116/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0665
# Epoch 116: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 157ms/step - loss: 0.0665 - val_loss: 0.0617
# Epoch 117/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0635
# Epoch 117: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 246ms/step - loss: 0.0635 - val_loss: 0.0625
# Epoch 118/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0705
# Epoch 118: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0705 - val_loss: 0.0639
# Epoch 119/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0658
# Epoch 119: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0658 - val_loss: 0.0661
# Epoch 120/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0683
# Epoch 120: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0683 - val_loss: 0.0605
# Epoch 121/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0694
# Epoch 121: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 244ms/step - loss: 0.0694 - val_loss: 0.0602
# Epoch 122/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0749
# Epoch 122: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 157ms/step - loss: 0.0749 - val_loss: 0.0627
# Epoch 123/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0695
# Epoch 123: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 157ms/step - loss: 0.0695 - val_loss: 0.0614
# Epoch 124/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0628
# Epoch 124: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0628 - val_loss: 0.0601
# Epoch 125/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0759
# Epoch 125: val_loss did not improve from 0.05706
# 19/19 [==============================] - 4s 242ms/step - loss: 0.0759 - val_loss: 0.0604
# Epoch 126/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0597
# Epoch 126: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0597 - val_loss: 0.0576
# Epoch 127/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0671
# Epoch 127: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0671 - val_loss: 0.0580
# Epoch 128/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0749
# Epoch 128: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0749 - val_loss: 0.0604
# Epoch 129/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0635
# Epoch 129: val_loss did not improve from 0.05706
# 19/19 [==============================] - 4s 240ms/step - loss: 0.0635 - val_loss: 0.0592
# Epoch 130/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0636
# Epoch 130: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0636 - val_loss: 0.0636
# Epoch 131/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0692
# Epoch 131: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0692 - val_loss: 0.0630
# Epoch 132/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0664
# Epoch 132: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0664 - val_loss: 0.0639
# Epoch 133/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0637
# Epoch 133: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 251ms/step - loss: 0.0637 - val_loss: 0.0652
# Epoch 134/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0622
# Epoch 134: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0622 - val_loss: 0.0643
# Epoch 135/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0646
# Epoch 135: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0646 - val_loss: 0.0655
# Epoch 136/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0685
# Epoch 136: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0685 - val_loss: 0.0631
# Epoch 137/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0602
# Epoch 137: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0602 - val_loss: 0.0638
# Epoch 138/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0610
# Epoch 138: val_loss did not improve from 0.05706
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0610 - val_loss: 0.0588
# Epoch 139/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0707
# Epoch 139: val_loss did not improve from 0.05706
# 19/19 [==============================] - 5s 260ms/step - loss: 0.0707 - val_loss: 0.0601
# Epoch 140/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0751
# Epoch 140: val_loss did not improve from 0.05706
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0751 - val_loss: 0.0613
# Epoch 141/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0665
# Epoch 141: val_loss did not improve from 0.05706
# 19/19 [==============================] - 4s 184ms/step - loss: 0.0665 - val_loss: 0.0581
# Epoch 142/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0645
# Epoch 142: val_loss improved from 0.05706 to 0.05684, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 429ms/step - loss: 0.0645 - val_loss: 0.0568
# Epoch 143/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0591
# Epoch 143: val_loss improved from 0.05684 to 0.05625, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 478ms/step - loss: 0.0591 - val_loss: 0.0562
# Epoch 144/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0599
# Epoch 144: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0599 - val_loss: 0.0638
# Epoch 145/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0600
# Epoch 145: val_loss did not improve from 0.05625
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0600 - val_loss: 0.0627
# Epoch 146/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0625
# Epoch 146: val_loss did not improve from 0.05625
# 19/19 [==============================] - 4s 188ms/step - loss: 0.0625 - val_loss: 0.0592
# Epoch 147/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0624
# Epoch 147: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0624 - val_loss: 0.0606
# Epoch 148/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0576
# Epoch 148: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0576 - val_loss: 0.0732
# Epoch 149/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0634
# Epoch 149: val_loss did not improve from 0.05625
# 19/19 [==============================] - 4s 238ms/step - loss: 0.0634 - val_loss: 0.0716
# Epoch 150/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0681
# Epoch 150: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0681 - val_loss: 0.0624
# Epoch 151/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0645
# Epoch 151: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0645 - val_loss: 0.0626
# Epoch 152/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0606
# Epoch 152: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 157ms/step - loss: 0.0606 - val_loss: 0.0597
# Epoch 153/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0625
# Epoch 153: val_loss did not improve from 0.05625
# 19/19 [==============================] - 4s 239ms/step - loss: 0.0625 - val_loss: 0.0595
# Epoch 154/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0648
# Epoch 154: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0648 - val_loss: 0.0579
# Epoch 155/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0693
# Epoch 155: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0693 - val_loss: 0.0570
# Epoch 156/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0637
# Epoch 156: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0637 - val_loss: 0.0614
# Epoch 157/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0627
# Epoch 157: val_loss did not improve from 0.05625
# 19/19 [==============================] - 4s 238ms/step - loss: 0.0627 - val_loss: 0.0599
# Epoch 158/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0615
# Epoch 158: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0615 - val_loss: 0.0617
# Epoch 159/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0645
# Epoch 159: val_loss did not improve from 0.05625
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0645 - val_loss: 0.0563
# Epoch 160/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0584
# Epoch 160: val_loss improved from 0.05625 to 0.05582, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 481ms/step - loss: 0.0584 - val_loss: 0.0558
# Epoch 161/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0677
# Epoch 161: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0677 - val_loss: 0.0589
# Epoch 162/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0754
# Epoch 162: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0754 - val_loss: 0.0599
# Epoch 163/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0672
# Epoch 163: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 191ms/step - loss: 0.0672 - val_loss: 0.0561
# Epoch 164/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0574
# Epoch 164: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 215ms/step - loss: 0.0574 - val_loss: 0.0562
# Epoch 165/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0606
# Epoch 165: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0606 - val_loss: 0.0572
# Epoch 166/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0664
# Epoch 166: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0664 - val_loss: 0.0576
# Epoch 167/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0625
# Epoch 167: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 190ms/step - loss: 0.0625 - val_loss: 0.0662
# Epoch 168/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0604
# Epoch 168: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 216ms/step - loss: 0.0604 - val_loss: 0.0644
# Epoch 169/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0680
# Epoch 169: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0680 - val_loss: 0.0606
# Epoch 170/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0606
# Epoch 170: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0606 - val_loss: 0.0624
# Epoch 171/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0563
# Epoch 171: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0563 - val_loss: 0.0632
# Epoch 172/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0563
# Epoch 172: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 205ms/step - loss: 0.0563 - val_loss: 0.0618
# Epoch 173/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0658
# Epoch 173: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0658 - val_loss: 0.0588
# Epoch 174/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0596
# Epoch 174: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0596 - val_loss: 0.0576
# Epoch 175/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0646
# Epoch 175: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 194ms/step - loss: 0.0646 - val_loss: 0.0585
# Epoch 176/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0680
# Epoch 176: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 209ms/step - loss: 0.0680 - val_loss: 0.0584
# Epoch 177/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0639
# Epoch 177: val_loss did not improve from 0.05582
# 19/19 [==============================] - 5s 244ms/step - loss: 0.0639 - val_loss: 0.0600
# Epoch 178/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0621
# Epoch 178: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0621 - val_loss: 0.0671
# Epoch 179/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0589
# Epoch 179: val_loss did not improve from 0.05582
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0589 - val_loss: 0.0677
# Epoch 180/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0567
# Epoch 180: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0567 - val_loss: 0.0653
# Epoch 181/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0590
# Epoch 181: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0590 - val_loss: 0.0646
# Epoch 182/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0635
# Epoch 182: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0635 - val_loss: 0.0648
# Epoch 183/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0618
# Epoch 183: val_loss did not improve from 0.05582
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0618 - val_loss: 0.0632
# Epoch 184/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0657
# Epoch 184: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0657 - val_loss: 0.0610
# Epoch 185/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0605
# Epoch 185: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0605 - val_loss: 0.0618
# Epoch 186/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0641
# Epoch 186: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0641 - val_loss: 0.0619
# Epoch 187/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0527
# Epoch 187: val_loss did not improve from 0.05582
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0527 - val_loss: 0.0596
# Epoch 188/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0632
# Epoch 188: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0632 - val_loss: 0.0583
# Epoch 189/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0592
# Epoch 189: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0592 - val_loss: 0.0602
# Epoch 190/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0620
# Epoch 190: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0620 - val_loss: 0.0608
# Epoch 191/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0630
# Epoch 191: val_loss did not improve from 0.05582
# 19/19 [==============================] - 4s 233ms/step - loss: 0.0630 - val_loss: 0.0586
# Epoch 192/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0621
# Epoch 192: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0621 - val_loss: 0.0619
# Epoch 193/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0615
# Epoch 193: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0615 - val_loss: 0.0582
# Epoch 194/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0621
# Epoch 194: val_loss did not improve from 0.05582
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0621 - val_loss: 0.0562
# Epoch 195/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0584
# Epoch 195: val_loss improved from 0.05582 to 0.05527, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 502ms/step - loss: 0.0584 - val_loss: 0.0553
# Epoch 196/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0637
# Epoch 196: val_loss did not improve from 0.05527
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0637 - val_loss: 0.0565
# Epoch 197/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0559
# Epoch 197: val_loss did not improve from 0.05527
# 19/19 [==============================] - 5s 255ms/step - loss: 0.0559 - val_loss: 0.0573
# Epoch 198/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0608
# Epoch 198: val_loss did not improve from 0.05527
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0608 - val_loss: 0.0566
# Epoch 199/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0520
# Epoch 199: val_loss did not improve from 0.05527
# 19/19 [==============================] - 3s 166ms/step - loss: 0.0520 - val_loss: 0.0564
# Epoch 200/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0550
# Epoch 200: val_loss improved from 0.05527 to 0.05436, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 474ms/step - loss: 0.0550 - val_loss: 0.0544
# Epoch 201/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0563
# Epoch 201: val_loss did not improve from 0.05436
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0563 - val_loss: 0.0548
# Epoch 202/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0582
# Epoch 202: val_loss did not improve from 0.05436
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0582 - val_loss: 0.0571
# Epoch 203/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0548
# Epoch 203: val_loss did not improve from 0.05436
# 19/19 [==============================] - 4s 214ms/step - loss: 0.0548 - val_loss: 0.0586
# Epoch 204/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0583
# Epoch 204: val_loss did not improve from 0.05436
# 19/19 [==============================] - 4s 194ms/step - loss: 0.0583 - val_loss: 0.0626
# Epoch 205/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 205: val_loss did not improve from 0.05436
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0587 - val_loss: 0.0575
# Epoch 206/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0578
# Epoch 206: val_loss did not improve from 0.05436
# 19/19 [==============================] - 3s 160ms/step - loss: 0.0578 - val_loss: 0.0578
# Epoch 207/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0603
# Epoch 207: val_loss did not improve from 0.05436
# 19/19 [==============================] - 4s 219ms/step - loss: 0.0603 - val_loss: 0.0571
# Epoch 208/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0590
# Epoch 208: val_loss did not improve from 0.05436
# 19/19 [==============================] - 4s 182ms/step - loss: 0.0590 - val_loss: 0.0601
# Epoch 209/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0561
# Epoch 209: val_loss did not improve from 0.05436
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0561 - val_loss: 0.0570
# Epoch 210/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0576
# Epoch 210: val_loss did not improve from 0.05436
# 19/19 [==============================] - 3s 161ms/step - loss: 0.0576 - val_loss: 0.0583
# Epoch 211/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0591
# Epoch 211: val_loss did not improve from 0.05436
# 19/19 [==============================] - 4s 218ms/step - loss: 0.0591 - val_loss: 0.0606
# Epoch 212/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0589
# Epoch 212: val_loss did not improve from 0.05436
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0589 - val_loss: 0.0588
# Epoch 213/400
# ...
# Epoch 329: val_loss did not improve from 0.03958
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0331 - val_loss: 0.0433
# Epoch 330/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 330: val_loss did not improve from 0.03958
# 19/19 [==============================] - 4s 209ms/step - loss: 0.0286 - val_loss: 0.0430
# Epoch 331/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0295
# Epoch 331: val_loss did not improve from 0.03958
# 19/19 [==============================] - 4s 203ms/step - loss: 0.0295 - val_loss: 0.0451
# Epoch 332/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0326
# Epoch 332: val_loss did not improve from 0.03958
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0326 - val_loss: 0.0434
# Epoch 333/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 333: val_loss did not improve from 0.03958
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0302 - val_loss: 0.0446
# Epoch 334/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 334: val_loss did not improve from 0.03958
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0245 - val_loss: 0.0411
# Epoch 335/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0235
# Epoch 335: val_loss did not improve from 0.03958
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0235 - val_loss: 0.0438
# Epoch 336/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 336: val_loss did not improve from 0.03958
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0245 - val_loss: 0.0397
# Epoch 337/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0305
# Epoch 337: val_loss did not improve from 0.03958
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0305 - val_loss: 0.0418
# Epoch 338/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0263
# Epoch 338: val_loss did not improve from 0.03958
# 19/19 [==============================] - 4s 225ms/step - loss: 0.0263 - val_loss: 0.0425
# Epoch 339/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 339: val_loss improved from 0.03958 to 0.03712, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 449ms/step - loss: 0.0218 - val_loss: 0.0371
# Epoch 340/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0259
# Epoch 340: val_loss improved from 0.03712 to 0.03539, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 481ms/step - loss: 0.0259 - val_loss: 0.0354
# Epoch 341/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 341: val_loss did not improve from 0.03539
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0247 - val_loss: 0.0356
# Epoch 342/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 342: val_loss improved from 0.03539 to 0.03538, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 468ms/step - loss: 0.0198 - val_loss: 0.0354
# Epoch 343/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 343: val_loss did not improve from 0.03538
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0269 - val_loss: 0.0365
# Epoch 344/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 344: val_loss did not improve from 0.03538
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0269 - val_loss: 0.0363
# Epoch 345/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0319
# Epoch 345: val_loss did not improve from 0.03538
# 19/19 [==============================] - 4s 199ms/step - loss: 0.0319 - val_loss: 0.0401
# Epoch 346/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0226
# Epoch 346: val_loss did not improve from 0.03538
# 19/19 [==============================] - 4s 211ms/step - loss: 0.0226 - val_loss: 0.0389
# Epoch 347/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0312
# Epoch 347: val_loss did not improve from 0.03538
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0312 - val_loss: 0.0412
# Epoch 348/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0295
# Epoch 348: val_loss did not improve from 0.03538
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0295 - val_loss: 0.0357
# Epoch 349/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0333
# Epoch 349: val_loss did not improve from 0.03538
# 19/19 [==============================] - 4s 208ms/step - loss: 0.0333 - val_loss: 0.0364
# Epoch 350/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0300
# Epoch 350: val_loss did not improve from 0.03538
# 19/19 [==============================] - 4s 202ms/step - loss: 0.0300 - val_loss: 0.0402
# Epoch 351/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0275
# Epoch 351: val_loss did not improve from 0.03538
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0275 - val_loss: 0.0369
# Epoch 352/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0221
# Epoch 352: val_loss did not improve from 0.03538
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0221 - val_loss: 0.0397
# Epoch 353/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0238
# Epoch 353: val_loss improved from 0.03538 to 0.03524, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 506ms/step - loss: 0.0238 - val_loss: 0.0352
# Epoch 354/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 354: val_loss did not improve from 0.03524
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0249 - val_loss: 0.0360
# Epoch 355/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0257
# Epoch 355: val_loss improved from 0.03524 to 0.03453, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 488ms/step - loss: 0.0257 - val_loss: 0.0345
# Epoch 356/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0256
# Epoch 356: val_loss did not improve from 0.03453
# 19/19 [==============================] - 5s 263ms/step - loss: 0.0256 - val_loss: 0.0365
# Epoch 357/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 357: val_loss did not improve from 0.03453
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0225 - val_loss: 0.0353
# Epoch 358/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 358: val_loss did not improve from 0.03453
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0297 - val_loss: 0.0346
# Epoch 359/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 359: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0271 - val_loss: 0.0349
# Epoch 360/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0255
# Epoch 360: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0255 - val_loss: 0.0357
# Epoch 361/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0260
# Epoch 361: val_loss did not improve from 0.03453
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0260 - val_loss: 0.0348
# Epoch 362/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0238
# Epoch 362: val_loss did not improve from 0.03453
# 19/19 [==============================] - 4s 195ms/step - loss: 0.0238 - val_loss: 0.0368
# Epoch 363/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0175
# Epoch 363: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 175ms/step - loss: 0.0175 - val_loss: 0.0353
# Epoch 364/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0226
# Epoch 364: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0226 - val_loss: 0.0379
# Epoch 365/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0215
# Epoch 365: val_loss did not improve from 0.03453
# 19/19 [==============================] - 5s 244ms/step - loss: 0.0215 - val_loss: 0.0417
# Epoch 366/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 366: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0165 - val_loss: 0.0366
# Epoch 367/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 367: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0192 - val_loss: 0.0379
# Epoch 368/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 368: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0197 - val_loss: 0.0373
# Epoch 369/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 369: val_loss did not improve from 0.03453
# 19/19 [==============================] - 5s 244ms/step - loss: 0.0192 - val_loss: 0.0419
# Epoch 370/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 370: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 171ms/step - loss: 0.0246 - val_loss: 0.0411
# Epoch 371/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 371: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0271 - val_loss: 0.0388
# Epoch 372/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0267
# Epoch 372: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0267 - val_loss: 0.0410
# Epoch 373/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 373: val_loss did not improve from 0.03453
# 19/19 [==============================] - 5s 270ms/step - loss: 0.0269 - val_loss: 0.0369
# Epoch 374/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 374: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0204 - val_loss: 0.0369
# Epoch 375/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 375: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0198 - val_loss: 0.0376
# Epoch 376/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 376: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0270 - val_loss: 0.0417
# Epoch 377/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 377: val_loss did not improve from 0.03453
# 19/19 [==============================] - 5s 250ms/step - loss: 0.0367 - val_loss: 0.0472
# Epoch 378/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 378: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 167ms/step - loss: 0.0383 - val_loss: 0.0466
# Epoch 379/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0340
# Epoch 379: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0340 - val_loss: 0.0425
# Epoch 380/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 380: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0246 - val_loss: 0.0419
# Epoch 381/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 381: val_loss did not improve from 0.03453
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0247 - val_loss: 0.0392
# Epoch 382/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 382: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0279 - val_loss: 0.0371
# Epoch 383/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 383: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 168ms/step - loss: 0.0227 - val_loss: 0.0373
# Epoch 384/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 384: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0233 - val_loss: 0.0406
# Epoch 385/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0193
# Epoch 385: val_loss did not improve from 0.03453
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0193 - val_loss: 0.0401
# Epoch 386/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0232
# Epoch 386: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 165ms/step - loss: 0.0232 - val_loss: 0.0380
# Epoch 387/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0255
# Epoch 387: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 164ms/step - loss: 0.0255 - val_loss: 0.0366
# Epoch 388/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 388: val_loss did not improve from 0.03453
# 19/19 [==============================] - 3s 163ms/step - loss: 0.0280 - val_loss: 0.0390
# Epoch 389/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 389: val_loss improved from 0.03453 to 0.03422, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 9s 506ms/step - loss: 0.0204 - val_loss: 0.0342
# Epoch 390/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0294
# Epoch 390: val_loss did not improve from 0.03422
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0294 - val_loss: 0.0481
# Epoch 391/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0227
# Epoch 391: val_loss did not improve from 0.03422
# 19/19 [==============================] - 4s 231ms/step - loss: 0.0227 - val_loss: 0.0369
# Epoch 392/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0241
# Epoch 392: val_loss did not improve from 0.03422
# 19/19 [==============================] - 4s 182ms/step - loss: 0.0241 - val_loss: 0.0382
# Epoch 393/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0276
# Epoch 393: val_loss improved from 0.03422 to 0.03167, saving model to /content/drive/My Drive/new_kimore/modelEX1.h5
# 19/19 [==============================] - 8s 432ms/step - loss: 0.0276 - val_loss: 0.0317
# Epoch 394/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0211
# Epoch 394: val_loss did not improve from 0.03167
# 19/19 [==============================] - 6s 302ms/step - loss: 0.0211 - val_loss: 0.0336
# Epoch 395/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 395: val_loss did not improve from 0.03167
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0187 - val_loss: 0.0360
# Epoch 396/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0195
# Epoch 396: val_loss did not improve from 0.03167
# 19/19 [==============================] - 3s 169ms/step - loss: 0.0195 - val_loss: 0.0359
# Epoch 397/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 397: val_loss did not improve from 0.03167
# 19/19 [==============================] - 4s 210ms/step - loss: 0.0210 - val_loss: 0.0368
# Epoch 398/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0181
# Epoch 398: val_loss did not improve from 0.03167
# 19/19 [==============================] - 4s 197ms/step - loss: 0.0181 - val_loss: 0.0400
# Epoch 399/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 399: val_loss did not improve from 0.03167
# 19/19 [==============================] - 3s 177ms/step - loss: 0.0148 - val_loss: 0.0375
# Epoch 400/400
# 19/19 [==============================] - ETA: 0s - loss: 0.0150
# Epoch 400: val_loss did not improve from 0.03167
# 19/19 [==============================] - 3s 170ms/step - loss: 0.0150 - val_loss: 0.0387
# Training time: 0:33:15.841102

# %%
print(tracemalloc.get_traced_memory())
# stopping the library
tracemalloc.stop()
# Out:
# (136357293, 139326711)

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.014816319569945335
# Validation loss 0.03167494758963585

# %%
# Plot the prediction of the model for the training and validation sets
import tensorflow as tf
from keras.models import load_model
from keras.initializers import glorot_uniform
# Load the best model's weights
best_model = load_model('/content/drive/My Drive/new_kimore/modelEX1.h5', custom_objects={'TCN': TCN, 'GlorotUniform': glorot_uniform()})

pred_train = best_model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = best_model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.2,1.2])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(valid_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.2,1.2])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()

plt.show()
# Out:
# 4/4 [==============================] - 12s 92ms/step
# 2/2 [==============================] - 0s 83ms/step

# %%
test_dev = abs(np.squeeze(pred_test)-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
#MSE
MSE=mean_squared_error(pred_test, test_y)
#MAPE
#P1 = 19*pred_test + 31;
#P2 = 19*test_y+31;
MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
print('MSE:',MSE)
rms_dev = np.sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
print('MAPE:',MAPE)
# Out:
# MSE: 0.061879494645145555
# Mean absolute deviation: 0.203795006261027
# RMS deviation: 0.2487558936892663
# MAPE: inf
