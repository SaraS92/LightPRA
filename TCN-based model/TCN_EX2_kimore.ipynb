# %%
pip install keras-tcn
# Out:
# Requirement already satisfied: keras-tcn in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (1.25.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (2.15.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (from keras-tcn) (0.23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->keras-tcn) (2.15.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->keras-tcn) (2.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->keras-tcn) (3.2.2)

# %%
# general
import numpy as np
import pandas as pd
import random
from google.colab import drive
from scipy.ndimage import gaussian_filter1d
# keras
from tcn import TCN
from keras.layers import Dense, Input, Lambda, concatenate, UpSampling1D, Attention, GRU
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *

#general
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import datetime
now = datetime.datetime.now
from sklearn.model_selection import train_test_split


from sklearn.metrics import mean_squared_error
from math import sqrt
# length of data sequences
timesteps = 104
# dimension of data sequences
n_dim = 80
batch_size = 2

# %%
drive.mount('/content/drive')
dir_name_samples ='/content/drive/My Drive/new_kimore/Preprocessed_data/Exercise2_data.csv'
dir_name_labels ='/content/drive/My Drive/new_kimore/Preprocessed_data/Labels_ex2.csv'
import warnings
warnings.filterwarnings("ignore")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_values = pd.read_csv(dir_name_samples, delimiter=',', encoding='utf-8')
print(X_values.shape)
# # Initialize the MinMaxScaler

# scaler = StandardScaler()
# # Fit and transform the data using the scaler
# scaled_data = scaler.fit_transform(X_values)

# # Create a new DataFrame with the scaled data
# scaled_df = pd.DataFrame(scaled_data, columns=X_values.columns)


# # Extract the underlying NumPy array
# numpy_2d_array = scaled_df.values
# #numpy_2d_array = X_values.values
# # Reshape the 2D array into a 3D array (207, 100, 80)
# X_train = numpy_2d_array.reshape(207, 100, 80)
# # The temporal pyramid requires that the length of the data sequences is divisible by 8.
# # The original length was 100 time steps, so we will repeat the first and last 2 data vectors to obtain sequences with 104 time steps
# X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
numpy_2d_array = X_values.values
X_train = numpy_2d_array.reshape(183, 100, 80)
# Calculate the mean along the specified axes (axis=0, axis=1, and axis=2) to obtain a mean value for the entire array
mean_value = X_train.mean(axis=(0, 1, 2))

# Subtract the mean from the entire array to achieve zero mean
X_train -= mean_value

# Calculate the maximum and minimum values in the array
max_value = X_train.max()
min_value = X_train.min()

# Normalize the array to a range between -1 and 1
data = 2 * (X_train - min_value) / (max_value - min_value) - 1
smoothed_data = np.empty_like(X_train)
for channel in range(80):
    smoothed_data[:, :, channel] = gaussian_filter1d(data[:, :, channel], sigma=5)
X_train=smoothed_data
X_train = np.concatenate((X_train[:,:2,:], X_train, X_train[:,-3:-1,:]), axis = 1)
#-----------labels------------------------------------
Y_values = pd.read_csv(dir_name_labels)
#change the secon column to the labels
y_values= Y_values['EX2'].values

reshaped_data_y = y_values.reshape(183, 1)
# Fit and transform the data using the scaler
#scaler2 = MinMaxScaler(feature_range=(0, 1))
#y_train = scaler2.fit_transform(reshaped_data_y)
min_value = np.min(reshaped_data_y)
max_value = np.max(reshaped_data_y)

# Normalize the vector to be in the range [-1, 1]
y_train = (reshaped_data_y - min_value) / (max_value - min_value)

print('Training sequences dimension', X_train)
print('Training labels dimension', y_train)
# Out:
# (18300, 80)
# Training sequences dimension [[[ 0.01772344  0.01378505  0.01080073 ...  0.00784859  0.00784859
#     0.00784859]
#   [ 0.0178559   0.01380547  0.01081011 ...  0.00784859  0.00784859
#     0.00784859]
#   [ 0.01772344  0.01378505  0.01080073 ...  0.00784859  0.00784859
#     0.00784859]
#   ...
#   [ 0.04846101  0.07670476  0.00844336 ...  0.00784859  0.00784859
#     0.00784859]
#   [ 0.04853744  0.07686032  0.0084287  ...  0.00784859  0.00784859
#     0.00784859]
#   [ 0.04848941  0.07676059  0.00843823 ...  0.00784859  0.00784859
#  [0.93333333]
#  [0.93333333]
#  [0.99166667]
#  [0.99166667]
#  [0.99166667]
#  [0.85      ]
#  [0.85      ]
#  [0.85      ]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.65      ]
#  [0.65      ]
#  [0.65      ]
#  [0.7       ]
#  [0.7       ]
#  [0.7       ]
#  [0.71666667]
#  [0.71666667]
#  [0.71666667]
#  [0.9       ]
#  [0.9       ]
#  [0.9       ]
#  [0.46666667]
#  [0.46666667]
#  [0.46666667]
#  [0.81666667]
#  [0.81666667]
#  [0.81666667]
#  [0.5       ]
#  [0.5       ]
#  [0.5       ]
#  [0.4       ]
#  [0.4       ]
#  [0.4       ]
#  [0.975     ]
#  [0.975     ]
#  [0.975     ]
#  [0.325     ]
#  [0.325     ]
#  [0.325     ]
#  [0.7       ]
#  [0.7       ]
#  [0.7       ]
#  [0.675     ]
#  [0.675     ]
#  [0.675     ]
#  [0.85      ]
#  [0.85      ]
#  [0.85      ]
#  [0.725     ]
#  [0.725     ]
#  [0.725     ]
#  [0.975     ]
#  [0.975     ]
#  [0.975     ]
#  [0.925     ]
#  [0.925     ]
#  [0.925     ]
#  [0.975     ]
#  [0.975     ]
#  [0.975     ]
#  [0.725     ]
#  [0.725     ]
#  [0.725     ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.95      ]
#  [0.95      ]
#  [0.95      ]
#  [0.9       ]
#  [0.9       ]
#  [0.9       ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.76666667]
#  [0.76666667]
#  [0.76666667]
#  [0.575     ]
#  [0.575     ]
#  [0.575     ]
#  [0.85      ]
#  [0.85      ]
#  [0.85      ]
#  [0.825     ]
#  [0.825     ]
#  [0.825     ]
#  [0.925     ]
#  [0.925     ]
#  [0.925     ]
#  [0.15      ]
#  [0.15      ]
#  [0.15      ]
#  [0.875     ]
#  [0.875     ]
#  [0.875     ]
#  [0.54012654]
#  [0.54012654]
#  [0.54012654]
#  [0.93333333]
#  [0.93333333]
#  [0.93333333]
#  [0.88333333]
#  [0.88333333]
#  [0.88333333]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.95      ]
#  [0.95      ]
#  [0.95      ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.85      ]
#  [0.85      ]
#  [0.85      ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.775     ]
#  [0.1       ]
#  [0.1       ]
#  [0.1       ]
#  [0.725     ]
#  [0.725     ]
#  [0.725     ]
#  [0.50986614]
#  [0.50986614]
#  [0.50986614]
#  [0.05      ]
#  [0.05      ]
#  [0.05      ]
#  [0.56666667]
#  [0.56666667]
#  [0.56666667]
#  [0.225     ]
#  [0.225     ]
#  [0.225     ]
#  [0.25      ]
#  [0.25      ]
#  [0.25      ]
#  [0.96666667]
#  [0.96666667]
#  [0.96666667]
#  [0.35      ]
#  [0.35      ]
#  [0.35      ]
#  [0.25      ]
#  [0.25      ]
#  [0.25      ]
#  [0.375     ]
#  [0.375     ]
#  [0.375     ]
#  [0.7566342 ]
#  [0.7566342 ]
#  [0.7566342 ]
#  [0.3694776 ]
#  [0.3694776 ]
#  [0.3694776 ]
#  [0.33333333]
#  [0.33333333]
#  [0.33333333]
#  [0.38333333]
#  [0.38333333]
#  [0.38333333]
#  [0.86666667]
#  [0.86666667]
#  [0.86666667]]

# %%
# Split the data into training and validation sets
train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train, test_size=0.3)
# Split your dataset into a training set (60%) and a combined validation-testing set (40%)
train_x, X_val_test, train_y, y_val_test = train_test_split(X_train, y_train, test_size=0.4, random_state=42)

# Split the combined validation-testing set (40%) into a validation set (20%) and a test set (20%)
valid_x, test_x, valid_y, test_y = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)

# Now, you have X_train, y_train for training (60%), X_val, y_val for validation (20%), and X_test, y_test for testing (20%)
print('Training data', train_x.shape)
print('Validation data', valid_x.shape)
print('Training label', train_y.shape)
print('Validation label', valid_y.shape)
# Out:
# Training data (109, 104, 80)
# Validation data (37, 104, 80)
# Training label (109, 1)
# Validation label (37, 1)

# %%
# Plot the first and last sequences in the training and validation data
plt.figure(figsize = (14,8))
plt.subplot(2,2,1)
plt.plot(train_x[0])
plt.subplot(2,2,2)
plt.plot(train_x[-1])
plt.subplot(2,2,3)
plt.plot(valid_x[0])
plt.subplot(2,2,4)
plt.plot(valid_x[-1])
plt.tight_layout()
plt.show()

# %%
# Reduce the data length by a factor of 2, 4, and 8
# The reduced sequences will be used as inputs to the temporal pyramid subnetwork
trainx_2 = np.zeros((train_x.shape[0], int(train_x.shape[1]/2), train_x.shape[2]))
validx_2 = np.zeros(trainx_2.shape)
testx_2 = np.zeros(trainx_2.shape)
trainx_4 = np.zeros((train_x.shape[0], int(train_x.shape[1]/4), train_x.shape[2]))
validx_4 = np.zeros(trainx_4.shape)
testx_4 = np.zeros(trainx_4.shape)
trainx_8 = np.zeros((train_x.shape[0], int(train_x.shape[1]/8), train_x.shape[2]))
validx_8 = np.zeros(trainx_8.shape)
testx_8 = np.zeros(trainx_8.shape)
trainx_2 = train_x[:,::2,:]
validx_2 = valid_x[:,::2,:]
testx_2 = test_x[:,::2,:]
trainx_4 = train_x[:,::4,:]
validx_4 = valid_x[:,::4,:]
testx_4 = test_x[:,::4,:]
trainx_8 = train_x[:,::8,:]
validx_8 = valid_x[:,::8,:]
testx_8 = test_x[:,::8,:]

# %%
trainx =  train_x
validx =  valid_x
testx =  test_x

# %%
import matplotlib.patches as mpatches
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
plt.plot(trainx[0,:,0:16], color='red')
plt.plot(trainx[0,:,16:32], color='blue')
plt.plot(trainx[0,:,32:48], color='green')
plt.plot(trainx[0,:,48:64], color='orange')
plt.plot(trainx[0,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('First Train Sequence')
plt.subplot(1,2,2)
plt.plot(trainx[-1,:,0:16], color='red')
plt.plot(trainx[-1,:,16:32], color='blue')
plt.plot(trainx[-1,:,32:48], color='green')
plt.plot(trainx[-1,:,48:64], color='orange')
plt.plot(trainx[-1,:,64:80], color='magenta')
plt.ylim([-1,1])
# Create custom proxy artists for the legends
red_patch = mpatches.Patch(color='red', label='trunk')
blue_patch = mpatches.Patch(color='blue', label='left arm')
green_patch = mpatches.Patch(color='green', label='right arm')
orange_patch = mpatches.Patch(color='orange', label='left leg')
magenta_patch = mpatches.Patch(color='magenta', label='right leg')
# Create the legends using the proxy artists
plt.legend(handles=[red_patch, blue_patch,green_patch,orange_patch,magenta_patch], loc='upper left')
plt.xlabel('Time steps')
plt.ylabel('Joint displacement degree')
plt.title('Last Train Sequence')
plt.tight_layout()
plt.show()

# %%
def createTCNLayers(input, timesteps, n_dim):
    print('shape of input:: ', input.shape)

    tcn_layer = TCN(input_shape=(timesteps, n_dim), nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8, 16, 32),
        padding='causal',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,use_weight_norm=False)(input)

    print('shape of tcn_layer: ', tcn_layer.shape)

    return tcn_layer

# %%
def getTCNLayers(input_f, input_2, input_4, input_8, timesteps, n_dim):

    print('--------------------------xxxx-----------------------------')
    tcn_1 = createTCNLayers(input_f, timesteps, n_dim)

    tcn_2 = createTCNLayers(input_2, timesteps, n_dim)
    #up_tcn_2 = UpSampling1D(size = 2)(tcn_2)
    print('tcn-2: ', tcn_2.shape)

    tcn_3 = createTCNLayers(input_4, timesteps, n_dim)
    #up_tcn_3 = UpSampling1D(size = 4)(tcn_3)
    print('tcn-3: ', tcn_3.shape)

    tcn_5 = createTCNLayers(input_8, timesteps, n_dim)
    #up-tcn_4 = UpSampling1D(size = 8)(tcn_4)
    print('tcn-5: ', tcn_5.shape)

    final_tcn = concatenate([tcn_1, tcn_2, tcn_3, tcn_5], axis=1)
    print('final_tcn: ', final_tcn.shape)
    print('--------------------------xxxx-----------------------------')

    return final_tcn

# %%
n_dim = 80 # dimension after reordering the data into body parts
n_dim1 = 16 # dimension of indiviudal body parts
n_dim2 = 16
n_dim3 = 16 # legs dimension
# Build the model ...

#### Full scale sequences
seq_input = Input(shape = (timesteps,n_dim), name = 'full_scale')

seq_input_trunk = Lambda(lambda x: x[:, :, 0:16])(seq_input)
seq_input_left_arm = Lambda(lambda x: x[:, :, 16:32])(seq_input)
seq_input_right_arm = Lambda(lambda x: x[:, :, 32:48])(seq_input)
seq_input_left_leg = Lambda(lambda x: x[:, :, 48:64])(seq_input)
seq_input_right_leg = Lambda(lambda x: x[:, :, 64:80])(seq_input)

#### Half scale sequences
seq_input_2 = Input(shape=(int(timesteps/2), n_dim), name='half_scale')

seq_input_trunk_2 = Lambda(lambda x: x[:, :, 0:16])(seq_input_2)
seq_input_left_arm_2 = Lambda(lambda x: x[:, :, 16:32])(seq_input_2)
seq_input_right_arm_2 = Lambda(lambda x: x[:, :, 32:48])(seq_input_2)
seq_input_left_leg_2 = Lambda(lambda x: x[:, :, 48:64])(seq_input_2)
seq_input_right_leg_2 = Lambda(lambda x: x[:, :, 64:80])(seq_input_2)

#### Quarter scale sequences
seq_input_4 = Input(shape=(int(timesteps/4), n_dim), name='quarter_scale')

seq_input_trunk_4 = Lambda(lambda x: x[:, :, 0:16])(seq_input_4)
seq_input_left_arm_4 = Lambda(lambda x: x[:, :, 16:32])(seq_input_4)
seq_input_right_arm_4 = Lambda(lambda x: x[:, :, 32:48])(seq_input_4)
seq_input_left_leg_4 = Lambda(lambda x: x[:, :, 48:64])(seq_input_4)
seq_input_right_leg_4 = Lambda(lambda x: x[:, :, 64:80])(seq_input_4)

#### Eighth scale sequences
seq_input_8 = Input(shape=(int(timesteps/8), n_dim), name='eighth_scale')

seq_input_trunk_8 = Lambda(lambda x: x[:, :, 0:16])(seq_input_8)
seq_input_left_arm_8 = Lambda(lambda x: x[:, :, 16:32])(seq_input_8)
seq_input_right_arm_8 = Lambda(lambda x: x[:, :, 32:48])(seq_input_8)
seq_input_left_leg_8 = Lambda(lambda x: x[:, :, 48:64])(seq_input_8)
seq_input_right_leg_8 = Lambda(lambda x: x[:, :, 64:80])(seq_input_8)

concat_trunk = getTCNLayers(seq_input_trunk, seq_input_trunk_2, seq_input_trunk_4, seq_input_trunk_8,
                            timesteps, n_dim1)
concat_left_arm = getTCNLayers(seq_input_left_arm, seq_input_left_arm_2, seq_input_left_arm_4, seq_input_left_arm_8,
                               timesteps, n_dim2)
concat_right_arm = getTCNLayers(seq_input_right_arm, seq_input_right_arm_2, seq_input_right_arm_4, seq_input_right_arm_8,
                               timesteps,n_dim2)
concat_left_leg = getTCNLayers(seq_input_left_leg, seq_input_left_leg_2, seq_input_left_leg_4, seq_input_left_leg_8,
                               timesteps, n_dim3)
concat_right_leg = getTCNLayers(seq_input_right_leg, seq_input_right_leg_2, seq_input_right_leg_4, seq_input_right_leg_8,
                               timesteps, n_dim3)

concat = concatenate([concat_trunk, concat_left_arm, concat_right_arm, concat_left_leg, concat_right_leg], axis=-1)

tcn_layer_final = TCN(nb_filters=12,kernel_size=3,nb_stacks=1,dilations=(1, 2, 4, 8),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                      use_weight_norm=False)(concat)

tcn_layer_final_1 = TCN(nb_filters=8,kernel_size=2,nb_stacks=1,dilations=(1, 2, 4),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=True,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=True,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final)

tcn_layer_final_2 = TCN(nb_filters=6,kernel_size=3,nb_stacks=1,dilations=(1, 2),
        padding='same',use_skip_connections=True,dropout_rate=0.05,return_sequences=False,
        activation='relu',kernel_initializer='he_normal',use_batch_norm=False,use_layer_norm=False,
                        use_weight_norm=False)(tcn_layer_final_1)

print('shape of tcn_layer_final: ', tcn_layer_final_2.shape)



out = Dense(1, activation = 'linear')(tcn_layer_final_2)

print('shape of out: ', out.shape)

model = Model(inputs=[seq_input, seq_input_2, seq_input_4, seq_input_8], outputs=out)
# Out:
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# --------------------------xxxx-----------------------------
# shape of input::  (None, 104, 16)
# shape of tcn_layer:  (None, 104, 12)
# shape of input::  (None, 52, 16)
# shape of tcn_layer:  (None, 52, 12)
# tcn-2:  (None, 52, 12)
# shape of input::  (None, 26, 16)
# shape of tcn_layer:  (None, 26, 12)
# tcn-3:  (None, 26, 12)
# shape of input::  (None, 13, 16)
# shape of tcn_layer:  (None, 13, 12)
# tcn-5:  (None, 13, 12)
# final_tcn:  (None, 195, 12)
# --------------------------xxxx-----------------------------
# shape of tcn_layer_final:  (None, 6)
# shape of out:  (None, 1)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  full_scale (InputLayer)     [(None, 104, 80)]            0         []
#
#  half_scale (InputLayer)     [(None, 52, 80)]             0         []
#
#  quarter_scale (InputLayer)  [(None, 26, 80)]             0         []
#
#  eighth_scale (InputLayer)   [(None, 13, 80)]             0         []
#
#  lambda_20 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_25 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_30 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_35 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_21 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_26 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_31 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_36 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_22 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_27 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_32 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_37 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_23 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_28 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_33 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_38 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  lambda_24 (Lambda)          (None, 104, 16)              0         ['full_scale[0][0]']
#
#  lambda_29 (Lambda)          (None, 52, 16)               0         ['half_scale[0][0]']
#
#  lambda_34 (Lambda)          (None, 26, 16)               0         ['quarter_scale[0][0]']
#
#  lambda_39 (Lambda)          (None, 13, 16)               0         ['eighth_scale[0][0]']
#
#  tcn_23 (TCN)                (None, 104, 12)              5676      ['lambda_20[0][0]']
#
#  tcn_24 (TCN)                (None, 52, 12)               5676      ['lambda_25[0][0]']
#
#  tcn_25 (TCN)                (None, 26, 12)               5676      ['lambda_30[0][0]']
#
#  tcn_26 (TCN)                (None, 13, 12)               5676      ['lambda_35[0][0]']
#
#  tcn_27 (TCN)                (None, 104, 12)              5676      ['lambda_21[0][0]']
#
#  tcn_28 (TCN)                (None, 52, 12)               5676      ['lambda_26[0][0]']
#
#  tcn_29 (TCN)                (None, 26, 12)               5676      ['lambda_31[0][0]']
#
#  tcn_30 (TCN)                (None, 13, 12)               5676      ['lambda_36[0][0]']
#
#  tcn_31 (TCN)                (None, 104, 12)              5676      ['lambda_22[0][0]']
#
#  tcn_32 (TCN)                (None, 52, 12)               5676      ['lambda_27[0][0]']
#
#  tcn_33 (TCN)                (None, 26, 12)               5676      ['lambda_32[0][0]']
#
#  tcn_34 (TCN)                (None, 13, 12)               5676      ['lambda_37[0][0]']
#
#  tcn_35 (TCN)                (None, 104, 12)              5676      ['lambda_23[0][0]']
#
#  tcn_36 (TCN)                (None, 52, 12)               5676      ['lambda_28[0][0]']
#
#  tcn_37 (TCN)                (None, 26, 12)               5676      ['lambda_33[0][0]']
#
#  tcn_38 (TCN)                (None, 13, 12)               5676      ['lambda_38[0][0]']
#
#  tcn_39 (TCN)                (None, 104, 12)              5676      ['lambda_24[0][0]']
#
#  tcn_40 (TCN)                (None, 52, 12)               5676      ['lambda_29[0][0]']
#
#  tcn_41 (TCN)                (None, 26, 12)               5676      ['lambda_34[0][0]']
#
#  tcn_42 (TCN)                (None, 13, 12)               5676      ['lambda_39[0][0]']
#
#  concatenate_6 (Concatenate  (None, 195, 12)              0         ['tcn_23[0][0]',
#  )                                                                   'tcn_24[0][0]',
#                                                                      'tcn_25[0][0]',
#                                                                      'tcn_26[0][0]']
#
#  concatenate_7 (Concatenate  (None, 195, 12)              0         ['tcn_27[0][0]',
#  )                                                                   'tcn_28[0][0]',
#                                                                      'tcn_29[0][0]',
#                                                                      'tcn_30[0][0]']
#
#  concatenate_8 (Concatenate  (None, 195, 12)              0         ['tcn_31[0][0]',
#  )                                                                   'tcn_32[0][0]',
#                                                                      'tcn_33[0][0]',
#                                                                      'tcn_34[0][0]']
#
#  concatenate_9 (Concatenate  (None, 195, 12)              0         ['tcn_35[0][0]',
#  )                                                                   'tcn_36[0][0]',
#                                                                      'tcn_37[0][0]',
#                                                                      'tcn_38[0][0]']
#
#  concatenate_10 (Concatenat  (None, 195, 12)              0         ['tcn_39[0][0]',
#  e)                                                                  'tcn_40[0][0]',
#                                                                      'tcn_41[0][0]',
#                                                                      'tcn_42[0][0]']
#
#  concatenate_11 (Concatenat  (None, 195, 60)              0         ['concatenate_6[0][0]',
#  e)                                                                  'concatenate_7[0][0]',
#                                                                      'concatenate_8[0][0]',
#                                                                      'concatenate_9[0][0]',
#                                                                      'concatenate_10[0][0]']
#
#  tcn_43 (TCN)                (None, 195, 12)              6012      ['concatenate_11[0][0]']
#
#  tcn_44 (TCN)                (None, 195, 8)               1176      ['tcn_43[0][0]']
#
#  tcn_45 (TCN)                (None, 6)                    546       ['tcn_44[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    7         ['tcn_45[0][0]']
#
# ==================================================================================================
# Total params: 121261 (473.68 KB)
# Trainable params: 121165 (473.30 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tracemalloc
tracemalloc.start()
#create call backs
save_dir='/content/drive/My Drive/new_kimore/'
checkpoint = ModelCheckpoint(save_dir+'modelEX2.h5', save_best_only=True, monitor='val_loss', verbose=1, mode='min')
# define our early stopping
early_stop = EarlyStopping(
    monitor='loss',
    min_delta=0.001,
    patience=70,
    verbose=1,
    mode='min',
    restore_best_weights=True)
callbacks_list = [early_stop, checkpoint]## This saves the best model

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
t = now()

early_stopping = EarlyStopping(monitor='val_loss', patience = 75)

history = model.fit([trainx, trainx_2, trainx_4, trainx_8], train_y, batch_size=7, epochs=400, verbose=1,
                validation_data=([validx, validx_2, validx_4, validx_8], valid_y), callbacks = callbacks_list)

print('Training time: %s' % (now() - t))
# Out:
# Epoch 1/400
# 16/16 [==============================] - ETA: 0s - loss: 7.6857
# Epoch 1: val_loss improved from inf to 9.17074, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 277s 2s/step - loss: 7.6857 - val_loss: 9.1707
# Epoch 2/400
# 16/16 [==============================] - ETA: 0s - loss: 0.3969
# Epoch 2: val_loss improved from 9.17074 to 0.87560, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 571ms/step - loss: 0.3969 - val_loss: 0.8756
# Epoch 3/400
# 16/16 [==============================] - ETA: 0s - loss: 0.4507
# Epoch 3: val_loss improved from 0.87560 to 0.35266, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 517ms/step - loss: 0.4507 - val_loss: 0.3527
# Epoch 4/400
# 16/16 [==============================] - ETA: 0s - loss: 0.4520
# Epoch 4: val_loss improved from 0.35266 to 0.26693, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 7s 469ms/step - loss: 0.4520 - val_loss: 0.2669
# Epoch 5/400
# 16/16 [==============================] - ETA: 0s - loss: 0.2859
# Epoch 5: val_loss improved from 0.26693 to 0.20067, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 549ms/step - loss: 0.2859 - val_loss: 0.2007
# Epoch 6/400
# 16/16 [==============================] - ETA: 0s - loss: 0.3185
# Epoch 6: val_loss improved from 0.20067 to 0.17929, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 7s 474ms/step - loss: 0.3185 - val_loss: 0.1793
# Epoch 7/400
# 16/16 [==============================] - ETA: 0s - loss: 0.2262
# Epoch 7: val_loss improved from 0.17929 to 0.16342, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 591ms/step - loss: 0.2262 - val_loss: 0.1634
# Epoch 8/400
# 16/16 [==============================] - ETA: 0s - loss: 0.2533
# Epoch 8: val_loss improved from 0.16342 to 0.14230, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 505ms/step - loss: 0.2533 - val_loss: 0.1423
# Epoch 9/400
# 16/16 [==============================] - ETA: 0s - loss: 0.2580
# Epoch 9: val_loss improved from 0.14230 to 0.14222, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 487ms/step - loss: 0.2580 - val_loss: 0.1422
# Epoch 10/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1543
# Epoch 10: val_loss did not improve from 0.14222
# 16/16 [==============================] - 3s 179ms/step - loss: 0.1543 - val_loss: 0.1444
# Epoch 11/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1536
# Epoch 11: val_loss improved from 0.14222 to 0.13395, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 590ms/step - loss: 0.1536 - val_loss: 0.1339
# Epoch 12/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1825
# Epoch 12: val_loss did not improve from 0.13395
# 16/16 [==============================] - 3s 175ms/step - loss: 0.1825 - val_loss: 0.1379
# Epoch 13/400
# 16/16 [==============================] - ETA: 0s - loss: 0.2323
# Epoch 13: val_loss did not improve from 0.13395
# 16/16 [==============================] - 3s 196ms/step - loss: 0.2323 - val_loss: 0.1394
# Epoch 14/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1670
# Epoch 14: val_loss improved from 0.13395 to 0.12894, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 569ms/step - loss: 0.1670 - val_loss: 0.1289
# Epoch 15/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1480
# Epoch 15: val_loss improved from 0.12894 to 0.12544, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 557ms/step - loss: 0.1480 - val_loss: 0.1254
# Epoch 16/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1050
# Epoch 16: val_loss improved from 0.12544 to 0.12320, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 491ms/step - loss: 0.1050 - val_loss: 0.1232
# Epoch 17/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1500
# Epoch 17: val_loss improved from 0.12320 to 0.11827, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 562ms/step - loss: 0.1500 - val_loss: 0.1183
# Epoch 18/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1326
# Epoch 18: val_loss did not improve from 0.11827
# 16/16 [==============================] - 3s 166ms/step - loss: 0.1326 - val_loss: 0.1207
# Epoch 19/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0963
# Epoch 19: val_loss did not improve from 0.11827
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0963 - val_loss: 0.1330
# Epoch 20/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1180
# Epoch 20: val_loss did not improve from 0.11827
# 16/16 [==============================] - 4s 278ms/step - loss: 0.1180 - val_loss: 0.1193
# Epoch 21/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1328
# Epoch 21: val_loss did not improve from 0.11827
# 16/16 [==============================] - 3s 165ms/step - loss: 0.1328 - val_loss: 0.1204
# Epoch 22/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1296
# Epoch 22: val_loss improved from 0.11827 to 0.11310, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 498ms/step - loss: 0.1296 - val_loss: 0.1131
# Epoch 23/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1118
# Epoch 23: val_loss did not improve from 0.11310
# 16/16 [==============================] - 4s 248ms/step - loss: 0.1118 - val_loss: 0.1174
# Epoch 24/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1027
# Epoch 24: val_loss did not improve from 0.11310
# 16/16 [==============================] - 3s 176ms/step - loss: 0.1027 - val_loss: 0.1153
# Epoch 25/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0939
# Epoch 25: val_loss did not improve from 0.11310
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0939 - val_loss: 0.1134
# Epoch 26/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1010
# Epoch 26: val_loss did not improve from 0.11310
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1010 - val_loss: 0.1146
# Epoch 27/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1140
# Epoch 27: val_loss did not improve from 0.11310
# 16/16 [==============================] - 4s 268ms/step - loss: 0.1140 - val_loss: 0.1141
# Epoch 28/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1066
# Epoch 28: val_loss improved from 0.11310 to 0.11308, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 515ms/step - loss: 0.1066 - val_loss: 0.1131
# Epoch 29/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0888
# Epoch 29: val_loss did not improve from 0.11308
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0888 - val_loss: 0.1131
# Epoch 30/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0866
# Epoch 30: val_loss improved from 0.11308 to 0.11137, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 578ms/step - loss: 0.0866 - val_loss: 0.1114
# Epoch 31/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0837
# Epoch 31: val_loss did not improve from 0.11137
# 16/16 [==============================] - 3s 188ms/step - loss: 0.0837 - val_loss: 0.1127
# Epoch 32/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1020
# Epoch 32: val_loss improved from 0.11137 to 0.11088, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 586ms/step - loss: 0.1020 - val_loss: 0.1109
# Epoch 33/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1076
# Epoch 33: val_loss improved from 0.11088 to 0.10768, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 501ms/step - loss: 0.1076 - val_loss: 0.1077
# Epoch 34/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1089
# Epoch 34: val_loss improved from 0.10768 to 0.10634, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 493ms/step - loss: 0.1089 - val_loss: 0.1063
# Epoch 35/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1097
# Epoch 35: val_loss improved from 0.10634 to 0.10581, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 546ms/step - loss: 0.1097 - val_loss: 0.1058
# Epoch 36/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1132
# Epoch 36: val_loss did not improve from 0.10581
# 16/16 [==============================] - 3s 169ms/step - loss: 0.1132 - val_loss: 0.1127
# Epoch 37/400
# 16/16 [==============================] - ETA: 0s - loss: 0.1034
# Epoch 37: val_loss did not improve from 0.10581
# 16/16 [==============================] - 3s 175ms/step - loss: 0.1034 - val_loss: 0.1107
# Epoch 38/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0944
# Epoch 38: val_loss did not improve from 0.10581
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0944 - val_loss: 0.1097
# Epoch 39/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0886
# Epoch 39: val_loss did not improve from 0.10581
# 16/16 [==============================] - 4s 274ms/step - loss: 0.0886 - val_loss: 0.1058
# Epoch 40/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0995
# Epoch 40: val_loss improved from 0.10581 to 0.10288, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 503ms/step - loss: 0.0995 - val_loss: 0.1029
# Epoch 41/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0889
# Epoch 41: val_loss did not improve from 0.10288
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0889 - val_loss: 0.1031
# Epoch 42/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0907
# Epoch 42: val_loss improved from 0.10288 to 0.10102, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 555ms/step - loss: 0.0907 - val_loss: 0.1010
# Epoch 43/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0945
# Epoch 43: val_loss improved from 0.10102 to 0.10078, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 540ms/step - loss: 0.0945 - val_loss: 0.1008
# Epoch 44/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0865
# Epoch 44: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 164ms/step - loss: 0.0865 - val_loss: 0.1025
# Epoch 45/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0819
# Epoch 45: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0819 - val_loss: 0.1020
# Epoch 46/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 46: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0777 - val_loss: 0.1020
# Epoch 47/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0907
# Epoch 47: val_loss did not improve from 0.10078
# 16/16 [==============================] - 4s 271ms/step - loss: 0.0907 - val_loss: 0.1011
# Epoch 48/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 48: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0821 - val_loss: 0.1026
# Epoch 49/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0795
# Epoch 49: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 173ms/step - loss: 0.0795 - val_loss: 0.1043
# Epoch 50/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 50: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 171ms/step - loss: 0.0773 - val_loss: 0.1065
# Epoch 51/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0756
# Epoch 51: val_loss did not improve from 0.10078
# 16/16 [==============================] - 4s 233ms/step - loss: 0.0756 - val_loss: 0.1065
# Epoch 52/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0819
# Epoch 52: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 216ms/step - loss: 0.0819 - val_loss: 0.1037
# Epoch 53/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0844
# Epoch 53: val_loss did not improve from 0.10078
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0844 - val_loss: 0.1028
# Epoch 54/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0899
# Epoch 54: val_loss improved from 0.10078 to 0.10020, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 549ms/step - loss: 0.0899 - val_loss: 0.1002
# Epoch 55/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0776
# Epoch 55: val_loss improved from 0.10020 to 0.09974, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 8s 494ms/step - loss: 0.0776 - val_loss: 0.0997
# Epoch 56/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0707
# Epoch 56: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 190ms/step - loss: 0.0707 - val_loss: 0.1002
# Epoch 57/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0834
# Epoch 57: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 259ms/step - loss: 0.0834 - val_loss: 0.1024
# Epoch 58/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0832
# Epoch 58: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0832 - val_loss: 0.1036
# Epoch 59/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0757
# Epoch 59: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0757 - val_loss: 0.1039
# Epoch 60/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0815
# Epoch 60: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0815 - val_loss: 0.1050
# Epoch 61/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0763
# Epoch 61: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 265ms/step - loss: 0.0763 - val_loss: 0.1048
# Epoch 62/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0738
# Epoch 62: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0738 - val_loss: 0.1019
# Epoch 63/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0727
# Epoch 63: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0727 - val_loss: 0.1023
# Epoch 64/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0808
# Epoch 64: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0808 - val_loss: 0.1026
# Epoch 65/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0801
# Epoch 65: val_loss did not improve from 0.09974
# Epoch 80: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0781 - val_loss: 0.1056
# Epoch 81/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0790
# Epoch 81: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0790 - val_loss: 0.1028
# Epoch 82/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 82: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0779 - val_loss: 0.1026
# Epoch 83/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0756
# Epoch 83: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 258ms/step - loss: 0.0756 - val_loss: 0.1037
# Epoch 84/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0756
# Epoch 84: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0756 - val_loss: 0.1030
# Epoch 85/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0684
# Epoch 85: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0684 - val_loss: 0.1025
# Epoch 86/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0743
# Epoch 86: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 173ms/step - loss: 0.0743 - val_loss: 0.1032
# Epoch 87/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0806
# Epoch 87: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0806 - val_loss: 0.1031
# Epoch 88/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0773
# Epoch 88: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 216ms/step - loss: 0.0773 - val_loss: 0.1037
# Epoch 89/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0762
# Epoch 89: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0762 - val_loss: 0.1042
# Epoch 90/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 90: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0821 - val_loss: 0.1042
# Epoch 91/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0769
# Epoch 91: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0769 - val_loss: 0.1036
# Epoch 92/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0727
# Epoch 92: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 280ms/step - loss: 0.0727 - val_loss: 0.1034
# Epoch 93/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0756
# Epoch 93: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0756 - val_loss: 0.1034
# Epoch 94/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0648
# Epoch 94: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 190ms/step - loss: 0.0648 - val_loss: 0.1037
# Epoch 95/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 95: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0777 - val_loss: 0.1040
# Epoch 96/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0845
# Epoch 96: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 266ms/step - loss: 0.0845 - val_loss: 0.1050
# Epoch 97/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0708
# Epoch 97: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0708 - val_loss: 0.1056
# Epoch 98/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0687
# Epoch 98: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 173ms/step - loss: 0.0687 - val_loss: 0.1049
# Epoch 99/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0747
# Epoch 99: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0747 - val_loss: 0.1047
# Epoch 100/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0749
# Epoch 100: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0749 - val_loss: 0.1048
# Epoch 101/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0769
# Epoch 101: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0769 - val_loss: 0.1056
# Epoch 102/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0743
# Epoch 102: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0743 - val_loss: 0.1059
# Epoch 103/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0694
# Epoch 103: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0694 - val_loss: 0.1078
# Epoch 104/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0744
# Epoch 104: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0744 - val_loss: 0.1080
# Epoch 105/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0785
# Epoch 105: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0785 - val_loss: 0.1061
# Epoch 106/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0753
# Epoch 106: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0753 - val_loss: 0.1047
# Epoch 107/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0700
# Epoch 107: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0700 - val_loss: 0.1035
# Epoch 108/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0657
# Epoch 108: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0657 - val_loss: 0.1020
# Epoch 109/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0721
# Epoch 109: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 250ms/step - loss: 0.0721 - val_loss: 0.1016
# Epoch 110/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0670
# Epoch 110: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 183ms/step - loss: 0.0670 - val_loss: 0.1014
# Epoch 111/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0651
# Epoch 111: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0651 - val_loss: 0.1013
# Epoch 112/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0833
# Epoch 112: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0833 - val_loss: 0.1009
# Epoch 113/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0809
# Epoch 113: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0809 - val_loss: 0.1017
# Epoch 114/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0706
# Epoch 114: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 242ms/step - loss: 0.0706 - val_loss: 0.1020
# Epoch 115/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0863
# Epoch 115: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0863 - val_loss: 0.1016
# Epoch 116/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0717
# Epoch 116: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0717 - val_loss: 0.1014
# Epoch 117/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0694
# Epoch 117: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0694 - val_loss: 0.1013
# Epoch 118/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0626
# Epoch 118: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 274ms/step - loss: 0.0626 - val_loss: 0.1009
# Epoch 119/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0740
# Epoch 119: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0740 - val_loss: 0.1012
# Epoch 120/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0786
# Epoch 120: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0786 - val_loss: 0.1005
# Epoch 121/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0724
# Epoch 121: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0724 - val_loss: 0.1001
# Epoch 122/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0702
# Epoch 122: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 211ms/step - loss: 0.0702 - val_loss: 0.1003
# Epoch 123/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0755
# Epoch 123: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0755 - val_loss: 0.1005
# Epoch 124/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0709
# Epoch 124: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0709 - val_loss: 0.1012
# Epoch 125/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0687
# Epoch 125: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0687 - val_loss: 0.1010
# Epoch 126/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0756
# Epoch 126: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0756 - val_loss: 0.1022
# Epoch 127/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0682
# Epoch 127: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 273ms/step - loss: 0.0682 - val_loss: 0.1029
# Epoch 128/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0692
# Epoch 128: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0692 - val_loss: 0.1028
# Epoch 129/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0752
# Epoch 129: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0752 - val_loss: 0.1039
# Epoch 130/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0711
# Epoch 130: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0711 - val_loss: 0.1037
# Epoch 131/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0702
# Epoch 131: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 246ms/step - loss: 0.0702 - val_loss: 0.1041
# Epoch 132/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0749
# Epoch 132: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 198ms/step - loss: 0.0749 - val_loss: 0.1036
# Epoch 133/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0715
# Epoch 133: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 172ms/step - loss: 0.0715 - val_loss: 0.1040
# Epoch 134/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0686
# Epoch 134: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0686 - val_loss: 0.1031
# Epoch 135/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0664
# Epoch 135: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0664 - val_loss: 0.1035
# Epoch 136/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0713
# Epoch 136: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 238ms/step - loss: 0.0713 - val_loss: 0.1030
# Epoch 137/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0757
# Epoch 137: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0757 - val_loss: 0.1025
# Epoch 138/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0683
# Epoch 138: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0683 - val_loss: 0.1026
# Epoch 139/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0657
# Epoch 139: val_loss did not improve from 0.09974
# Epoch 154: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 199ms/step - loss: 0.0584 - val_loss: 0.1011
# Epoch 155/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0721
# Epoch 155: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0721 - val_loss: 0.0998
# Epoch 156/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0651
# Epoch 156: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 173ms/step - loss: 0.0651 - val_loss: 0.0998
# Epoch 157/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0626
# Epoch 157: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 225ms/step - loss: 0.0626 - val_loss: 0.1010
# Epoch 158/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0705
# Epoch 158: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0705 - val_loss: 0.1060
# Epoch 159/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0703
# Epoch 159: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0703 - val_loss: 0.1043
# Epoch 160/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0733
# Epoch 160: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0733 - val_loss: 0.1032
# Epoch 161/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0612
# Epoch 161: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0612 - val_loss: 0.1035
# Epoch 162/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0660
# Epoch 162: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0660 - val_loss: 0.1035
# Epoch 163/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0692
# Epoch 163: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0692 - val_loss: 0.1030
# Epoch 164/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0559
# Epoch 164: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 190ms/step - loss: 0.0559 - val_loss: 0.1019
# Epoch 165/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0664
# Epoch 165: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0664 - val_loss: 0.1028
# Epoch 166/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0693
# Epoch 166: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 269ms/step - loss: 0.0693 - val_loss: 0.1029
# Epoch 167/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0686
# Epoch 167: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0686 - val_loss: 0.1030
# Epoch 168/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0648
# Epoch 168: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0648 - val_loss: 0.1065
# Epoch 169/400
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0551 - val_loss: 0.1021
# Epoch 199/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0523
# Epoch 199: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0523 - val_loss: 0.1052
# Epoch 200/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0593
# Epoch 200: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0593 - val_loss: 0.1032
# Epoch 201/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0511
# Epoch 201: val_loss did not improve from 0.09974
# 16/16 [==============================] - 5s 290ms/step - loss: 0.0511 - val_loss: 0.1064
# Epoch 202/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0510
# Epoch 202: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 171ms/step - loss: 0.0510 - val_loss: 0.1091
# Epoch 203/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0608
# Epoch 203: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 171ms/step - loss: 0.0608 - val_loss: 0.1099
# Epoch 204/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0567
# Epoch 204: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0567 - val_loss: 0.1138
# Epoch 205/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0622
# Epoch 205: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 223ms/step - loss: 0.0622 - val_loss: 0.1144
# Epoch 206/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0488
# Epoch 206: val_loss did not improve from 0.09974
# 16/16 [==============================] - 4s 224ms/step - loss: 0.0488 - val_loss: 0.1067
# Epoch 207/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0428
# Epoch 207: val_loss did not improve from 0.09974
# 16/16 [==============================] - 3s 184ms/step - loss: 0.0428 - val_loss: 0.1011
# Epoch 208/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0414
# Epoch 208: val_loss improved from 0.09974 to 0.09729, saving model to /content/drive/My Drive/new_kimore/modelEX2.h5
# 16/16 [==============================] - 9s 571ms/step - loss: 0.0414 - val_loss: 0.0973
# Epoch 209/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0510
# Epoch 209: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0510 - val_loss: 0.0999
# Epoch 210/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0469
# Epoch 210: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0469 - val_loss: 0.1035
# Epoch 211/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0350
# Epoch 211: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0350 - val_loss: 0.1078
# Epoch 212/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 212: val_loss did not improve from 0.09729
# 16/16 [==============================] - 4s 236ms/step - loss: 0.0419 - val_loss: 0.1080
# Epoch 213/400
# Epoch 384/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 384: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 173ms/step - loss: 0.0103 - val_loss: 0.1098
# Epoch 385/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 385: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0103 - val_loss: 0.1075
# Epoch 386/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 386: val_loss did not improve from 0.09729
# 16/16 [==============================] - 4s 269ms/step - loss: 0.0088 - val_loss: 0.1152
# Epoch 387/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 387: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 186ms/step - loss: 0.0108 - val_loss: 0.1214
# Epoch 388/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0105
# Epoch 388: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0105 - val_loss: 0.1167
# Epoch 389/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 389: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 173ms/step - loss: 0.0163 - val_loss: 0.1096
# Epoch 390/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 390: val_loss did not improve from 0.09729
# 16/16 [==============================] - 4s 225ms/step - loss: 0.0087 - val_loss: 0.1103
# Epoch 391/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 391: val_loss did not improve from 0.09729
# 16/16 [==============================] - 4s 233ms/step - loss: 0.0104 - val_loss: 0.1104
# Epoch 392/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 392: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0110 - val_loss: 0.1079
# Epoch 393/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 393: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 173ms/step - loss: 0.0081 - val_loss: 0.1179
# Epoch 394/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 394: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0103 - val_loss: 0.1173
# Epoch 395/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 395: val_loss did not improve from 0.09729
# 16/16 [==============================] - 4s 275ms/step - loss: 0.0111 - val_loss: 0.1110
# Epoch 396/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0117
# Epoch 396: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0117 - val_loss: 0.1147
# Epoch 397/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 397: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0101 - val_loss: 0.1109
# Epoch 398/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 398: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 189ms/step - loss: 0.0077 - val_loss: 0.1093
# Epoch 399/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 399: val_loss did not improve from 0.09729
# 16/16 [==============================] - 4s 268ms/step - loss: 0.0092 - val_loss: 0.1078
# Epoch 400/400
# 16/16 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 400: val_loss did not improve from 0.09729
# 16/16 [==============================] - 3s 185ms/step - loss: 0.0098 - val_loss: 0.1213
# Training time: 0:28:27.484876

# %%
print(tracemalloc.get_traced_memory())
# stopping the library
tracemalloc.stop()
# Out:
# (133966781, 138231171)

# %%
# Plot the results
plt.figure(1)
plt.plot(history.history['loss'], 'b', label = 'Training Loss')
plt.title('Training Loss')
plt.plot(history.history['val_loss'], 'r', label = 'Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Print the minimum loss
print("Training loss", np.min(history.history['loss']))
print("Validation loss",np.min(history.history['val_loss']))
# Out:
# Training loss 0.007652455475181341
# Validation loss 0.09729355573654175

# %%
# Plot the prediction of the model for the training and validation sets
import tensorflow as tf
from keras.models import load_model
from keras.initializers import glorot_uniform
# Load the best model's weights
best_model = load_model('/content/drive/My Drive/new_kimore/modelEX2.h5', custom_objects={'TCN': TCN, 'GlorotUniform': glorot_uniform()})

pred_train = best_model.predict([trainx, trainx_2, trainx_4, trainx_8])

pred_test = best_model.predict([testx, testx_2, testx_4, testx_8])

plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.plot(pred_train,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(train_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.ylim([-0.1,1.1])
plt.title('Training Set',fontsize=18)
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.subplot(2,1,2)
plt.plot(pred_test,'s', color='red', label='Prediction', linestyle='None', alpha = 0.5, markersize=6)
plt.plot(valid_y,'o', color='green',label='Quality Score', alpha = 0.4, markersize=6)
plt.title('Testing Set',fontsize=18)
plt.ylim([-0.1,1.1])
plt.xlabel('Sequence Number',fontsize=16)
plt.ylabel('Quality Scale',fontsize=16)
plt.legend(loc=3, prop={'size':14}) # loc:position
plt.tight_layout()

plt.show()
# Out:
# 4/4 [==============================] - 14s 80ms/step
# 2/2 [==============================] - 0s 31ms/step

# %%
test_dev = abs(pred_test-test_y)
# Cumulative deviation
mean_abs_dev = np.mean(test_dev)
# RMS deviation
#MSE
MSE=mean_squared_error(pred_test, test_y)
#MAPE
#P1 = 19*pred_test + 31;
#P2 = 19*test_y+31;
MAPE=np.mean(np.abs((pred_test-test_y)/test_y))*100
print('MSE:',MSE)
rms_dev = np.sqrt(mean_squared_error(pred_test, test_y))
print('Mean absolute deviation:', mean_abs_dev)
print('RMS deviation:', rms_dev)
print('MAPE:',MAPE)
# Out:
# MSE: 0.10182101767789965
# Mean absolute deviation: 0.2721324888381526
# RMS deviation: 0.319094057728908
# MAPE: inf
